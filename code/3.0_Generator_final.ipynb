# %% [markdown]
# # **Generative LLM**

# %%
# !pip install datasets
# !pip install torch
# !pip install transformers
# !pip install peft
# !pip install bitsandbytes -U
# !pip install -U trl
# !pip install nltk
# !pip install faiss-cpu
# !pip install sentence_transformers
# Out:
# Collecting datasets
#   Using cached datasets-4.0.0-py3-none-any.whl.metadata (19 kB)
# Collecting filelock (from datasets)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from datasets) (1.24.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Using cached pyarrow-21.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from datasets) (2.1.1)
# Collecting requests>=2.32.2 (from datasets)
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting tqdm>=4.66.3 (from datasets)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting xxhash (from datasets)
#   Using cached xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Using cached multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /opt/conda/lib/python3.11/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2023.9.2)
# Collecting huggingface-hub>=0.24.0 (from datasets)
#   Using cached huggingface_hub-0.34.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.11/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.11/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.8.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.24.0->datasets) (4.8.0)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub>=0.24.0->datasets)
#   Using cached hf_xet-1.1.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Using cached datasets-4.0.0-py3-none-any.whl (494 kB)
# Using cached huggingface_hub-0.34.3-py3-none-any.whl (558 kB)
# Using cached multiprocess-0.70.16-py311-none-any.whl (143 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached pyarrow-21.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (42.8 MB)
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
# Using cached hf_xet-1.1.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Installing collected packages: xxhash, tqdm, requests, pyarrow, hf-xet, filelock, dill, multiprocess, huggingface-hub, datasets
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 13.0.0
#     Uninstalling pyarrow-13.0.0:
#       Successfully uninstalled pyarrow-13.0.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.7
#     Uninstalling dill-0.3.7:
#       Successfully uninstalled dill-0.3.7
# Successfully installed datasets-4.0.0 dill-0.3.8 filelock-3.18.0 hf-xet-1.1.5 huggingface-hub-0.34.3 multiprocess-0.70.16 pyarrow-21.0.0 requests-2.32.4 tqdm-4.67.1 xxhash-3.5.0
# Collecting torch
#   Using cached torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch) (3.18.0)
# Collecting typing-extensions>=4.10.0 (from torch)
#   Using cached typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch) (3.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch) (2023.9.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
#   Using cached nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
#   Using cached nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
#   Using cached nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
#   Using cached nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
#   Using cached nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)
#   Using cached nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)
#   Using cached nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
#   Using cached nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
#   Using cached nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)
#   Using cached nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch)
#   Using cached triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /opt/conda/lib/python3.11/site-packages (from triton==3.3.1->torch) (68.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Using cached torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl (821.2 MB)
# Using cached nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
# Using cached nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
# Using cached nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
# Using cached nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
# Using cached nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
# Using cached nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
# Using cached nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
# Using cached nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
# Using cached nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
# Using cached nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
# Using cached nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
# Using cached nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Using cached triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Installing collected packages: nvidia-cusparselt-cu12, typing-extensions, triton, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.8.0
#     Uninstalling typing_extensions-4.8.0:
#       Successfully uninstalled typing_extensions-4.8.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
# Successfully installed nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 sympy-1.14.0 torch-2.7.1 triton-3.3.1 typing-extensions-4.14.1
# Collecting transformers
#   Using cached transformers-4.54.1-py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /opt/conda/lib/python3.11/site-packages (from transformers) (0.34.3)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.11/site-packages (from transformers) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Using cached regex-2025.7.34-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from transformers) (2.32.4)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Using cached tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.11/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2023.9.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (2023.7.22)
# Using cached transformers-4.54.1-py3-none-any.whl (11.2 MB)
# Using cached regex-2025.7.34-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (798 kB)
# Using cached safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Using cached tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Installing collected packages: safetensors, regex, tokenizers, transformers
# Successfully installed regex-2025.7.34 safetensors-0.5.3 tokenizers-0.21.4 transformers-4.54.1
# Collecting peft
#   Using cached peft-0.17.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from peft) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from peft) (23.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from peft) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /opt/conda/lib/python3.11/site-packages (from peft) (2.7.1)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.11/site-packages (from peft) (4.54.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from peft) (4.67.1)
# Collecting accelerate>=0.21.0 (from peft)
#   Using cached accelerate-1.9.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.11/site-packages (from peft) (0.5.3)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /opt/conda/lib/python3.11/site-packages (from peft) (0.34.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (2023.9.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (1.1.5)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (1.14.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /opt/conda/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /opt/conda/lib/python3.11/site-packages (from triton==3.3.1->torch>=1.13.0->peft) (68.2.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.11/site-packages (from transformers->peft) (2025.7.34)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/conda/lib/python3.11/site-packages (from transformers->peft) (0.21.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=1.13.0->peft) (2.1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface_hub>=0.25.0->peft) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface_hub>=0.25.0->peft) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface_hub>=0.25.0->peft) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface_hub>=0.25.0->peft) (2023.7.22)
# Using cached peft-0.17.0-py3-none-any.whl (503 kB)
# Using cached accelerate-1.9.0-py3-none-any.whl (367 kB)
# Installing collected packages: accelerate, peft
# Successfully installed accelerate-1.9.0 peft-0.17.0
# Collecting bitsandbytes
#   Using cached bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torch<3,>=2.2 in /opt/conda/lib/python3.11/site-packages (from bitsandbytes) (2.7.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from bitsandbytes) (1.24.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (3.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (2023.9.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=2.2->bitsandbytes) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /opt/conda/lib/python3.11/site-packages (from triton==3.3.1->torch<3,>=2.2->bitsandbytes) (68.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.13.3->torch<3,>=2.2->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch<3,>=2.2->bitsandbytes) (2.1.3)
# Using cached bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl (72.9 MB)
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.46.1
# Collecting trl
#   Using cached trl-0.20.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: accelerate>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from trl) (1.9.0)
# Requirement already satisfied: datasets>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from trl) (4.0.0)
# Requirement already satisfied: transformers>=4.53.2 in /opt/conda/lib/python3.11/site-packages (from trl) (4.54.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /opt/conda/lib/python3.11/site-packages (from accelerate>=1.4.0->trl) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from accelerate>=1.4.0->trl) (23.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from accelerate>=1.4.0->trl) (5.9.5)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from accelerate>=1.4.0->trl) (6.0.1)
# Requirement already satisfied: torch>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from accelerate>=1.4.0->trl) (2.7.1)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /opt/conda/lib/python3.11/site-packages (from accelerate>=1.4.0->trl) (0.34.3)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/conda/lib/python3.11/site-packages (from accelerate>=1.4.0->trl) (0.5.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from datasets>=3.0.0->trl) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.11/site-packages (from datasets>=3.0.0->trl) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from datasets>=3.0.0->trl) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from datasets>=3.0.0->trl) (2.1.1)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.11/site-packages (from datasets>=3.0.0->trl) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.11/site-packages (from datasets>=3.0.0->trl) (4.67.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.11/site-packages (from datasets>=3.0.0->trl) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /opt/conda/lib/python3.11/site-packages (from datasets>=3.0.0->trl) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /opt/conda/lib/python3.11/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (2023.9.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.11/site-packages (from transformers>=4.53.2->trl) (2025.7.34)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/conda/lib/python3.11/site-packages (from transformers>=4.53.2->trl) (0.21.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.11/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (3.8.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub>=0.21.0->accelerate>=1.4.0->trl) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub>=0.21.0->accelerate>=1.4.0->trl) (1.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=3.0.0->trl) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=3.0.0->trl) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=3.0.0->trl) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=3.0.0->trl) (2023.7.22)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (1.14.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /opt/conda/lib/python3.11/site-packages (from triton==3.3.1->torch>=2.0.0->accelerate>=1.4.0->trl) (68.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets>=3.0.0->trl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets>=3.0.0->trl) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets>=3.0.0->trl) (2023.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (1.3.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=3.0.0->trl) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=2.0.0->accelerate>=1.4.0->trl) (2.1.3)
# Using cached trl-0.20.0-py3-none-any.whl (504 kB)
# Installing collected packages: trl
# Successfully installed trl-0.20.0
# Collecting nltk
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.11/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.11/site-packages (from nltk) (2025.7.34)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from nltk) (4.67.1)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Installing collected packages: nltk
# Successfully installed nltk-3.9.1

# %%
import subprocess
import sys
from datasets import Dataset
import re
import string
import seaborn as sns
import os
import pandas as pd
import random
import torch 
import numpy as np
from datasets import Dataset
import bitsandbytes as bnb
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    TrainingArguments,
    Trainer,
    DataCollatorForLanguageModeling,
    BitsAndBytesConfig,
    GenerationConfig
)
from trl import SFTTrainer
from peft import LoraConfig, get_peft_model, TaskType, PeftModel
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, classification_report
import warnings
import nltk
nltk.download('punkt_tab')
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
from sentence_transformers import SentenceTransformer
import faiss
import json
from tqdm import tqdm

warnings.filterwarnings('ignore')
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# Set random seeds for reproducibility
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.empty_cache()
# Out:
# [nltk_data] Downloading package punkt_tab to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## **1) Import Data**
#
# * Clean Linebreaks
# * Limit Speech Length

# %%
data = pd.read_csv("../data/final_data.csv", on_bad_lines='skip')

# drop unnamed
if "Unnamed: 0" in data.columns:
    data = data.drop("Unnamed: 0", axis=1)

data["party"] = data["party"].replace("CDU/CSU", "Union")
data
# Out:
#                                              speech_text  legislative_period  \
# 0      Herr Präsident! Kolleginnen und Kollegen! Die ...                  19
# 1      Sehr geehrter Herr Präsident! Liebe Kolleginne...                  19
# 2      Herr Präsident! Liebe Kolleginnen und Kollegen...                  19
# 3      Herr Präsident! Liebe Kolleginnen und Kollegen...                  19
# 4      Liebe Kolleginnen und Kollegen! Es ist vorhin ...                  19
# ...                                                  ...                 ...
# 36112  Sehr geehrter Herr Präsident! Liebe Kolleginne...                  20
# 36113  Frau Präsidentin! Meine Damen und Herren! Sie ...                  20
# 36114  Sehr geehrter Herr Präsident! Meine Damen und ...                  20
# 36115  Sehr geehrte Präsidentin! Liebe Kolleginnen un...                  20
# 36116  Sehr geehrte Frau Präsidentin! Sehr geehrte Fr...                  20
#
#        protocol_nr  agenda_item_number  party  \
# 0               10                   3  Union
# 1               10                   3    SPD
# 2               10                   3  Union
# 3               10                   3  GRÜNE
# 4               10                   3    FDP
# ...            ...                 ...    ...
# 36112           99                   5    SPD
# 36113           99                   3  GRÜNE
# 36114           99                   4    AfD
# 36115           99                   7  LINKE
# 36116           99                   6    FDP
#
#                                        agenda_item_title        date  \
# 0      Aktuelle Stunde zu einer europäischen Bankenunion  2018-01-31
# 1      Aktuelle Stunde zu einer europäischen Bankenunion  2018-01-31
# 2      Aktuelle Stunde zu einer europäischen Bankenunion  2018-01-31
# 3      Aktuelle Stunde zu einer europäischen Bankenunion  2018-01-31
# 4      Aktuelle Stunde zu einer europäischen Bankenunion  2018-01-31
# ...                                                  ...         ...
# 36112                            Wolfsbestandsmanagement  2023-04-26
# 36113  Aktuelle Stunde - Umstrittene Personalpolitik ...  2023-04-26
# 36114            Bundeswehreinsatz Evakuierung aus Sudan  2023-04-26
# 36115                       Unregulierte Massenmigration  2023-04-26
# 36116               Bundeswehreinsatz EUNAVFOR MED IRINI  2023-04-26
#
#                  full_name
# 0          Hans Michelbach
# 1      Ingrid Arndt-Brauer
# 2           Antje Tillmann
# 3           Gerhard Schick
# 4           Florian Toncar
# ...                    ...
# 36112          Lina Seitzl
# 36113         Till Steffen
# 36114      Joachim Wundrak
# 36115         Clara Bünger
# 36116         Nils Gründer
#
# [36117 rows x 8 columns]

# %%
# clean line breaks and special spaces
data["cleaned_text"] = data["speech_text"].apply(lambda x: x.replace("\xa0", " "))
data["cleaned_text"] = data["cleaned_text"].apply(lambda x: x.replace("\n", " "))

# remove repeated spaces
data["cleaned_text"] = data["cleaned_text"].apply(lambda x: re.sub(r'\s+', ' ', x).strip())

# %%
# extract count of words
data["word_count"] = data["cleaned_text"].apply(lambda x: len(x.split()))

# limit speech length
data_filtered = data[data["word_count"] >= 200][data["word_count"] < 1501]

print("Nr. of Training Speeches:", len(data_filtered))
data_filtered
# Out:
# Nr. of Training Speeches: 36117
#                                              speech_text  legislative_period  \
# 0      Herr Präsident! Kolleginnen und Kollegen! Die ...                  19
# 1      Sehr geehrter Herr Präsident! Liebe Kolleginne...                  19
# 2      Herr Präsident! Liebe Kolleginnen und Kollegen...                  19
# 3      Herr Präsident! Liebe Kolleginnen und Kollegen...                  19
# 4      Liebe Kolleginnen und Kollegen! Es ist vorhin ...                  19
# ...                                                  ...                 ...
# 36112  Sehr geehrter Herr Präsident! Liebe Kolleginne...                  20
# 36113  Frau Präsidentin! Meine Damen und Herren! Sie ...                  20
# 36114  Sehr geehrter Herr Präsident! Meine Damen und ...                  20
# 36115  Sehr geehrte Präsidentin! Liebe Kolleginnen un...                  20
# 36116  Sehr geehrte Frau Präsidentin! Sehr geehrte Fr...                  20
#
#        protocol_nr  agenda_item_number  party  \
# 0               10                   3  Union
# 1               10                   3    SPD
# 2               10                   3  Union
# 3               10                   3  GRÜNE
# 4               10                   3    FDP
# ...            ...                 ...    ...
# 36112           99                   5    SPD
# 36113           99                   3  GRÜNE
# 36114           99                   4    AfD
# 36115           99                   7  LINKE
# 36116           99                   6    FDP
#
#                                        agenda_item_title        date  \
# 0      Aktuelle Stunde zu einer europäischen Bankenunion  2018-01-31
# 1      Aktuelle Stunde zu einer europäischen Bankenunion  2018-01-31
# 2      Aktuelle Stunde zu einer europäischen Bankenunion  2018-01-31
# 3      Aktuelle Stunde zu einer europäischen Bankenunion  2018-01-31
# 4      Aktuelle Stunde zu einer europäischen Bankenunion  2018-01-31
# ...                                                  ...         ...
# 36112                            Wolfsbestandsmanagement  2023-04-26
# 36113  Aktuelle Stunde - Umstrittene Personalpolitik ...  2023-04-26
# 36114            Bundeswehreinsatz Evakuierung aus Sudan  2023-04-26
# 36115                       Unregulierte Massenmigration  2023-04-26
# 36116               Bundeswehreinsatz EUNAVFOR MED IRINI  2023-04-26
#
#                  full_name                                       cleaned_text  \
# 0          Hans Michelbach  Herr Präsident! Kolleginnen und Kollegen! Die ...
# 1      Ingrid Arndt-Brauer  Sehr geehrter Herr Präsident! Liebe Kolleginne...
# 2           Antje Tillmann  Herr Präsident! Liebe Kolleginnen und Kollegen...
# 3           Gerhard Schick  Herr Präsident! Liebe Kolleginnen und Kollegen...
# 4           Florian Toncar  Liebe Kolleginnen und Kollegen! Es ist vorhin ...
# ...                    ...                                                ...
# 36112          Lina Seitzl  Sehr geehrter Herr Präsident! Liebe Kolleginne...
# 36113         Till Steffen  Frau Präsidentin! Meine Damen und Herren! Sie ...
# 36114      Joachim Wundrak  Sehr geehrter Herr Präsident! Meine Damen und ...
# 36115         Clara Bünger  Sehr geehrte Präsidentin! Liebe Kolleginnen un...
# 36116         Nils Gründer  Sehr geehrte Frau Präsidentin! Sehr geehrte Fr...
#
#        word_count
# 0             520
# 1             693
# 2             710
# 3             752
# 4             872
# ...           ...
# 36112         837
# 36113         789
# 36114         611
# 36115         480
# 36116         578
#
# [36117 rows x 10 columns]

# %%
# list of greeting-related words
greeting_words = [
    "Damen", "Herren", "Herr", "Kollegen", "Kolleginnen", "Präsident", "Präsidentin",
    "Kollege", "Kollegin", "verehrte", "verehrten", "geehrte", "geehrter", "geehrten"
]

# Build a regex pattern to match any of these words as whole words (case insensitive)
greeting_pattern = re.compile(r'\b(?:' + '|'.join(greeting_words) + r')\b', flags=re.IGNORECASE)

def remove_greeting_sentences(text, max_sentences=10):
    # Tokenize into sentences
    sentences = sent_tokenize(text, language='german')
    
    cleaned_sentences = []
    for i, sentence in enumerate(sentences):
        if i < max_sentences and greeting_pattern.search(sentence):
            continue  # Skip greeting sentence
        cleaned_sentences.append(sentence)
    
    return ' '.join(cleaned_sentences)

# apply
data_filtered['speech_text_cleaned'] = data_filtered['cleaned_text'].apply(remove_greeting_sentences)
data_filtered
# Out:
#                                              speech_text  legislative_period  \
# 0      Herr Präsident! Kolleginnen und Kollegen! Die ...                  19
# 1      Sehr geehrter Herr Präsident! Liebe Kolleginne...                  19
# 2      Herr Präsident! Liebe Kolleginnen und Kollegen...                  19
# 3      Herr Präsident! Liebe Kolleginnen und Kollegen...                  19
# 4      Liebe Kolleginnen und Kollegen! Es ist vorhin ...                  19
# ...                                                  ...                 ...
# 36112  Sehr geehrter Herr Präsident! Liebe Kolleginne...                  20
# 36113  Frau Präsidentin! Meine Damen und Herren! Sie ...                  20
# 36114  Sehr geehrter Herr Präsident! Meine Damen und ...                  20
# 36115  Sehr geehrte Präsidentin! Liebe Kolleginnen un...                  20
# 36116  Sehr geehrte Frau Präsidentin! Sehr geehrte Fr...                  20
#
#        protocol_nr  agenda_item_number  party  \
# 0               10                   3  Union
# 1               10                   3    SPD
# 2               10                   3  Union
# 3               10                   3  GRÜNE
# 4               10                   3    FDP
# ...            ...                 ...    ...
# 36112           99                   5    SPD
# 36113           99                   3  GRÜNE
# 36114           99                   4    AfD
# 36115           99                   7  LINKE
# 36116           99                   6    FDP
#
#                                        agenda_item_title        date  \
# 0      Aktuelle Stunde zu einer europäischen Bankenunion  2018-01-31
# 1      Aktuelle Stunde zu einer europäischen Bankenunion  2018-01-31
# 2      Aktuelle Stunde zu einer europäischen Bankenunion  2018-01-31
# 3      Aktuelle Stunde zu einer europäischen Bankenunion  2018-01-31
# 4      Aktuelle Stunde zu einer europäischen Bankenunion  2018-01-31
# ...                                                  ...         ...
# 36112                            Wolfsbestandsmanagement  2023-04-26
# 36113  Aktuelle Stunde - Umstrittene Personalpolitik ...  2023-04-26
# 36114            Bundeswehreinsatz Evakuierung aus Sudan  2023-04-26
# 36115                       Unregulierte Massenmigration  2023-04-26
# 36116               Bundeswehreinsatz EUNAVFOR MED IRINI  2023-04-26
#
#                  full_name                                       cleaned_text  \
# 0          Hans Michelbach  Herr Präsident! Kolleginnen und Kollegen! Die ...
# 1      Ingrid Arndt-Brauer  Sehr geehrter Herr Präsident! Liebe Kolleginne...
# 2           Antje Tillmann  Herr Präsident! Liebe Kolleginnen und Kollegen...
# 3           Gerhard Schick  Herr Präsident! Liebe Kolleginnen und Kollegen...
# 4           Florian Toncar  Liebe Kolleginnen und Kollegen! Es ist vorhin ...
# ...                    ...                                                ...
# 36112          Lina Seitzl  Sehr geehrter Herr Präsident! Liebe Kolleginne...
# 36113         Till Steffen  Frau Präsidentin! Meine Damen und Herren! Sie ...
# 36114      Joachim Wundrak  Sehr geehrter Herr Präsident! Meine Damen und ...
# 36115         Clara Bünger  Sehr geehrte Präsidentin! Liebe Kolleginnen un...
# 36116         Nils Gründer  Sehr geehrte Frau Präsidentin! Sehr geehrte Fr...
#
#        word_count                                speech_text_cleaned
# 0             520  Die Bankenunion ist einer von drei Bausteinen,...
# 1             693  Liebe Gäste auf der Tribüne! Ich finde es schö...
# 2             710  Auch ohne die FDP hat es dieser Deutsche Bunde...
# 3             752  Ich glaube, es war deutlich, dass sich selbst ...
# 4             872  Das mag so sein. Aber wenn man sich in dieser ...
# ...           ...                                                ...
# 36112         837  Mit der Redezeit, die ich habe, möchte ich ger...
# 36113         789  Sie hörten gerade die Rede eines Menschen, von...
# 36114         611  Die jüngsten Gewaltausbrüche im Sudan und dere...
# 36115         480  Ehrlich gesagt bin ich es leid, dass wir uns j...
# 36116         578  Gestatten Sie mir die Bemerkung: So weit kommt...
#
# [36117 rows x 11 columns]

# %%
# sainity check
print(data_filtered["speech_text"][100])
print(data_filtered["speech_text_cleaned"][100])
# Out:
# Frau Präsidentin! Liebe Kolleginnen und Kollegen! Meine sehr verehrten Damen und Herren! Als ich 2013 ganz frisch im Bundestag die Berichterstattung für digitale Bildung übernommen habe, wusste mit diesen Begriffen noch kaum jemand etwas anzufangen, außer natürlich einer eingeschworenen Gemeinschaft digitalaffiner Lehrkräfte im Twitterlehrerzimmer. Seither sind wir wesentlich weitergekommen. Das freut mich ungemein. Nicht zuletzt waren es unser parlamentarischer Antrag im Jahr 2015 – danke noch einmal an den Kollegen Sven Volmering, der leider nicht mehr hier in unseren Reihen sitzt – und auch die beharrliche Aufklärungs- und Überzeugungsarbeit einer Community, die die KMK dazu bewogen haben, Handlungsempfehlungen für eine solche Bildungswelt zu erarbeiten. Dann kam die Ankündigung der damaligen Bildungsministerin Wanka eines DigitalPakts in der „BamS“. Jetzt haben wir den DigitalPakt, und zwar mit Brief und Siegel. Das ist großartig. Das ist ein Anlass zur Freude, zum Durchatmen, aber bitte nicht zu lang.
# Wir leben in einer Welt, die niemals stehen bleibt, in der digitale Medien, die Methode digitalen Lernens und Arbeitens immer selbstverständlicher werden. Die Schule muss dazu ermutigen und befähigen. Insofern bin ich der Opposition dankbar, als sie den DigitalPakt weiterdenkt und weiterentwickelt. Das steht heute nicht an, aber es muss weitergehen, ganz klar. Auch ich bin überzeugt: Der DigitalPakt muss dauerhaft finanziert werden. Das ist eine dauerhafte Aufgabe.
# Auch andere Bildungsbereiche müssen irgendwann dazukommen. Den technischen Support können wir den Lehrkräften nicht weiterhin überlassen. Sie sind überfordert. Bei Datenschutz und Datensicherheit haben wir noch Handlungsbedarf, auch wenn, liebe Frau Kollegin Suding, der Fuß nicht im Gefängnis steht. Bußgelder ja, aber Gefängnis nicht.
# Nicht zuletzt sollten wir Open Educational Resources unbedingt stärker fördern. Dazu gab es aufgrund unserer Initiative einen kleinen, aber feinen Haushaltstitel im Haushalt des BMBF. Es würde mich riesig freuen, wenn wir damit endlich weiterkommen.
# Was wir aber nicht aus dem Auge verlieren sollten, ist: Der digitale Wandel ist viel mehr kultureller als technologischer Art. Den Wandel der Lernkultur können wir aber nicht von oben verordnen, auch nicht mit Geld initiieren. Die Investitionen in Technik werden nur dann etwas verändern, wenn wir Lehrenden und Lernenden vor Ort die nötige Unterstützung, aber auch den nötigen Freiraum geben, um ihre eigene zeitgemäße Lehr- und Lernkultur zu entwickeln.
# Vielen Dank.
# Ich schließe die Aussprache.
#
# Als ich 2013 ganz frisch im Bundestag die Berichterstattung für digitale Bildung übernommen habe, wusste mit diesen Begriffen noch kaum jemand etwas anzufangen, außer natürlich einer eingeschworenen Gemeinschaft digitalaffiner Lehrkräfte im Twitterlehrerzimmer. Seither sind wir wesentlich weitergekommen. Das freut mich ungemein. Dann kam die Ankündigung der damaligen Bildungsministerin Wanka eines DigitalPakts in der „BamS“. Jetzt haben wir den DigitalPakt, und zwar mit Brief und Siegel. Das ist großartig. Das ist ein Anlass zur Freude, zum Durchatmen, aber bitte nicht zu lang. Wir leben in einer Welt, die niemals stehen bleibt, in der digitale Medien, die Methode digitalen Lernens und Arbeitens immer selbstverständlicher werden. Die Schule muss dazu ermutigen und befähigen. Insofern bin ich der Opposition dankbar, als sie den DigitalPakt weiterdenkt und weiterentwickelt. Das steht heute nicht an, aber es muss weitergehen, ganz klar. Auch ich bin überzeugt: Der DigitalPakt muss dauerhaft finanziert werden. Das ist eine dauerhafte Aufgabe. Auch andere Bildungsbereiche müssen irgendwann dazukommen. Den technischen Support können wir den Lehrkräften nicht weiterhin überlassen. Sie sind überfordert. Bei Datenschutz und Datensicherheit haben wir noch Handlungsbedarf, auch wenn, liebe Frau Kollegin Suding, der Fuß nicht im Gefängnis steht. Bußgelder ja, aber Gefängnis nicht. Nicht zuletzt sollten wir Open Educational Resources unbedingt stärker fördern. Dazu gab es aufgrund unserer Initiative einen kleinen, aber feinen Haushaltstitel im Haushalt des BMBF. Es würde mich riesig freuen, wenn wir damit endlich weiterkommen. Was wir aber nicht aus dem Auge verlieren sollten, ist: Der digitale Wandel ist viel mehr kultureller als technologischer Art. Den Wandel der Lernkultur können wir aber nicht von oben verordnen, auch nicht mit Geld initiieren. Die Investitionen in Technik werden nur dann etwas verändern, wenn wir Lehrenden und Lernenden vor Ort die nötige Unterstützung, aber auch den nötigen Freiraum geben, um ihre eigene zeitgemäße Lehr- und Lernkultur zu entwickeln. Vielen Dank. Ich schließe die Aussprache.

# %% [markdown]
# ### **Get Topics and Counts of Speeches per Party and Topic**

# %%
parties = data_filtered["party"].unique()

for party in parties:
    print(f"Partei: {party}")
    print(data_filtered[data_filtered["party"] == party]["agenda_item_title"].value_counts().head(20))
# Out:
# Partei: Union
# agenda_item_title
# Auswärtiges Amt                                                   75
# Verteidigung                                                      68
# Abschließende Beratungen ohne Aussprache                          67
# Wirtschaftliche Zusammenarbeit und Entwicklung                    66
# Gesundheit                                                        64
# Ernährung und Landwirtschaft                                      58
# Bildung und Forschung                                             53
# Überweisungen im vereinfachten Verfahren                          51
# Familie, Senioren, Frauen und Jugend                              49
# Arbeit und Soziales                                               43
# Bundeswehreinsatz in Kosovo (KFOR)                                35
# Digitales und Verkehr                                             33
# Bundeswehreinsatz in Mali (MINUSMA)                               32
# Umwelt, Naturschutz und nukleare Sicherheit                       32
# Bundeswehreinsatz in Südsudan (UNMISS)                            28
# Umwelt, Naturschutz, nukleare Sicherheit und Verbraucherschutz    27
# Bundeskanzlerin und Bundeskanzleramt                              25
# Justiz und Verbraucherschutz                                      25
# Verkehr und digitale Infrastruktur                                24
# Regierungserklärung zum Europäischen Rat                          23
# Name: count, dtype: int64
# Partei: SPD
# agenda_item_title
# Verteidigung                                                      62
# Gesundheit                                                        56
# Abschließende Beratungen ohne Aussprache                          55
# Wirtschaftliche Zusammenarbeit und Entwicklung                    55
# Auswärtiges Amt                                                   52
# Ernährung und Landwirtschaft                                      49
# Bildung und Forschung                                             46
# Familie, Senioren, Frauen und Jugend                              44
# Bundeskanzlerin und Bundeskanzleramt                              38
# Digitales und Verkehr                                             37
# Überweisungen im vereinfachten Verfahren                          37
# Arbeit und Soziales                                               33
# Umwelt, Naturschutz, nukleare Sicherheit und Verbraucherschutz    27
# Umwelt, Naturschutz und nukleare Sicherheit                       25
# Verkehr und digitale Infrastruktur                                24
# Bundeswehreinsatz in Kosovo (KFOR)                                23
# Wohnen, Stadtentwicklung und Bauwesen                             21
# Regierungserklärung zum Europäischen Rat                          20
# Bundeswehreinsatz in Mali (MINUSMA)                               19
# Justiz und Verbraucherschutz                                      19
# Name: count, dtype: int64
# Partei: GRÜNE
# agenda_item_title
# Auswärtiges Amt                                                   52
# Wirtschaftliche Zusammenarbeit und Entwicklung                    41
# Gesundheit                                                        39
# Ernährung und Landwirtschaft                                      36
# Verteidigung                                                      36
# Bildung und Forschung                                             34
# Abschließende Beratungen ohne Aussprache                          33
# Familie, Senioren, Frauen und Jugend                              28
# Arbeit und Soziales                                               26
# Überweisungen im vereinfachten Verfahren                          24
# Digitales und Verkehr                                             23
# Umwelt, Naturschutz, nukleare Sicherheit und Verbraucherschutz    19
# Wohnen, Stadtentwicklung und Bauwesen                             16
# Umwelt, Naturschutz und nukleare Sicherheit                       15
# Überweisung im vereinfachten Verfahren                            14
# Regierungserklärung zum Europäischen Rat                          14
# Wirtschaft und Klimaschutz                                        13
# Bundeskanzlerin und Bundeskanzleramt                              13
# Bundeswehreinsatz in Mali (MINUSMA)                               13
# Bundeswehreinsatz in Kosovo (KFOR)                                12
# Name: count, dtype: int64
# Partei: FDP
# agenda_item_title
# Verteidigung                                                      42
# Auswärtiges Amt                                                   35
# Wirtschaftliche Zusammenarbeit und Entwicklung                    34
# Abschließende Beratungen ohne Aussprache                          34
# Gesundheit                                                        34
# Ernährung und Landwirtschaft                                      28
# Bildung und Forschung                                             28
# Familie, Senioren, Frauen und Jugend                              26
# Überweisungen im vereinfachten Verfahren                          25
# Arbeit und Soziales                                               23
# Digitales und Verkehr                                             18
# Umwelt, Naturschutz und nukleare Sicherheit                       16
# Justiz und Verbraucherschutz                                      15
# Umwelt, Naturschutz, nukleare Sicherheit und Verbraucherschutz    14
# Bundeswehreinsatz in Kosovo (KFOR)                                13
# Wohnen, Stadtentwicklung und Bauwesen                             13
# Bundeswehreinsatz in Mali (MINUSMA)                               13
# Wirtschaft und Klimaschutz                                        11
# Bundeswehreinsatz in Südsudan (UNMISS)                            11
# Verkehr und digitale Infrastruktur                                11
# Name: count, dtype: int64
# Partei: AfD
# agenda_item_title
# Abschließende Beratungen ohne Aussprache                          44
# Auswärtiges Amt                                                   42
# Wirtschaftliche Zusammenarbeit und Entwicklung                    40
# Ernährung und Landwirtschaft                                      38
# Gesundheit                                                        37
# Verteidigung                                                      36
# Bildung und Forschung                                             30
# Familie, Senioren, Frauen und Jugend                              27
# Arbeit und Soziales                                               26
# Bundeskanzlerin und Bundeskanzleramt                              25
# Überweisungen im vereinfachten Verfahren                          25
# Digitales und Verkehr                                             19
# Justiz und Verbraucherschutz                                      18
# Umwelt, Naturschutz, nukleare Sicherheit und Verbraucherschutz    17
# Umwelt, Naturschutz und nukleare Sicherheit                       16
# Wirtschaft und Klimaschutz                                        15
# Bundeswehreinsatz in Kosovo (KFOR)                                15
# Verkehr und digitale Infrastruktur                                13
# Bundeswehreinsatz in Mali (MINUSMA)                               13
# Wohnen, Stadtentwicklung und Bauwesen                             13
# Name: count, dtype: int64
# Partei: LINKE
# agenda_item_title
# Verteidigung                                                      29
# Abschließende Beratungen ohne Aussprache                          29
# Wirtschaftliche Zusammenarbeit und Entwicklung                    26
# Gesundheit                                                        24
# Bildung und Forschung                                             23
# Familie, Senioren, Frauen und Jugend                              23
# Arbeit und Soziales                                               20
# Auswärtiges Amt                                                   19
# Ernährung und Landwirtschaft                                      19
# Überweisungen im vereinfachten Verfahren                          17
# Umwelt, Naturschutz und nukleare Sicherheit                       15
# Bundeswehreinsatz in Mali (MINUSMA)                               13
# Justiz und Verbraucherschutz                                      13
# Bundeswehreinsatz in Kosovo (KFOR)                                12
# Bundeswehreinsatz in Südsudan (UNMISS)                            11
# Verkehr und digitale Infrastruktur                                10
# Umwelt, Naturschutz, nukleare Sicherheit und Verbraucherschutz     9
# Digitales und Verkehr                                              9
# Wirtschaft und Energie                                             9
# Bundeswehreinsatz im Mittelmeer (SEA GUARDIAN)                     9
# Name: count, dtype: int64

# %%
def classify_topic_from_agenda(title):
    if pd.isna(title):
        return "Sonstiges"

    title = str(title).lower()

    # 1
    if "mindestlohn" in title or "lohnerhöhung" in title or "arbeitslohn" in title:
        return "Mindestlohn"

    # 2
    elif "kosovo" in title or "kfor" in title or "bundeswehreinsatz im kosovo" in title or "einsatz der bundeswehr im kosovo" in title:
        return "Kosovo"

    # 3
    elif any(term in title for term in [
        "corona", "covid", "pandemie", "wirtschaftshilfe",
        "wirtschaftsstabilisierungsfonds", "coronahilfen",
        "pandemiehilfe",
    ]):
        return "Pandemiehilfen"

    # 4
    elif any(term in title for term in [
        "gas", "gaspreis", "energiepreis", "energiepreise",
        "gasversorgung", "gasmarkt", "energiekrise",
        "preisdeckel", "gaspreisbremse"
    ]):
        return "Gaspreise"

    else:
        return "Sonstiges"

# %%
data_filtered["topic_for_RAG"] = data_filtered["agenda_item_title"].apply(classify_topic_from_agenda)

topic_counts = data_filtered.groupby(["party", "topic_for_RAG"]).size().reset_index(name="count")
pivot_table = topic_counts.pivot(index="party", columns="topic_for_RAG", values="count").fillna(0).astype(int)
print(pivot_table)

# enough speeches for RAG
# Out:
# topic_for_RAG  Gaspreise  Kosovo  Mindestlohn  Pandemiehilfen  Sonstiges
# party
# AfD                   55      18           14             144       4810
# FDP                   63      15           15             124       4466
# GRÜNE                 79      14           18             114       4842
# LINKE                 41      13           11             105       3448
# SPD                  112      27           27             209       7657
# Union                108      38           31             275       9224

# %%
# save

topics = ["Mindestlohn", "Kosovo", "Pandemiehilfen", "Gaspreise"]
filtered_df = data_filtered[data_filtered["topic_for_RAG"].isin(topics)]

structured_speeches = []

for idx, row in filtered_df.iterrows():
    structured_speeches.append({
        "party": row["party"],
        "topic": row["topic_for_RAG"],
        "speech_nr": idx,
        "original_speech": row["cleaned_text"]
    })
    
with open("classified_speeches.json", "w", encoding="utf-8") as f:
    json.dump(structured_speeches, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ## **2) Sample Speeches**
#
# * Ensure same number of training speeches per party

# %%
parties_count = data_filtered[["cleaned_text", "party"]].groupby("party").count().reset_index()
parties_count
# Out:
#    party  cleaned_text
# 0    AfD          5041
# 1    FDP          4683
# 2  GRÜNE          5067
# 3  LINKE          3618
# 4    SPD          8032
# 5  Union          9676

# %%
data_filtered = data_filtered.drop_duplicates(subset="cleaned_text")

# %%
# As we agreed to a balance sample, I shorten the dataframe to te maximmum length of LINKE
max_length = parties_count["cleaned_text"].min() #3618

parteien = data_filtered["party"].unique()

# Leerer DataFrame zum Sammeln
clean_df = pd.DataFrame()

# For every random subset if more than 3618 speeches, else take all of them
for partei in parteien:
    partei_unique_df = data_filtered[data_filtered["party"] == partei]

    if len(partei_unique_df) >= max_length:
        partei_sample = partei_unique_df.sample(n=max_length, random_state=42)
    else:
        partei_sample = partei_unique_df


    clean_df = pd.concat([clean_df, partei_sample], ignore_index=True)


clean_df.head()
# Out:
#                                          speech_text  legislative_period  \
# 0  Sehr geehrte Frau Präsidentin! Werte Kolleginn...                  20
# 1  Hochgeschätzter Herr Präsident! Kolleginnen un...                  19
# 2  Frau Präsidentin! Verehrte Kolleginnen und Kol...                  20
# 3  Frau Präsidentin! Liebe Kolleginnen und Kolleg...                  20
# 4  Herr Präsident! Meine sehr verehrten Damen und...                  19
#
#    protocol_nr  agenda_item_number  party  \
# 0           79                  12  Union
# 1           23                   6  Union
# 2           18                   8  Union
# 3           21                   4  Union
# 4          164                   3  Union
#
#                                    agenda_item_title        date  \
# 0  EU-Richtlinie Umweltauswirkungen Kunststoffpro...  2023-01-19
# 1                 Verkehr und digitale Infrastruktur  2018-03-22
# 2  Aktuelle Stunde - Bundeswehreinsätze in Mali b...  2022-02-18
# 3                Meinungsfreiheit in Sozialen Medien  2022-03-17
# 4                        Bundeswehreinsatz EUTM Mali  2020-05-29
#
#                full_name                                       cleaned_text  \
# 0            Björn Simon  Sehr geehrte Frau Präsidentin! Werte Kolleginn...
# 1        Andreas Scheuer  Hochgeschätzter Herr Präsident! Kolleginnen un...
# 2        Reinhard Brandl  Frau Präsidentin! Verehrte Kolleginnen und Kol...
# 3       Marc Henrichmann  Frau Präsidentin! Liebe Kolleginnen und Kolleg...
# 4  Johann David Wadephul  Herr Präsident! Meine sehr verehrten Damen und...
#
#    word_count                                speech_text_cleaned topic_for_RAG
# 0         789  Auch von meiner Seite aus einen herzlichen Glü...     Sonstiges
# 1        1292  Luftqualität ist Lebensqualität; aber Lebensqu...     Sonstiges
# 2         741  Die Ampelkoalition kann jetzt nichts für die S...     Sonstiges
# 3         936  Das vierte Wort im Antrag der AfD ist „Russlan...     Sonstiges
# 4        1011  Die Lage im Sahel ist kritisch. Sie ist sogar ...     Sonstiges

# %% [markdown]
# ## **3.) Import the Base Model**

# %%
# Model configuration
model_name = "jphme/Llama-2-13b-chat-german"
device = "cuda" if torch.cuda.is_available() else "cpu"

print(f"Loading Llama model: {model_name}")
print(f"Device: {device}")

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token


quantization_config = BitsAndBytesConfig(
    load_in_4bit = True, 
    bnb_4bit_quant_type = 'nf4',
    bnb_4bit_use_double_quant = True, 
    bnb_4bit_compute_dtype = torch.bfloat16 
)


# Load LLama model
base_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    quantization_config = quantization_config,
    device_map="auto" if torch.cuda.is_available() else None,
)

print("Llama model and tokenizer loaded successfully!")
print(f"Model parameters: {base_model.num_parameters():,}")
# Out:
# Loading Llama model: jphme/Llama-2-13b-chat-german
# Device: cuda
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Llama model and tokenizer loaded successfully!
# Model parameters: 13,015,864,320

# %%
# create the chat template --> was missing

tokenizer.chat_template = """<s>[INST] <<SYS>>Du bist ein hilfreicher, respektvoller und ehrlicher Assistent.
Verhalte dich wie ein*e Abgeordnete*r im deutschen Bundestag.
Gegeben einer Parteizugehörigkeit und eines Themas, schreibe eine politische Rede im Umfang von 200 bis 1500 Worten.
<</SYS>>

{% for message in messages %}
{{ message['content'] }}{% if not loop.last %} [/INST] <s>[INST] {% else %} [/INST] {% endif %}
{% endfor %}</s>"""

tokenizer.model_max_length = 2048

# %% [markdown]
# ## **4.) Generate a baseline speech given a title**

# %%
def generate_prediction_base(fraction_label, title, model, tokenizer):
    
    """Generate politicat party speeches using the base Llama model with chat template"""
    
    # Create messages in the format expected by Llama
    messages = [
        {
            "role": "user",
            "content": f" Du bist ein*e Abgeordnete*r im deutschen Bundestag. Deine Fraktion ist: {fraction_label}. Schreibe eine politische Rede mit bis zu 1500 Worten, die du im Bundestag hälst. Der Titel ist {title}."
        }
    ]

    # Apply chat template with thinking disabled for consistency
    formatted_text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
        enable_thinking=False  # Disable for consistency with training
    )

    model_inputs = tokenizer([formatted_text], return_tensors="pt", max_length=2048, truncation=True).to(model.device)

    # Generate prediction with proper stopping
    with torch.inference_mode():
        generated_ids = model.generate(
            **model_inputs,
            max_new_tokens=2048,
            temperature=0.1,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id,  # Ensure EOS token stops generation
        )

    # Extract only the new tokens
    output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist()

    # Decode the response and remove EOS token if present
    content = tokenizer.decode(output_ids, skip_special_tokens=True).strip()

    return content

# %%
# get an actual speech title per party

random_title_info = {}

for party in clean_df["party"].unique():
    sample = clean_df[clean_df["party"] == party].sample(n=1, random_state=23)
    index = sample.index[0]
    title = sample["agenda_item_title"].values[0]
    random_title_info[party] = {"index": index, "title": title}

random_title_info
# Out:
# {'Union': {'index': 713, 'title': 'Regulierung von Bonitätsauskünften'},
#  'SPD': {'index': 4331,
#   'title': 'Bildung und Forschung für geflüchtete Ukrainer'},
#  'GRÜNE': {'index': 7949,
#   'title': 'Verteidigungspolitik, Einsatzbereitschaft Bundeswehr'},
#  'FDP': {'index': 11567,
#   'title': 'Aktuelle Stunde zur Eskalation in der Golfregion'},
#  'AfD': {'index': 15185, 'title': 'Kinderzukunftsprogramm'},
#  'LINKE': {'index': 18803, 'title': 'Netzwerkdurchsetzungsgesetz'}}

# %%
# make predictions for base model on title


prediction_base = []

for party, value in random_title_info.items():
    print(party)
    prediction_base.append(generate_prediction_base(party, value["title"], base_model, tokenizer))
# Out:
# Union
# SPD
# GRÜNE
# FDP
# AfD
# LINKE

# %%
prediction_base_df = pd.DataFrame(prediction_base).rename(columns = {0 : "speech"})
prediction_base_df["party"] =  list(random_title_info.keys())
prediction_base_df.to_csv("../data/generative_predictions_base.csv")
prediction_base_df
# Out:
#                                               speech  party
# 0  #Regulierung von Bonitätsauskünften#\n\nHerr P...  Union
# 1  #Bildung und Forschung für geflüchtete Ukraine...    SPD
# 2  #Verteidigungspolitik, Einsatzbereitschaft Bun...  GRÜNE
# 3  #Halte 1#\n\nHerr Präsident, verehrtes Haus,\n...    FDP
# 4  #Hallo, meine Damen und Herren,\n\nheute möcht...    AfD
# 5  #Netzwerkdurchsetzungsgesetz#\n\nHerr Präsiden...  LINKE

# %% [markdown]
# **Compare Predictions and true speeches**

# %%
for i, (party, value) in enumerate(random_title_info.items()):
    
    # true speech
    true_speech = clean_df.loc[clean_df['agenda_item_title'] == value["title"], 'speech_text'].values[0]

    # Get the predicted speech
    predicted_speech = prediction_base[i]

    # Print comparison
    print("\n===================")
    print(f"=== {party} ===")
    print(f"Agenda Item: {value['title']}")
    print("===================")

    print(" True Speech:")
    print("===================")
    print(true_speech)
    
    print("Predicted Speech:")
    print("===================")
    print(predicted_speech)
# Out:
# ===================
# === Union ===
# Agenda Item: Regulierung von Bonitätsauskünften
# ===================
#  True Speech:
# ===================
# Ich warte gern noch etwas, wenn Sie mich weiter loben wollen, Frau Präsidentin.
# Sonntag ist der erste Advent.
# Sehr geehrte Frau Präsidentin! Liebe Kolleginnen! Liebe Kollegen! In unserem Land besteht grundsätzlich die im Grundgesetz verankerte Vertragsfreiheit. Mit der hat eine Partei in diesem Haus immer wieder sichtliche Probleme. Lieber Matthias Birkwald, liebe Frau Nastic, heute Nachmittag haben wir hier über die Frage eines Kündigungsschutzes für über 70-jährige Mieter debattiert.
# Das klingt toll, das klingt gut, aber das ist bei Ihren Anträgen immer so. Es gibt da immer zwei Seiten der Medaille, eine positive, die verlockend klingt – das ist der Kündigungsschutz für über 70-jährige Mieter –, aber gleichzeitig die Rückseite der Medaille, nämlich die Problematik, dass dann ein 65-jähriger, 67-jähriger, 68-jähriger Mietinteressent gar keinen Mietvertrag mehr bekommen wird.
# Das heißt ja im Endeffekt: Was immer gut gemeint ist, ist noch lange nicht gut gemacht.
# – Er darf eine Zwischenfrage stellen; ich würde sie zulassen, Frau Präsidentin.
# Nein, das kann er jetzt nicht. Jetzt reden Sie. Ich weiß schon: Sie wollen wieder mehr Redezeit.
# Los geht’s! Sie haben immer noch vier Minuten.
# Herr Kollege Birkwald, auch für euch gilt: Quidquid agis, prudenter agas et respice finem! – Das heißt: Was immer du tust, handle klug und bedenke das Ende. – Sie sind mit diesem Antrag gerade wieder im Begriff, das Kind mit dem Bade auszuschütten.
# Die Vorredner haben bereits zum Teil darauf hingewiesen: Es gibt ja bei der Schufa nicht nur die negative Auskunft. Es gibt ja bei der Schufa nicht nur die Situation, dass ein gesperrtes Konto, ein nicht zurückgezahlter Kredit oder eine offene Mahngebühr dazu führt, dass eine Auskunft negativ ist. Es gibt genauso die Möglichkeit, nichts auf dem Kerbholz zu haben, also keine Probleme, keinen Schufa-Eintrag. Damit schafft man – es wurde von den Kollegen bereits angesprochen – eine Vertrauensbasis, wie es sie in früheren kleinen Gesellschaften, in kleinen Dörfern gegeben hat: Da hat man sich gekannt; da wurde beim Viehhändler noch der Vertrag mit Handschlag besiegelt;
# da kannte man den Vertragspartner. Es gibt aber in unserer heutigen Gesellschaft oft genug anonyme Vertragsverhältnisse: Man kennt den Vertragspartner nicht. Um das Vertrauen herzustellen, gibt es die Möglichkeit, eine Schufa-Auskunft einzuholen. – Frau Nastic wollte mich was fragen, Frau Präsidentin.
# Ich würde es zulassen.
# Wollen Sie wirklich was fragen, Frau Nastic? – Gut. Sie lassen es zu?
# Ja, selbstverständlich.
# Vielen Dank, dass Sie die Frage zulassen. – Was sagen Sie denn zu den heutigen Nachrichten, dass die Schufa millionenfach Daten eingekauft hat, mittlerweile auch Kontoauszüge durchleuchten will, damit den Datenschutz massiv verletzt und die Menschen quasi zu gläsernen Bürgern macht? Damit wären der Schufa alle Kontobewegungen bekannt. Auch der ehemalige Datenschutzbeauftragte Peter Schaar ist alarmiert und wendet sich massiv gegen das, was die Schufa da gerade macht.
# Danke, Frau Nastic, für die Frage. – Ich bin weit davon entfernt, die Schufa heiligzusprechen. Natürlich: Wo die Schufa arbeitet, können auch Fehler gemacht werden. Es muss unter Datenschutzaspekten geprüft werden, ob die Sammelwut, die manchmal an den Tag gelegt wird, überhaupt begründet und verhältnismäßig ist, ob die zur Zweckverfolgung gewählten Mittel überhaupt sinnvoll sind.
# Sind das noch die Reste von der Weindebatte?
# – Die Weindebatte hat in Ravensburg ihre Spuren hinterlassen.
# Jetzt bitte ich doch, das Thema ernst zu nehmen. – Noch mal, Frau Nastic: Ich verkenne nicht, dass bei der Schufa auch Fehler gemacht werden. Wenn die Informationen, die ich auch heute Nachmittag der Presse entnehmen konnte, zutreffend sind, dann muss das eingegrenzt werden. Es wurde ja von der Kollegin Rößner vorhin ausgeführt, dass wir natürlich auch bei der Schufa die Einhaltung der Regeln immer wieder überprüfen müssen.
# Vielleicht noch was dazu: Die Chancen einer positiven Schufa-Auskunft sind natürlich mindestens genauso groß wie die Risiken oder Probleme, die ein Vertragsanbahnungsinteressent bei einer negativen Auskunft hat. Deshalb lassen Sie uns bitte beide Seiten der Medaille sehen, nämlich auch die Möglichkeit, mit einer positiven Schufa-Auskunft die Basis für eine vertrauensvolle Vertragsanbahnung zu schaffen. Das vermisse ich in Ihrem Antrag komplett. Das heißt, Sie schütten das Kind wieder mit dem Bade aus, und das ist schade.
# Es ist, wie gesagt, legitim, dass beide Vertragsparteien Informationen über die jeweils andere Seite einholen und sich informieren, um zu wissen, dass der Vertrag tatsächlich erfüllt werden kann. Es ist tatsächlich so, dass viele wirtschaftlich nicht so begüterte Verbraucher – Mietinteressenten, Kaufinteressenten, Verbraucher, die ein Handy kaufen, einen Handyvertrag oder einen Stromliefervertrag abschließen wollen – davon auch profitieren. Es gibt zwei Möglichkeiten: Der Vertragspartner kann sich durch eine Bankbürgschaft absichern. Die Bankbürgschaft kostet aber Geld. Oder ich kann sagen: Okay, ich lege eine Selbstauskunft der Schufa vor. Ich habe bisher immer meine Rechnungen ordentlich bezahlt.
# – Nein, das ist jetzt in Anführungszeichen, Herr Kollege Birkwald. – Du kannst mit gutem Gewissen einen Vertrag mit mir eingehen.
# Die Chancen für die Verbraucher verkennen Sie in Ihrem Antrag. Mit der Abschaffung der Schufa würden Sie die Situation für die Verbraucher keineswegs verbessern, sondern verbösern. Deshalb wird es Sie nicht wundern: Wir werden den Antrag ablehnen.
#
# Predicted Speech:
# ===================
# #Regulierung von Bonitätsauskünften#
#
# Herr Präsident, verehrtes Haus,
#
# Heute, im Namen der Union, möchte ich mich für die Regulierung von Bonitätsauskünften einsetzen. Die Bonitätsauskünfte sind ein wichtiger Bestandteil des Kreditmarktes und tragen wesentlich zur Finanzierung von Unternehmen und Privatpersonen bei. Sie ermöglichen es Kreditinstituten, die Bonität eines Kreditnehmers zu bewerten und die Risiken zu bewerten, die mit der Kreditvergabe verbunden sind.
#
# Wir müssen jedoch die Bonitätsauskünfte regeln, um sicherzustellen, dass sie fair und transparent sind. Die Union ist der Überzeugung, dass die Regulierung von Bonitätsauskünften dazu beitragen kann, die Kreditvergabe zu verbessern, die Kreditmarkttransparenz zu erhöhen und die Risiken für Kreditinstitute und Kreditnehmer zu verringern.
#
# Herr Präsident, die Bonitätsauskünfte sind ein komplexes Thema, und wir müssen sicherstellen, dass wir die richtigen Maßnahmen ergreifen, um die Interessen von Kreditinstituten und Kreditnehmern zu schützen. Die Union schlägt folgende Maßnahmen zur Regulierung von Bonitätsauskünften vor:
#
# 1. Transparenz: Wir müssen sicherstellen, dass die Bonitätsauskünfte transparent sind und die Kreditnehmer über die Informationen informiert sind, die für die Bewertung ihrer Bonität verwendet werden. Dies wird dazu beitragen, die Kreditmarkttransparenz zu erhöhen und die Kreditnehmer vor unangemessenen Kreditvergaben zu schützen.
# 2. Standardisierung: Wir müssen sicherstellen, dass die Bonitätsauskünfte standardisiert sind, um eine fairere Bewertung der Bonität der Kreditnehmer zu ermöglichen. Dies wird dazu beitragen, die Kreditmarkttransparenz zu erhöhen und die Kreditnehmer vor unangemessenen Kreditvergaben zu schützen.
# 3. Regelmäßige Überprüfung: Wir müssen sicherstellen, dass die Bonitätsauskünfte regelmäßig überprüft werden, um sicherzustellen, dass sie den aktuellen Marktbedingungen entsprechen. Dies wird dazu beitragen, die Kreditmarkttransparenz zu erhöhen und die Kreditnehmer vor unangemessenen Kreditvergaben zu schützen.
# 4. Anpassung an die Marktentwicklung: Wir müssen sicherstellen, dass die Bonitätsauskünfte an die Marktentwicklung angepasst werden, um sicherzustellen, dass sie den aktuellen Marktbedingungen entsprechen. Dies wird dazu beitragen, die Kreditmarkttransparenz zu erhöhen und die Kreditnehmer vor unangemessenen Kreditvergaben zu schützen.
# 5. Strafen für unangemessene Bonitätsauskünfte: Wir müssen sicherstellen, dass Kreditinstitute, die unangemessene Bonitätsauskünfte verbreiten, strafbar gemacht werden. Dies wird dazu beitragen, die Kreditmarkttransparenz zu erhöhen und die Kreditnehmer vor unangemessenen Kreditvergaben zu schützen.
#
# Herr Präsident, die Union ist der Überzeugung, dass die Regulierung von Bonitätsauskünften dazu beitragen kann, die Kreditvergabe zu verbessern, die Kreditmarkttransparenz zu erhöhen und die Risiken für Kreditinstitute und Kreditnehmer zu verringern. Wir bitten das Haus, diese Vorschläge zu berücksichtigen und die Regulierung von Bonitätsauskünften zu unterstützen.
#
# Dieser Vorschlag ist ein wichtiger Schritt in Richtung einer stabilen und transparenten Finanzmärkteinrichtung. Wir müssen zusammenarbeiten, um die Bonitätsauskünfte zu regulieren und sicherzustellen, dass die Kreditmarkttransparenz erhöht und die Risiken für Kreditinstitute und Kreditnehmer verringert werden.
#
# Herr Präsident, ich danke Ihnen für die Gelegenheit, diesen wichtigen Vorschlag vorzubringen. Wir bitten das Haus, diesen Vorschlag zu berücksichtigen und die Regulierung von Bonitätsauskünften zu unterstützen.
#
# Dieser Vorschlag ist ein wichtiger Schritt in Richtung einer stabilen und transparenten Finanzmärkteinrichtung. Wir müssen zusammenarbeiten, um die Bonitätsauskünfte zu regulieren und sicherzustellen, dass die Kreditmarkttransparenz erhöht und die Risiken für Kreditinstitute und Kreditnehmer verringert werden.
#
# Herr Präsident, ich danke Ihnen für die Gelegenheit, diesen wichtigen Vorschlag vorzubringen. Wir bitten das Haus, diesen Vorschlag zu berücksichtigen und die Regulierung von Bonitätsauskünften zu unterstützen.
#
# Dieser Vorschlag ist ein wichtiger Schritt in Richtung einer stabilen und transparenten Finanzmärkteinrichtung. Wir müssen zusammenarbeiten, um die Bonitätsauskünfte zu regulieren und sicherzustellen, dass die Kreditmarkttransparenz erhöht und die Risiken für Kreditinstitute und Kreditnehmer verringert werden.
#
# Herr Präsident, ich danke Ihnen für die Gelegenheit, diesen wichtigen Vorschlag vorzubringen. Wir bitten das Haus, diesen Vorschlag zu berücksichtigen und die Regulierung von Bonitätsauskünften zu unterstützen.
#
# Dieser Vorschlag ist ein wichtiger Schritt in Richtung einer stabilen und transparenten Finanzmärkteinrichtung. Wir müssen zusammenarbeiten, um die Bonitätsauskünfte zu regulieren und sicherzustellen, dass die Kreditmarkttransparenz erhöht und die Risiken für Kreditinstitute und Kreditnehmer verringert werden.
#
# Herr Präsident, ich danke Ihnen für die Gelegenheit, diesen wichtigen Vorschlag vorzubringen. Wir bitten das Haus, diesen Vorschlag zu berücksichtigen und die Regulierung von Bonitätsauskünften zu unterstützen.
#
# Dieser Vorschlag ist ein wichtiger Schritt in Richtung einer stabilen und transparenten Finanzmärkteinrichtung. Wir müssen zusammenarbeiten, um die Bonitätsauskünfte zu regulieren und sicherzustellen, dass die Kreditmarkttransparenz erhöht und die Risiken für Kreditinstitute und Kreditnehmer verringert werden.
#
# Herr Präsident, ich danke Ihnen für die Gelegenheit, diesen wichtigen Vorschlag vorzubringen. Wir bitten das Haus, diesen Vorschlag zu berücksichtigen und die Regulierung von Bonitätsauskünften zu unterstützen.
#
# Dieser Vorschlag ist ein wichtiger Schritt in Richtung einer stabilen und transparenten Finanzmärkteinrichtung. Wir müssen zusammenarbeiten, um die Bonitätsauskünfte zu regulieren und sicherzustellen, dass die Kreditmarkttransparenz erhöht und die Risiken für Kreditinstitute und Kreditnehmer verringert werden.
#
# Herr Präsident, ich danke Ihnen für die Gelegenheit, diesen wichtigen Vorschlag vorzubringen. Wir bitten das Haus, diesen Vorschlag zu berücksichtigen und die Regulierung von Bonitätsauskünften zu unterstützen.
#
# Dieser Vorschlag ist ein wichtiger Schritt in Richtung einer stabilen und transparenten Finanzmärkteinrichtung. Wir müssen zusammenarbeiten, um die Bonitätsauskünfte zu regulieren und sicherzustellen, dass die Kreditmarkttransparenz erhöht und die Risiken für Kreditinstitute und Kreditnehmer verringert werden.
#
# Herr Präsident, ich danke Ihnen für die Gelegenheit, diesen wichtigen Vorschlag vorzubringen. Wir bitten das Haus, diesen Vorschlag zu berücksichtigen und die Regulierung von Bonitätsauskünften zu unterstützen.
#
# Dieser Vorschlag ist ein wichtiger Schritt in Richtung einer stabilen und transparenten Finanzmärkteinrichtung. Wir müssen zusammenarbeiten, um die Bonitätsauskünfte zu regulieren und sicherzustellen, dass die Kreditmarkttranspar
#
# ===================
# === SPD ===
# Agenda Item: Bildung und Forschung für geflüchtete Ukrainer
# ===================
#  True Speech:
# ===================
# Sehr verehrter Herr Präsident! Meine Damen und Herren! Über 1 Million Menschen sind inzwischen aus der Ukraine nach Deutschland geflohen. Der Krieg hat ihnen nicht nur die Heimat genommen, er hat ihnen auch die Gewissheit genommen, die das Lernen in vertrauten Räumen und in der vertrauten Sprache bietet. Deswegen ist es wichtig, dass wir heute besonders über die Solidarität mit Schülerinnen und Schülern, mit Studentinnen und Studenten sprechen. Sie haben unsere Unterstützung, um ihren Bildungsweg in Deutschland fortzusetzen.
# Dabei sind nicht nur Ukrainerinnen und Ukrainer geflohen; auch viele Drittstaatsangehörige, wie wir heute schon gehört haben, hatte es zum Studium an ukrainische Hochschulen gezogen. Auch sie wurden durch denselben Krieg vertrieben, auch nach Deutschland. Ich habe in den letzten Monaten immer wieder mit diesen Studierenden gesprochen, zuletzt am Samstag mit einigen jungen Menschen zum Beispiel aus Somalia. Für sie war die Ukraine der Ort, mit dem sie die Hoffnung verbunden haben, Ärztin oder Zahnarzt zu werden. Der russische Angriffskrieg hat diese Hoffnung zerstört.
# Von Anfang an war klar, dass Deutschland für flüchtende Menschen aus der Ukraine offensteht, unabhängig vom Pass. Auch Drittstaatsangehörige durften für 90 Tage ohne Visum hier sein, waren also sicher. Aber wer sein Zuhause verliert, braucht nicht nur kurzfristigen Schutz, sondern einen Ort mit Bleibeperspektive. Deshalb bin ich dankbar, dass Deutschland sich dafür eingesetzt hat, dass auch Menschen aus Drittstaaten den europaweit einheitlichen temporären Schutz genießen, zumindest wenn sie nicht sicher und dauerhaft in ihr Herkunftsland zurückkehren können. Ich bin auch dankbar, dass Bundesinnenministerin Nancy Faeser schnell klargestellt hat, dass Menschen mit einem dauerhaften Aufenthaltstitel in der Ukraine natürlich mehr Verbindung zur Ukraine haben als zu ihrem Geburtsland. Sie werden daher mit Ukrainerinnen und Ukrainern gleichgestellt, und das ist eine gute Sache.
# Wir wissen aber auch, dass einige Bundesländer weiter vorausgehen. Wir haben beispielsweise Berlin, Hamburg und Bremen, die diesen Drittstaatsangehörigen eine Fiktionsbescheinigung für sechs Monate ausgestellt haben. Ich glaube, das ist eine gute Lösung. Ich habe aber auch vor einigen Stunden aus Augsburg, aus Bayern, eine Nachricht erhalten von einem Studierenden, der in Augsburg eigentlich schon anfangen sollte, zu studieren. Er soll aber jetzt im Dezember abgeschoben werden. Das sind Schicksale, die vor dem Hintergrund des Fachkräftemangels natürlich absolut irrsinnig sind. Ich bin froh darüber, dass wir mit diesem Antrag ein klares Zeichen dafür setzen, dass wir auf Bundesebene eine einheitliche Lösung suchen.
#
# Predicted Speech:
# ===================
# #Bildung und Forschung für geflüchtete Ukrainer#
#
# Herr Präsident,
#
# ich stehe heute hier, um über ein Thema zu sprechen, das für uns alle von großer Bedeutung ist: Bildung und Forschung für geflüchtete Ukrainer. Als sozialdemokratische Fraktion sind wir immer wieder auf die Notwendigkeit hingewiesen worden, die Rechte und Chancen von Menschen, die vor Gewalt und Unterdrückung geflohen sind, zu schützen und zu fördern.
#
# Wir kennen die Geschichte der Ukraine, und wir kennen die Leiden, die die Menschen dort erdulden müssen. Wir haben die traurigen Folgen des Krieges in der Ostukraine und die Verletzungen, die durch die russische Aggression verursacht wurden, gesehen. Wir haben die Flüchtlinge und Migranten begrüßt, die hierher gekommen sind, um ein neues Leben zu suchen, und wir haben uns bemüht, ihnen eine sichere und unterstützende Umgebung zu bieten.
#
# Doch wir wissen auch, dass die Flüchtlingssituation nicht nur eine humanitäre Angelegenheit ist, sondern auch eine Frage der langfristigen Entwicklung und des Wohlstands für diese Menschen und für unser Land. Daher müssen wir unsere Bemühungen nicht auf die kurzfristige Unterbringung und Versorgung konzentrieren, sondern auch auf die Bildung und Forschung für geflüchtete Ukrainer.
#
# Wir müssen anerkennen, dass Bildung und Forschung die Schlüssel zu einem erfolgreichen Leben sind. Sie ermöglichen es den Menschen, ihre Fähigkeiten zu entwickeln, sich anzupassen und sich an die neue Umgebung anzupassen. Sie helfen ihnen, sich in der Gesellschaft zu integrieren und ihre Rechte und Freiheiten zu wahren.
#
# Daher müssen wir unsere Bemühungen auf die Bereitstellung von Bildungsmöglichkeiten für geflüchtete Ukrainer konzentrieren. Wir müssen sicherstellen, dass diese Menschen Zugang zu qualitativ hochwertiger Bildung haben, sowohl in der Grund- als auch in der weiterführenden Bildung. Wir müssen unsere Bildungssysteme anpassen, um die spezifischen Bedürfnisse und Herausforderungen dieser Menschen zu berücksichtigen.
#
# Darüber hinaus müssen wir unsere Forschungspolitik anpassen, um die Bedürfnisse und Interessen geflüchteter Ukrainer zu berücksichtigen. Wir müssen unsere Forschungslandschaft anpassen, um die spezifischen Herausforderungen und Chancen in der Ukraine zu berücksichtigen. Wir müssen unsere Forschungsinvestitionen auf die Bereitstellung von Lösungen für die Herausforderungen konzentrieren, mit denen diese Menschen konfrontiert sind.
#
# Wir müssen auch die Zusammenarbeit zwischen Regierungsinstitutionen, Bildungseinrichtungen und NGOs fördern, um die Bereitstellung von Bildungsmöglichkeiten und Forschungschancen für geflüchtete Ukrainer zu gewährleisten. Wir müssen die Ressourcen und Expertise dieser Organisationen nutzen, um die Bedürfnisse dieser Menschen zu erfüllen.
#
# Schließlich müssen wir unsere Bemühungen nicht auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer beschränken. Wir müssen uns auch auf die Integration dieser Menschen in unser Gesellschaft konzentrieren. Wir müssen unsere Gesellschaft anpassen, um die Vielfalt und die Fähigkeiten dieser Menschen zu schätzen. Wir müssen unsere Gesellschaft anpassen, um die Rechte und Freiheiten dieser Menschen zu schützen und zu fördern.
#
# Daher müssen wir unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren. Wir müssen unsere Gesellschaft anpassen, um die Bedürfnisse und Herausforderungen dieser Menschen zu berücksichtigen. Wir müssen unsere Gesellschaft anpassen, um die Rechte und Freiheiten dieser Menschen zu schützen und zu fördern.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Eng
#
# ===================
# === GRÜNE ===
# Agenda Item: Verteidigungspolitik, Einsatzbereitschaft Bundeswehr
# ===================
#  True Speech:
# ===================
# Sehr geehrte Frau Präsidentin! Sehr geehrter Herr Minister! Sehr geehrte Kolleginnen und Kollegen! Sehr geehrte Zuschauer und Zuschauerinnen! Da ist es also, das Artikelgesetz „Zeitenwende“ – lang angekündigt und zweifellos von gravierender Bedeutung für die sogenannte Zeitenwende.
# Und doch: Trotz dieser immer wieder betonten Relevanz wird heute nicht nur über dieses Gesetz debattiert. Verstehen Sie mich bitte nicht falsch; denn alle drei Gesetzentwürfe verdienen eine ausführliche, differenzierte Diskussion in diesem Hohen Haus. Deshalb hätten meiner Meinung nach alle drei separate Tagesordnungspunkte verdient, um deren Tragweite gerecht zu werden.
# Mit einem gewissen Frust nehme ich zur Kenntnis, dass von vielen hier im Haus, auch auf der Regierungsbank, aktuell das Narrativ verbreitet wird: Die Union blockiert das Artikelgesetz.
# Meine Damen und Herren, das ist schlichtweg falsch, und das irritiert auch unsere Verbündeten, besonders in Litauen.
# Wir nehmen unsere politische Verantwortung sehr ernst. Wir werden konstruktiv und ergebnisoffen mit Ihnen verhandeln. Aber, liebe Kollegen, vergessen Sie nicht: Wir sind nicht der Notnagel für Ihre verlorengegangene Mehrheit in diesem Haus.
# Deswegen: Unterlassen Sie das Verbreiten solcher Narrative! Denn sie sind falsch.
# Und billige wahlkampftaktische Manöver sind angesichts der derzeitigen Lage mehr als unangebracht.
# Damit mir nicht dasselbe vorgeworfen wird, ist es mir ein Anliegen, zu betonen, dass der Gesetzentwurf viele wichtige Punkte aufgreift. Umzüge und Rückumzugsentscheidungen von Bundeswehrangehörigen und deren Familien werden vereinfacht. Durch eine Alarmierungsvergütung werden die besonderen Einschränkungen von Bundeswehrsoldaten mit kurzen Alarmierungszeiten honoriert. Zusätzliche Stellenzulagen werden geschaffen. Die Möglichkeiten für die Auszahlung einer Einmalentschädigung nach dem Erleiden eines Dienstunfalles werden ausgeweitet. Das Arbeitssicherstellungsgesetz wird angepasst, um in Krisen die Versorgung der Bundeswehr und den Schutz der Zivilbevölkerung gewährleisten zu können.
# Aber es gibt eben auch noch viele offene Punkte, die hier im Parlament, im Verteidigungsausschuss und in der öffentlichen Anhörung diskutiert werden müssen. Ein zentrales Beispiel hierfür ist die fortbestehende Ungleichbehandlung von Soldaten auf Zeit und Berufssoldaten, insbesondere im Fall einer Wehrdienstbeschädigung, die zur Dienstunfähigkeit führt. Auch eine Öffnung des Einsatz-Weiterverwendungsgesetzes für Soldaten auf Zeit, die im Inland verletzt wurden, muss ergebnisoffen diskutiert werden. Die Erweiterung der Einsatzentschädigung auf Unfälle im Inland und Übungen geht uns hier nicht weit genug.
# Ein anderes Beispiel ist die weiterhin bestehende Hinzuverdienstgrenze für ehemalige Soldaten. Hier herrschte, als wir den Antrag der CDU/CSU im Plenum debattiert haben, eigentlich große Einigkeit zwischen den demokratischen Fraktionen dieses Hauses. Auch in verschiedenen Versionen des Referentenentwurfes für dieses Artikelgesetz wurde die Abschaffung der Hinzuverdienstgrenze aufgenommen, bevor dies dann ohne ersichtliche Erklärung wieder gestrichen wurde.
# Meine Güte! Die Schwelle zur Lächerlichkeit ist hier schon lange überschritten worden. Die öffentlichen Haushalte sind schwer belastet. Und wir halten hochqualifiziertes Personal davon ab, weiterzuarbeiten und weiter Geld in die Rentenversicherung einzuzahlen? Wer noch ernsthaft glaubt, dass wir als Staat es uns erlauben können, Leute vom Arbeiten abzuhalten oder sogar dafür zu bestrafen, der hat doch echt den Knall nicht gehört.
# Und das, geschätzte Kollegen, sind nur drei Punkte, bei denen noch erheblicher Diskussionsbedarf besteht. Es gibt angesichts der Tragweite dieses Gesetzes noch viele weitere Punkte, welche wir im Rahmen der parlamentarischen Befassung noch mal kritisch prüfen sollten und auch werden. Denn dieses Gesetzesvorhaben verdient und erfordert unsere kritische Auseinandersetzung; mir sind die Belange unserer Soldatinnen und Soldaten sowie unserer Verbündeten viel zu wichtig.
# Deswegen werden wir mit Ihnen ergebnisoffen verhandeln. Aber wir werden es nicht hinnehmen, dass wir als CDU/CSU-Fraktion hier von Ihnen vor vollendete Tatsachen gestellt werden.
# Deshalb freue ich mich auf die öffentliche Anhörung zu dem Artikelgesetz am 16. Dezember.
# Herzlichen Dank.
#
# Predicted Speech:
# ===================
# #Verteidigungspolitik, Einsatzbereitschaft Bundeswehr#
#
# Herr Präsident,
#
# heute möchte ich über eine Thematik sprechen, die für unsere Gesellschaft von entscheidender Bedeutung ist: die Verteidigungspolitik und die Einsatzbereitschaft der Bundeswehr.
#
# Wir leben in einer Welt, die von Unsicherheit und Herausforderungen geprägt ist. Von den Konflikten in der Ukraine bis hin zu den Spannungen im Nahen Osten und den Klimawandel sind wir vor vielen Herausforderungen konfrontiert. Deshalb ist es unerlässlich, dass wir unsere Verteidigungspolitik neu positionieren und unsere Bundeswehr auf die Herausforderungen der Zukunft vorbereiten.
#
# Die Grünen haben immer eine starke Verteidigungspolitik vertreten. Wir glauben, dass eine starke Verteidigungspolitik nicht nur für die Sicherheit unseres Landes, sondern auch für die Stabilität der Welt notwendig ist. Wir müssen unsere Bundeswehr stärken und ihre Einsatzbereitschaft verbessern, um unsere Interessen und Werte zu schützen.
#
# Um dies zu erreichen, müssen wir unseren Verteidigungsausgaben erhöhen. Die Bundeswehr ist in den letzten Jahren unterfinanziert und unterausgerüstet gewesen. Wir müssen unseren Verteidigungsbudget erhöhen, um die Bundeswehr auf dem neuesten Stand zu halten und ihre Einsatzbereitschaft zu verbessern.
#
# Außerdem müssen wir unsere Verteidigungspolitik neu positionieren. Wir müssen unsere Bündnisse und Abkommen überprüfen und neu positionieren, um sicherzustellen, dass wir unsere Interessen und Werte effektiv schützen können. Wir müssen auch unsere Verteidigungsstrategie überdenken und unsere Bundeswehr auf die Herausforderungen der Zukunft vorbereiten.
#
# Die Bundeswehr muss auch in der Lage sein, sich an internationalen Missionen und Kampfeinsätzen zu beteiligen. Wir müssen unsere Bundeswehr stärken und ihre Einsatzbereitschaft verbessern, um unsere Interessen und Werte zu schützen.
#
# Aber unsere Verteidigungspolitik muss nicht nur auf militärische Macht ausgerichtet sein. Wir müssen auch unseren Fokus auf die Ursachen der Konflikte und des Widerstands legen. Wir müssen unsere Entwicklungs- und Friedenspolitik stärken, um die Ursachen von Konflikten anzugehen und die Stabilität der Welt zu fördern.
#
# In diesem Zusammenhang müssen wir auch unsere Zusammenarbeit mit anderen Ländern und Organisationen stärken. Wir müssen unsere Bündnisse und Abkommen überprüfen und neu positionieren, um sicherzustellen, dass wir unsere Interessen und Werte effektiv schützen können.
#
# Zusammenfassend müssen wir unsere Verteidigungspolitik neu positionieren und unsere Bundeswehr auf die Herausforderungen der Zukunft vorbereiten. Wir müssen unseren Verteidigungsausgaben erhöhen, unsere Verteidigungspolitik neu positionieren und unsere Bundeswehr stärken und ihre Einsatzbereitschaft verbessern. Wir müssen unsere Entwicklungs- und Friedenspolitik stärken und unsere Zusammenarbeit mit anderen Ländern und Organisationen stärken.
#
# Dies ist unser Ziel, und wir werden unser Bestes geben, um es zu erreichen. Dankbar für die Gelegenheit, zu sprechen.
#
# Herr Präsident, ich bitte um die Beantwortung der Frage.
#
# ===================
# === FDP ===
# Agenda Item: Aktuelle Stunde zur Eskalation in der Golfregion
# ===================
#  True Speech:
# ===================
# Sehr geehrter Herr Präsident! Meine sehr geehrten Damen und Herren! Verehrte Kolleginnen und Kollegen! In der Großraumregion Golf haben wir es mit einer zugespitzten, gefährlichen Situation zu tun. Ich nenne nur die Situation im Jemen, den Stellvertreterkrieg, der mit Brutalität und vielen Zehntausenden von Opfern in der Zivilbevölkerung geführt wird. Ich nenne die Angriffe und die Festsetzung von Schiffen in der Straße von Hormus durch iranische Revolutionsgarden. Als vorläufig letzten Akt der Eskalation nenne ich den Anschlag mit Drohnen und Marschflugkörpern in Saudi-Arabien auf eine der größten Ölraffinerien der Welt. Dieser Anschlag auf die zivile Infrastruktur war auch ein Anschlag auf die Energieversorgung der Welt. Deswegen ist es richtig, ihn aufs Schärfste zu verurteilen. Es kann als gesichert angesehen werden, dass letztlich die Verantwortung, mindestens aber die politische Verantwortung, der Iran trägt. Deshalb ist es richtig, dass die E3, also Deutschland gemeinsam mit den Regierungen von Großbritannien und Frankreich, in diesem Sinne Stellung bezogen haben.
# Man kann es fast schon als gelassen bezeichnen, wie Saudi-Arabien reagiert hat. Das ist positiv zu bewerten: Es hat nicht mit hitziger Rhetorik oder gar mit Übersprungreaktionen oder Vergeltungshandlungen geantwortet. Damit hat es – auch wenn dem Kollegen Trittin dieses Wort nicht gefällt – deeskalierend gewirkt. Gleichwohl ist nach wie vor nur ein kleiner Funke erforderlich, damit diese Spannungslage in der Golfregion eine militärische Dimension erfährt. Das ist alles noch sehr präsent.
# In diesem Zusammenhang stellt sich die Frage: Welche Rolle spielen die Vereinigten Staaten? Ich möchte den Blick auch auf die Zeit vor Donald Trump richten, auf die Zeit der Obama-Administration. Schon damals wurde beklagt, dass sich die USA unter Obama allenthalben als Weltpolizist zurückgezogen haben. Die USA wurden in der Rolle des Weltpolizisten zwar nicht geliebt, aber sie haben nach ihrem Rückzug ein Vakuum hinterlassen, das uns auch nicht gefallen kann, weil jetzt andere Mächte ihren Einfluss in dieser Region auszuweiten versuchen. Und dann kam Donald Trump. Er ist mit dem Wahlversprechen angetreten: Ich möchte die Amerikaner nicht in neue Kriege und Konflikte verwickeln. Im Gegenteil, ich werde unsere Truppen aus Afghanistan und Syrien schnell abziehen. – Gott sei Dank, möchte ich fast sagen, hat er hiervon Abstand genommen und eine Rolle rückwärts gemacht. Aber auch das schafft natürlich Verunsicherung.
# In der angesichts der verschiedenen Interessen in diesen Kriegen und Konflikten kaum noch zu überschauenden Gemengelage muss sich Deutschland nicht nur zurechtfinden, sondern auch Position beziehen. Deutschland muss sich über seine eigenen Interessen klar werden. Es muss seine Interessen definieren und entlang dieser Linien politische Entscheidungen treffen und diese sodann in konkretes Handeln umsetzen.
# Ich will das am Beispiel der Straße von Hormus, die ich eingangs kurz erwähnt hatte, klarmachen: Mit dem, was durch die Straße von Hormus transportiert wird, wird ein Fünftel des Ölhungers der Welt befriedigt. Auch deutsche Handelsschiffe passieren diese Meerenge. Das heißt, wir haben eigene Interessen, die es dort zu schützen gilt. Deswegen ist es richtig, dass wir uns darum bemühen, eine solide rechtliche Grundlage zu finden. Ideal wäre ein UN-Mandat. Das ist aber wegen der bekannten Position einiger Vetomächte unrealistisch. Das heißt, ein EU-Mandat könnte dafür herhalten. Gespräche, in denen man sich darüber abstimmt, wie das bewerkstelligt werden kann, finden bereits statt. Das ist nicht trivial. Ich glaube, es ist richtig, zu erkennen, dass wir schützenswerte eigene Interessen haben. Wir dürfen uns aber auch nicht selbst in eine Falle manövrieren, indem wir sagen: Ein Land geht mit ein oder zwei Schiffen in die Region, es geht vorweg und sendet eine Einladung an die anderen EU-Staaten aus, die dann folgen können. Nein, hier muss es eine Art Koalition der Willigen innerhalb der EU geben. Das ist ein richtiger Ansatz, meine Damen und Herren. Hier sollte Deutschland eine führende Rolle einnehmen.
# Im Übrigen sehe ich mit Blick auf das JCPoA durchaus eine Chance, dass die Vereinigten Staaten wieder mit ins Boot geholt werden. Immerhin wurden bis zur Aufkündigung des Abkommens durch die Vereinigten Staaten im Mai letzten Jahres mit den USA Gespräche über eine regionale und inhaltliche Ausweitung des Anwendungsgebiets des JCPoA geführt. Es gilt, an diese Gespräche anzuknüpfen und diesen Weg weiter zu beschreiten. Mit Blick auf die Ausführungen des Kollegen Trittin möchte ich mit Ihrer Genehmigung, Herr Präsident, zwei Schlusssätze sagen: Es ist schlimm genug, dass es überhaupt eines Atomabkommens bedurfte.
# Natürlich wäre es schöner gewesen, wenn wir das gar nicht erst über zwölf Jahre hinweg hätten verhandeln müssen, um die Aggressionen des Iran einzudämmen.
# Herr Kollege, kommen Sie bitte zum Schluss.
# Ich komme zum Schluss, Herr Präsident. – Zu Ihrer Bemerkung zu den Bemühungen der Bundesregierung, legale wirtschaftliche Beziehungen mit dem Iran zu tätigen, sage ich: Die Bundesregierung hat sich als Speerspitze für das Instrumentarium INSTEX eingesetzt.
# Herr Kollege, bitte, Sie haben jetzt Ihre Redezeit um 40 Sekunden überzogen.
# Ich komme zum Schluss. Danke, Herr Präsident. – Die Europäische Union ist auf einem guten Weg, eine abgestimmte Position zu finden.
#
# Predicted Speech:
# ===================
# #Halte 1#
#
# Herr Präsident, verehrtes Haus,
#
# Heute spreche ich über eine Angelegenheit, die uns alle beunruhigt und uns alle in Betracht zieht: die aktuelle Eskalation in der Golfregion. Die Spannungen zwischen den USA, Iran und Saudi-Arabien haben sich in den letzten Wochen zu einer gefährlichen Krise eskaliert.
#
# Die FDP betont die Bedeutung einer vorsichtigen und diplomatischen Lösung dieser Krise. Wir müssen unsere Beziehungen zu allen beteiligten Parteien pflegen und die Gefahr von Konfrontation vermeiden. Die FDP setzt sich für eine politische Lösung ein, die den Frieden und die Stabilität in der Region gewährleistet.
#
# Die FDP betont die Bedeutung der internationalen Zusammenarbeit und der Einhaltung des Völkerrechts. Wir müssen die Rolle der Vereinten Nationen und anderer multilateraler Organisationen nutzen, um eine friedliche Lösung zu fördern. Die FDP setzt sich für eine umfassende und transparente Untersuchung der Ursachen der Krise ein und fordert die Beteiligten auf, die internationale Gemeinschaft über ihre Handlungen auf dem Laufenden zu halten.
#
# Die FDP betont die Bedeutung der Menschenrechte und der menschlichen Sicherheit in der Golfregion. Wir müssen unsere Bemühungen um eine friedliche Lösung der Krise mit den Grundwerten der Menschenrechte und der menschlichen Sicherheit verbinden. Die FDP setzt sich für die Sicherheit und den Schutz der Zivilbevölkerung ein und fordert die Beteiligten auf, alle Maßnahmen zu vermeiden, die zu unnötiger Gewalt oder Zivilschäden führen könnten.
#
# Die FDP betont die Bedeutung der Wirtschafts- und Handelsbeziehungen zwischen den Ländern der Golfregion und der Welt. Wir müssen unsere wirtschaftlichen Interessen und die wirtschaftliche Stabilität der Region schützen. Die FDP setzt sich für die Förderung von Handels- und Investitionsbeziehungen ein und fordert die Beteiligten auf, die wirtschaftliche Entwicklung und den wirtschaftlichen Fortschritt in der Region zu unterstützen.
#
# Die FDP betont die Bedeutung der Umwelt- und Klimaschutzbemühungen in der Golfregion. Wir müssen unsere Bemühungen um eine friedliche Lösung der Krise mit den Umwelt- und Klimaschutzbemühungen verbinden. Die FDP setzt sich für die Förderung von Umwelt- und Klimaschutzmaßnahmen ein und fordert die Beteiligten auf, ihre Verantwortung für die Umwelt und die Zukunft der Menschheit zu erfüllen.
#
# Die FDP betont die Bedeutung der politischen Stabilität und der nationalen Sicherheit in der Golfregion. Wir müssen unsere Bemühungen um eine friedliche Lösung der Krise mit der politischen Stabilität und der nationalen Sicherheit verbinden. Die FDP setzt sich für die Förderung von politischer Stabilität und nationaler Sicherheit ein und fordert die Beteiligten auf, ihre Verantwortung für die politische Stabilität und die nationale Sicherheit in der Region zu erfüllen.
#
# Die FDP betont die Bedeutung der internationalen Zusammenarbeit und der Einhaltung des Völkerrechts. Wir müssen unsere Beziehungen zu allen beteiligten Parteien pflegen und die Gefahr von Konfrontation vermeiden. Die FDP setzt sich für eine politische Lösung ein, die den Frieden und die Stabilität in der Region gewährleistet.
#
# Die FDP betont die Bedeutung der Menschenrechte und der menschlichen Sicherheit in der Golfregion. Wir müssen unsere Bemühungen um eine friedliche Lösung der Krise mit den Grundwerten der Menschenrechte und der menschlichen Sicherheit verbinden. Die FDP setzt sich für die Sicherheit und den Schutz der Zivilbevölkerung ein und fordert die Beteiligten auf, alle Maßnahmen zu vermeiden, die zu unnötiger Gewalt oder Zivilschäden führen könnten.
#
# Die FDP betont die Bedeutung der Wirtschafts- und Handelsbeziehungen zwischen den Ländern der Golfregion und der Welt. Wir müssen unsere wirtschaftlichen Interessen und die wirtschaftliche Stabilität der Region schützen. Die FDP setzt sich für die Förderung von Handels- und Investitionsbeziehungen ein und fordert die Beteiligten auf, die wirtschaftliche Entwicklung und den wirtschaftlichen Fortschritt in der Region zu unterstützen.
#
# Die FDP betont die Bedeutung der Umwelt- und Klimaschutzbemühungen in der Golfregion. Wir müssen unsere Bemühungen um eine friedliche Lösung der Krise mit den Umwelt- und Klimaschutzbemühungen verbinden. Die FDP setzt sich für die Förderung von Umwelt- und Klimaschutzmaßnahmen ein und fordert die Beteiligten auf, ihre Verantwortung für die Umwelt und die Zukunft der Menschheit zu erfüllen.
#
# Die FDP betont die Bedeutung der politischen Stabilität und der nationalen Sicherheit in der Golfregion. Wir müssen unsere Bemühungen um eine friedliche Lösung der Krise mit der politischen Stabilität und der nationalen Sicherheit verbinden. Die FDP setzt sich für die Förderung von politischer Stabilität und nationaler Sicherheit ein und fordert die Beteiligten auf, ihre Verantwortung für die politische Stabilität und die nationale Sicherheit in der Region zu erfüllen.
#
# Die FDP betont die Bedeutung der internationalen Zusammenarbeit und der Einhaltung des Völkerrechts. Wir müssen unsere Beziehungen zu allen beteiligten Parteien pflegen und die Gefahr von Konfrontation vermeiden. Die FDP setzt sich für eine politische Lösung ein, die den Frieden und die Stabilität in der Region gewährleistet.
#
# Die FDP betont die Bedeutung der Menschenrechte und der menschlichen Sicherheit in der Golfregion. Wir müssen unsere Bemühungen um eine friedliche Lösung der Krise mit den Grundwerten der Menschenrechte und der menschlichen Sicherheit verbinden. Die FDP setzt sich für die Sicherheit und den Schutz der Zivilbevölkerung ein und fordert die Beteiligten auf, alle Maßnahmen zu vermeiden, die zu unnötiger Gewalt oder Zivilschäden führen könnten.
#
# Die FDP betont die Bedeutung der Wirtschafts- und Handelsbeziehungen zwischen den Ländern der Golfregion und der Welt. Wir müssen unsere wirtschaftlichen Interessen und die wirtschaftliche Stabilität der Region schützen. Die FDP setzt sich für die Förderung von Handels- und Investitionsbeziehungen ein und fordert die Beteiligten auf, die wirtschaftliche Entwicklung und den wirtschaftlichen Fortschritt in der Region zu unterstützen.
#
# Die FDP betont die Bedeutung der Umwelt- und Klimaschutzbemühungen in der Golfregion. Wir müssen unsere Bemühungen um eine friedliche Lösung der Krise mit den Umwelt- und Klimaschutzbemühungen verbinden. Die FDP setzt sich für die Förderung von Umwelt- und Klimaschutzmaßnahmen ein und fordert die Beteiligten auf, ihre Verantwortung für die Umwelt und die Zukunft der Menschheit zu erfüllen.
#
# Die FDP betont die Bedeutung der politischen Stabilität und der nationalen Sicherheit in der Golfregion. Wir müssen unsere Bemühungen um eine friedliche Lösung der Krise mit der politischen Stabilität und der nationalen Sicherheit verbinden. Die FDP setzt sich für die Förderung von politischer Stabilität und nationaler Sicherheit ein und fordert die Beteiligten auf, ihre Verantwortung für die politische Stabilität und die nationale Sicherheit in der Region zu erfüllen.
#
# Die FDP betont die Bedeutung der internationalen Zusammenarbeit und der Einhaltung des Völkerrechts. Wir müssen unsere Beziehungen zu allen beteiligten Parteien pflegen und die Gefahr von Konfrontation vermeiden. Die FDP setzt sich für eine politische Lösung ein, die den Frieden und die Stabilität in der Region gewährle
#
# ===================
# === AfD ===
# Agenda Item: Kinderzukunftsprogramm
# ===================
#  True Speech:
# ===================
# Vielen Dank. – Frau Präsidentin! Frau Ministerin! Liebe Kolleginnen und Kollegen! Diese Bundesregierung hat eine Antwort auf die Kinderarmut gefunden. – Dieses Zitat vom 28. August 2023 stammt von der Ministerin. Heute, dreieinhalb Wochen später, gibt es noch immer keinen Kabinettsbeschluss, und es gibt auch noch immer keinen Entwurf hier im Parlament.
# Sicher ist jedoch, dass der Entwurf, so wie er uns vorliegt, keine Antwort auf die Kinderarmut gibt, dass er aber 500 Millionen Euro teure neue Verwaltungsaufgaben für die Bundesagentur für Arbeit und für die Länder mit sich bringt.
# Diese sogenannte Kindergrundsicherung als Antwort auf Kinderarmut zu bezeichnen, gleichzeitig aber einen Haushalt vorzulegen, der, ehrlich gesagt, überall dort, wo es für Kinder wichtig wäre, kürzt, das ist für uns grundlegend falsch – und offensichtlich nicht nur für uns. Die Kollegin Jensen von der FDP sagte gestern: Die Grundannahme der Kollegin, der Ministerin Lisa Paus, ist, dass ein pauschales Überweisen von mehr Geld auf das Konto der Familien Kinderarmut bekämpft, und der Überzeugung sind wir als Freie Demokraten so nicht.
# Wir als CDU/CSU sind das übrigens auch nicht.
# Deshalb bringen wir diesen Antrag mit zehn Maßnahmen zum Kinderzukunftsprogramm ein. Denn Bildung und soziale Infrastruktur verbunden mit zielgerichteten finanziellen Leistungen sind doch die Schlüssel für bessere Chancen, für eine bessere Zukunft von Kindern.
# Ich möchte zwei Punkte von zehn hervorheben; meine Kolleginnen und Kollegen werden auf die übrigen eingehen. Da ist zunächst die Stärkung der Frühen Hilfen: Das sind diese niedrigschwelligen Angebote, zum Beispiel über die Familienhebammen; jeder von Ihnen/von euch kennt es aus den eigenen Wahlkreisen: Der Bedarf wächst. Familien, werdende und junge Eltern früh zu unterstützen, ins Hilfesystem zu bringen, sie zu beraten und zu unterstützen, gute und starke Eltern sein zu können – diesen Bereich müssen wir in den Blick nehmen.
# Ich möchte auch noch ein paar Worte zu unserem Ansatz bei der finanziellen Unterstützung sagen. Wir wollen das Kindergeld erhalten. Das Kindergeld ist keine Sozialleistung.
# Das Kindergeld muss im Steuerrecht verankert bleiben mit dem Ziel, es auch weiterhin entsprechend der Anpassung des steuerlichen Kinderfreibetrages zu erhöhen. Wir sind ja ein bisschen bei Ihnen, wenn es darum geht, den Kinderzuschlag und den Teilhabebetrag zusammenzufassen, auch das Schulstarterpaket automatisch mit auszuzahlen. Aber im Gegensatz zu Ihnen wollen wir es an die Erwerbstätigkeit koppeln, und wir wollen vor allen Dingen in den vorhandenen Strukturen bleiben; denn 500 Millionen Euro für eine neue Verwaltungsstruktur, das ist bei diesem Haushalt für mich ein schlechter Witz. Stattdessen braucht es die konsequente Umsetzung des Onlinezugangsgesetzes und des Digitale-Familienleistungen-Gesetzes. All das, was Sie sagen, digitale und Onlinedatenabgleiche, wäre heute möglich, wenn Sie es umsetzen würden.
# In diesem Sinne freue ich mich auf die Beratungen.
# Vielen Dank.
#
# Predicted Speech:
# ===================
# #Hallo, meine Damen und Herren,
#
# heute möchte ich über ein Thema sprechen, das für uns alle von großer Bedeutung ist: die Kinderzukunftsprogramm. Als Abgeordnete der AfD möchte ich die Notwendigkeit betonen, dass wir unsere Kinder und die nächste Generation auf die Herausforderungen der Zukunft vorbereiten.
#
# Wir leben in einer Zeit, in der sich die Welt schnell verändert und wir uns mit den Folgen von Klimawandel, dem Rückgang der natürlichen Ressourcen und dem Wandel der Arbeitswelt konfrontiert sehen. Es ist unser Verantwortung, unsere Kinder auf diese Herausforderungen vorzubereiten und ihnen die notwendigen Fähigkeiten und Wissen zu vermitteln, um erfolgreich in dieser sich ständig verändernden Welt zu navigieren.
#
# Das Kinderzukunftsprogramm ist ein entscheidender Schritt in dieser Richtung. Es zielt darauf ab, die Bildungssysteme in Deutschland zu verbessern und sicherzustellen, dass unsere Kinder die Fähigkeiten und Fähigkeiten haben, um in einer sich ständig verändernden Welt erfolgreich zu sein.
#
# Das Programm umfasst mehrere Schlüsselbereiche, darunter:
#
# 1. Digitale Bildung: Wir müssen sicherstellen, dass unsere Kinder die notwendigen Fähigkeiten haben, um in der digitalen Welt erfolgreich zu sein. Dies beinhaltet die Förderung der Digitalen Kompetenz, die Förderung der Programmierkenntnisse und die Integration von Technologie in den Unterricht.
# 2. Umweltbildung: Wir müssen unsere Kinder auf die Herausforderungen des Klimawandels und der Umweltverschmutzung vorbereiten. Dies beinhaltet die Förderung der Umweltbildung, die Förderung von Nachhaltigkeit und die Förderung von Umweltbewusstsein.
# 3. Arbeitsmarktfähigkeiten: Wir müssen unsere Kinder auf die sich ständig verändernden Arbeitsmärkte vorbereiten. Dies beinhaltet die Förderung der beruflichen Bildung, die Förderung der Innovation und die Förderung der Fähigkeiten zur Anpassungsfähigkeit.
# 4. Soziale Kompetenz: Wir müssen unsere Kinder auf die Herausforderungen der globalen Zusammenarbeit und des interkulturellen Dialogs vorbereiten. Dies beinhaltet die Förderung der sozialen Kompetenz, die Förderung der Empathie und die Förderung der Fähigkeit zur Zusammenarbeit.
#
# Das Kinderzukunftsprogramm ist ein entscheidender Schritt in Richtung einer besseren Zukunft für unsere Kinder. Es ist unser Verantwortung, diese Initiative zu unterstützen und sicherzustellen, dass unsere Kinder die notwendigen Fähigkeiten und Wissen haben, um in einer sich ständig verändernden Welt erfolgreich zu sein.
#
# Ich bitte die Abgeordneten, dieses Programm zu unterstützen und sich für die Zukunft unserer Kinder einzusetzen.
#
# Vielen Dank.
#
# ===================
# === LINKE ===
# Agenda Item: Netzwerkdurchsetzungsgesetz
# ===================
#  True Speech:
# ===================
# Sehr geehrte Frau Präsidentin! Liebe Kolleginnen und Kollegen! Hass und Hetze im Netz kennen wir alle. Frauen bekommen sie mehr zu spüren als Männer; Menschen, die sich politisch engagieren, gerade auf der kommunalen Ebene, mehr als solche, die die Netzwerke nur in der Freizeit nutzen. Menschen mit Migrationshintergrund bekommen Hass und Hetze stärker zu spüren als Deutsche. Hass und Hetze im Netz – das ist ein Gift, das den demokratischen Diskurs zerstört; ein Gift, das den Austausch der Gedanken, Ideen und Meinungen behindert; ein Gift, das geeignet ist, die Grundfesten unserer freiheitlich-demokratischen Grundordnung anzugreifen.
# Wir wollen, dass man auch im Netz gut, in fairer Auseinandersetzung und sachlich diskutiert. Dafür müssen wir mehrere Voraussetzungen schaffen. Eine ist, dass die Gesellschaft, dass wir alle die Hauptverantwortung haben. Wir müssen gemeinsam dafür eintreten, dass wir eine gute Debatte im Netz haben. Das Wirksamste, wenn eine Diskussion bei Facebook oder Instagram ausartet, ist, dass sich Leute dagegenlehnen, dass sie sagen: „So geht es nicht, so kann man nicht diskutieren“; dass man mit Argumenten dagegenhält und auch ein klares Stoppschild zeigt. Dafür wurden in den letzten Jahren tolle Initiativen entwickelt: HateAid zum Beispiel macht einen tollen Job in der Beratung derjenigen, die von Hass und Hetze betroffen sind, oder auch die ganz neue Initiative „Stark im Amt“, die sich an Kommunalpolitiker richtet.
# Das Zweite ist, dass wir als Rechtsstaat Hass und Hetze nicht einfach hinnehmen dürfen. Deshalb haben wir 2017 das NetzDG auf den Weg gebracht, und ich kann dem Kollegen Müller nur zustimmen: Das ist ein Erfolgsmodell. Der Digital Services Act der Europäischen Kommission orientiert sich genau an unserem NetzDG,
# und mit den Änderungen, die wir heute auf den Weg bringen, verbessern wir noch mal die Verfahren, verbessern wir die Transparenz und auch die Meldewege, die es ermöglichen, dass der Einzelne sich tatsächlich beschweren kann, wenn seine Rechte verletzt wurden. Und: Für die Meinungsfreiheit stellen wir sicher, dass sich auch derjenige beschweren kann, der meint, dass ein Beitrag von ihm fälschlicherweise gelöscht worden ist.
# Das sind Maßnahmen, die zu einem sehr ausgewogenen Verhältnis zwischen all denjenigen beitragen, die sich im Netz bewegen. Sie bestimmen auch die Abstufungen im Rahmen der regulierten Selbstregulierung: dass die Plattform bei klaren Fällen nämlich schnell agieren muss, dass aber natürlich auch der Weg zu den Gerichten weiterhin offen ist. Das ist ein gutes, abgewogenes Verfahren, das auch international Maßstäbe setzt.
# Mir ist wichtig, dass wir mit diesen Änderungen heute auch den Forschern den Zugang zu den Daten ermöglichen; denn wir müssen wissen, was in den Netzwerken passiert, damit wir auch wirksame Maßnahmen ergreifen können, wenn Sachen aus dem Ruder laufen. Das tun wir mit diesem Gesetz. Das werden wir in Zukunft weiter tun und beobachten. Mit diesem Gesetz legen wir die Grundlagen dafür. Deshalb ein herzliches Dankeschön für die guten Beratungen. Ich hoffe, dass wir weiterhin gemeinsam gegen Hass und Hetze aufstehen.
#
# Predicted Speech:
# ===================
# #Netzwerkdurchsetzungsgesetz#
#
# Herr Präsident,
#
# heute möchte ich über ein Thema sprechen, das für die Zukunft unseres Landes von entscheidender Bedeutung ist. Ich spreche von dem Netzwerkdurchsetzungsgesetz. Dieses Gesetz ist ein Schlüssel zur Förderung der Digitalisierung, zur Stärkung der Wettbewerbsfähigkeit unseres Landes und zur Sicherstellung der Datenschutzrechte der Bürger.
#
# Wir stehen vor einer entscheidenden Phase in der Geschichte unseres Landes. Die Digitalisierung hat sich in den letzten Jahren zu einem unaufhaltsamen Prozess entwickelt. Sie hat sich auf alle Bereiche unseres Lebens ausgewirkt und hat unsere Wirtschaft, unsere Gesellschaft und unsere Kommunikation verändert. Doch diese Entwicklung hat auch Herausforderungen mit sich gebracht. Wir müssen sicherstellen, dass wir die Vorteile der Digitalisierung nutzen können, ohne die Risiken zu ignorieren.
#
# Das Netzwerkdurchsetzungsgesetz ist ein wichtiges Werkzeug, um diese Herausforderungen anzugehen. Es zielt darauf ab, die Wettbewerbsfähigkeit unseres Landes zu stärken, die Datenschutzrechte der Bürger zu schützen und die Sicherheit unseres Netzwerks zu gewährleisten.
#
# Herr Präsident,
#
# zuerst möchte ich die Bedeutung des Netzwerkdurchsetzungsgesetzes für die Wettbewerbsfähigkeit unseres Landes betonen. In einer globalisierten Welt ist es entscheidend, dass wir unsere Wirtschaft auf dem neuesten Stand der Technologie halten. Das Netzwerkdurchsetzungsgesetz wird uns helfen, unsere Unternehmen und unseren Mittelstand zu unterstützen, indem es die Entwicklung neuer Technologien und Innovationen fördert.
#
# Dieses Gesetz wird uns helfen, die Wettbewerbsfähigkeit unseres Landes zu stärken, indem es die Entwicklung neuer Technologien und Innovationen fördert. Es wird uns helfen, unsere Unternehmen und unseren Mittelstand zu unterstützen, indem es die Entwicklung neuer Technologien und Innovationen fördert.
#
# Außerdem wird das Netzwerkdurchsetzungsgesetz dazu beitragen, die Datenschutzrechte der Bürger zu schützen. In der digitalen Ära ist es entscheidend, dass wir die Privatsphäre und die Sicherheit der Bürger schützen. Dieses Gesetz wird uns helfen, die Datenschutzrechte der Bürger zu schützen, indem es die Verantwortung der Unternehmen für die Sicherheit und Privatsphäre der Daten festlegt.
#
# Schließlich möchte ich die Bedeutung der Sicherheit unseres Netzwerks betonen. In einer digitalen Welt ist die Sicherheit unseres Netzwerks von entscheidender Bedeutung. Das Netzwerkdurchsetzungsgesetz wird uns helfen, die Sicherheit unseres Netzwerks zu gewährleisten, indem es die Verantwortung der Unternehmen für die Sicherheit festlegt.
#
# Herr Präsident,
#
# ich bitte die Abgeordneten, dieses Gesetz zu unterstützen. Das Netzwerkdurchsetzungsgesetz ist ein Schlüssel zur Förderung der Digitalisierung, zur Stärkung der Wettbewerbsfähigkeit unseres Landes und zur Sicherstellung der Datenschutzrechte der Bürger. Wir müssen sicherstellen, dass wir die Vorteile der Digitalisierung nutzen können, ohne die Risiken zu ignorieren.
#
# Das Netzwerkdurchsetzungsgesetz ist ein wichtiges Werkzeug, um diese Herausforderungen anzugehen. Es zielt darauf ab, die Wettbewerbsfähigkeit unseres Landes zu stärken, die Datenschutzrechte der Bürger zu schützen und die Sicherheit unseres Netzwerks zu gewährleisten.
#
# Herr Präsident,
#
# ich bitte die Abgeordneten, dieses Gesetz zu unterstützen. Wir müssen sicherstellen, dass wir die Vorteile der Digitalisierung nutzen können, ohne die Risiken zu ignorieren. Das Netzwerkdurchsetzungsgesetz ist ein Schlüssel zur Förderung der Digitalisierung, zur Stärkung der Wettbewerbsfähigkeit unseres Landes und zur Sicherstellung der Datenschutzrechte der Bürger.
#
# Das Netzwerkdurchsetzungsgesetz ist ein wichtiges Werkzeug, um diese Herausforderungen anzugehen. Es zielt darauf ab, die Wettbewerbsfähigkeit unseres Landes zu stärken, die Datenschutzrechte der Bürger zu schützen und die Sicherheit unseres Netzwerks zu gewährleisten.
#
# Herr Präsident,
#
# ich bitte die Abgeordneten, dieses Gesetz zu unterstützen. Wir müssen sicherstellen, dass wir die Vorteile der Digitalisierung nutzen können, ohne die Risiken zu ignorieren. Das Netzwerkdurchsetzungsgesetz ist ein Schlüssel zur Förderung der Digitalisierung, zur Stärkung der Wettbewerbsfähigkeit unseres Landes und zur Sicherstellung der Datenschutzrechte der Bürger.
#
# Das Netzwerkdurchsetzungsgesetz ist ein wichtiges Werkzeug, um diese Herausforderungen anzugehen. Es zielt darauf ab, die Wettbewerbsfähigkeit unseres Landes zu stärken, die Datenschutzrechte der Bürger zu schützen und die Sicherheit unseres Netzwerks zu gewährleisten.
#
# Herr Präsident,
#
# ich bitte die Abgeordneten, dieses Gesetz zu unterstützen. Wir müssen sicherstellen, dass wir die Vorteile der Digitalisierung nutzen können, ohne die Risiken zu ignorieren. Das Netzwerkdurchsetzungsgesetz ist ein Schlüssel zur Förderung der Digitalisierung, zur Stärkung der Wettbewerbsfähigkeit unseres Landes und zur Sicherstellung der Datenschutzrechte der Bürger.
#
# Das Netzwerkdurchsetzungsgesetz ist ein wichtiges Werkzeug, um diese Herausforderungen anzugehen. Es zielt darauf ab, die Wettbewerbsfähigkeit unseres Landes zu stärken, die Datenschutzrechte der Bürger zu schützen und die Sicherheit unseres Netzwerks zu gewährleisten.
#
# Herr Präsident,
#
# ich bitte die Abgeordneten, dieses Gesetz zu unterstützen. Wir müssen sicherstellen, dass wir die Vorteile der Digitalisierung nutzen können, ohne die Risiken zu ignorieren. Das Netzwerkdurchsetzungsgesetz ist ein Schlüssel zur Förderung der Digitalisierung, zur Stärkung der Wettbewerbsfähigkeit unseres Landes und zur Sicherstellung der Datenschutzrechte der Bürger.
#
# Das Netzwerkdurchsetzungsgesetz ist ein wichtiges Werkzeug, um diese Herausforderungen anzugehen. Es zielt darauf ab, die Wettbewerbsfähigkeit unseres Landes zu stärken, die Datenschutzrechte der Bürger zu schützen und die Sicherheit unseres Netzwerks zu gewährleisten.
#
# Herr Präsident,
#
# ich bitte die Abgeordneten, dieses Gesetz zu unterstützen. Wir müssen sicherstellen, dass wir die Vorteile der Digitalisierung nutzen können, ohne die Risiken zu ignorieren. Das Netzwerkdurchsetzungsgesetz ist ein Schlüssel zur Förderung der Digitalisierung, zur Stärkung der Wettbewerbsfähigkeit unseres Landes und zur Sicherstellung der Datenschutzrechte der Bürger.
#
# Das Netzwerkdurchsetzungsgesetz ist ein wichtiges Werkzeug, um diese Herausforderungen anzugehen. Es zielt darauf ab, die Wettbewerbsfähigkeit unseres Landes zu stärken, die Datenschutzrechte der Bürger zu schützen und die Sicherheit unseres Netzwerks zu gewährleisten.
#
# Herr Präsident,
#
# ich bitte die Abgeordneten, dieses Gesetz zu unterstützen. Wir müssen sicherstellen, dass wir die Vorteile der Digitalisierung nutzen können, ohne die Risiken zu ignorieren. Das Netzwerkdurchsetzungsgesetz ist ein Schlüssel zur Förderung der Digitalisierung, zur Stärkung der Wettbewerbsfähigkeit unseres Landes und zur Sicherstellung der Datenschutzrechte der Bürger.
#
# Das Netzwerkdurchsetzungsgesetz ist ein wichtiges Werkzeug, um diese Herausforderungen anzugehen. Es zielt darauf ab,

# %% [markdown]
# ## **5) Fine Tuning with Political Speeches**

# %%
# reload model for fine tuned


model_name = "jphme/Llama-2-13b-chat-german"
device = "cuda" if torch.cuda.is_available() else "cpu"

print(f"Loading Llama model: {model_name}")
print(f"Device: {device}")

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token


quantization_config = BitsAndBytesConfig(
    load_in_4bit = True, 
    bnb_4bit_quant_type = 'nf4',
    bnb_4bit_use_double_quant = True, 
    bnb_4bit_compute_dtype = torch.bfloat16 
)


# Load LLama model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    quantization_config = quantization_config,
    device_map="auto" if torch.cuda.is_available() else None,
)

print("Llama model and tokenizer loaded successfully!")
print(f"Model parameters: {model.num_parameters():,}")
# Out:
# Loading Llama model: jphme/Llama-2-13b-chat-german
# Device: cuda
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Llama model and tokenizer loaded successfully!
# Model parameters: 13,015,864,320

# %%
# create the chat template --> was missing

tokenizer.chat_template = """<s>[INST] <<SYS>>Du bist ein hilfreicher, respektvoller und ehrlicher Assistent.
Verhalte dich wie ein*e Abgeordnete*r im deutschen Bundestag.
Gegeben einer Parteizugehörigkeit und eines Themas, schreibe eine politische Rede im Umfang von 200 bis 1500 Worten.
<</SYS>>

{% for message in messages %}
{{ message['content'] }}{% if not loop.last %} [/INST] <s>[INST] {% else %} [/INST] {% endif %}
{% endfor %}</s>"""

tokenizer.model_max_length = 2048

# %%
# convert data to suitable format
def row_to_prompt(row):

    # get correct style of prompt
    messages = [
        {
            "role": "user",
            "content": f" Du bist ein*e Abgeordnete*r im deutschen Bundestag. Deine Fraktion ist: {row['party']}. Schreibe eine politische Rede mit bis zu 1500 Worten, die du im Bundestag hälst. Der Titel ist {row['agenda_item_title']}."

        },
        {
            "role": "assistant",
            "content": row['cleaned_text']
        }
    ]

    # apply chat template
    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=False
    )
    return prompt

# %%
# make sataset 

clean_df["text"] = clean_df.apply(row_to_prompt, axis=1)
dataset = Dataset.from_pandas(clean_df[["text"]])

# %%
clean_df['text'][0]
# Out:
# '<s>[INST] <<SYS>>Du bist ein hilfreicher, respektvoller und ehrlicher Assistent.\nVerhalte dich wie ein*e Abgeordnete*r im deutschen Bundestag.\nGegeben einer Parteizugehörigkeit und eines Themas, schreibe eine politische Rede im Umfang von 200 bis 1500 Worten.\n<</SYS>>\n\n Du bist ein*e Abgeordnete*r im deutschen Bundestag. Deine Fraktion ist: Union. Schreibe eine politische Rede mit bis zu 1500 Worten, die du im Bundestag hälst. Der Titel ist EU-Richtlinie Umweltauswirkungen Kunststoffprodukte. [/INST] <s>[INST] Sehr geehrte Frau Präsidentin! Werte Kolleginnen und Kollegen! Auch von meiner Seite aus einen herzlichen Glückwunsch an die Ministerin und alles Gute für das neue Lebensjahr. Liebe Kolleginnen und Kollegen, keine Frage: Achtlos weggeworfene Kunststoffprodukte stellen ein großes Problem für unsere Umwelt dar; das wissen wir alle. Sie benötigen Jahrzehnte, wenn nicht gar Jahrhunderte, um sich zu zersetzen, belasten unsere Ökosysteme und schaden uns Menschen und auch der Tierwelt. Ich weiß, dass wir – das haben wir bei den vorausgegangenen Reden zu diesem Thema gehört – fraktionsübergreifend dasselbe Ziel verfolgen: Wir müssen und wir wollen die Stoffkreisläufe weiter schließen und damit die Umwelt weiter entlasten. Aber der Weg zu diesem Ziel eint uns nicht. Technologieoffenheit, Ideologiefreiheit und ein Level Playing Field – das sind die Voraussetzungen dafür, dass dieses Gesetz funktionieren kann. Und dafür steht die Union. Wir debattieren heute in erster Lesung über das vorliegende Einwegkunststofffondsgesetz. Es ist übrigens die vorerst letzte nationale Umsetzung der EU-Einwegkunststoffrichtlinie. Die Verwendung von bestimmten Einwegkunststoffen soll dabei reduziert werden. Als Folge soll die Umweltbelastung durch Plastikmüll auf den Straßen, in unseren Parks, in unseren Gewässern usw. verringert werden. Schon zu Beginn des parlamentarischen Verfahrens – das ist ja heute – bin ich sicher, dass wir in den kommenden Wochen an vielen Stellen des Gesetzesentwurfes Verbesserungen herbeiführen werden. Wir werden Sie, liebe Kolleginnen und Kollegen der Ampelfraktionen, dabei nach Kräften unterstützen. In den Einwegkunststofffonds werden Hersteller und Importeure von bestimmten Produktgruppen regelmäßig einzahlen müssen, solange deren Vertrieb läuft. Die gesammelten Mittel sollen anschließend dazu verwendet werden, die Hersteller an den Kosten der Entsorgung und Reinigung im öffentlichen Bereich, die bis jetzt alleine durch die Allgemeinheit getragen wurden, zu beteiligen. Durch die Verteuerung der Produkte sollen die Verbraucherinnen und Verbraucher und in Folge dann natürlich die Produzenten angeregt werden, auf umweltfreundliche Alternativen umzusteigen. So viel zur Theorie. Das klingt doch erst mal sehr harmonisch. Wir müssen dabei jedoch im Auge behalten, dass Produkte aus deutscher Fabrikation durch einseitige nationale Preissteigerungen im EU-Raum und global ihre Wettbewerbsfähigkeit nicht verlieren dürfen. Die Vorgaben der Europäischen Kommission zur Umsetzung der EU-Einwegkunststoffrichtlinie geben der nationalen Umsetzung große Spielräume. Das ist zwar auf der einen Seite sehr großzügig, sorgt aber auf der anderen Seite mit Sicherheit dafür, dass wir in der EU einen Flickenteppich an nationalen Umsetzungen sehen werden, und das ist ja eigentlich nicht sinnvoll. Das ist also auf jeden Fall auch volkswirtschaftlich betrachtet ein wichtiger Grund, vorsichtig zu sein. Mit dem vorliegenden Vorschlag des Umweltministeriums preschen Sie, liebe Bundesregierung, innerhalb der EU jedoch vor, ohne die angekündigten Leitlinien der EU-Kommission zur Umsetzung abzuwarten. Deutschland ist eines der ersten Mitgliedsländer, das bereits ein konkretes Kostenmodell erarbeitet hat. Das ist ausnahmsweise mal schnell – das ist positiv –, aber auf der anderen Seite nicht wirklich gut in dem Fall. Wir müssen unsere Unternehmen in einem starken europäischen Binnenmarkt doch bestmöglich unterstützen. Sie schaffen einen bürokratieintens ...

# %%
# tokenize the resulting chat formated prompt
def tokenize(example):
    result = tokenizer(
        example["text"],
        padding="max_length",
        truncation=True,
        max_length=2048,
    )
    # Labels for causal LM training are the input_ids themselves
    result["labels"] = result["input_ids"].copy()
    return result

# %%
tokenized_dataset = dataset.map(tokenize, batched=True, remove_columns=["text"])
# Out:
# Map:   0%|          | 0/21708 [00:00<?, ? examples/s]

# %%
# training settings

lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q_proj", "v_proj", "k_proj", "o_proj", "gate_proj", "up_proj", "down_proj"], 
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

training_args = TrainingArguments(
    output_dir="./llama2-all-speeches",
    per_device_train_batch_size=1, 
    gradient_accumulation_steps=8, 
    num_train_epochs=3,
    learning_rate=2e-4,
    fp16=True,
    logging_steps=10,
    save_strategy="epoch",
    report_to="none"
)

# %%
trainer = SFTTrainer(
    model=model, # fine tune the model
    train_dataset=tokenized_dataset, # not sample,
    args=training_args,
    peft_config=lora_config
)

trainer.train()
trainer.save_model("./Llama_all_speeches")
# Out:
# Truncating train dataset:   0%|          | 0/21708 [00:00<?, ? examples/s]
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
#     <div>
#
#       <progress value='8142' max='8142' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8142/8142 13:22:23, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>14.559400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>5.529500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.612400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.391100</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.666600</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.095400</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.755800</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.606400</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.592400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.559900</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.532500</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.405100</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.465500</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.420800</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.561300</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.452200</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.491000</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.464300</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.330400</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.508900</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.545500</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.458800</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.459600</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.419900</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.404000</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.449900</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.354900</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.407000</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.344000</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.444500</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.465900</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.432000</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.574000</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.525800</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.557300</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.397400</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.497200</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.453600</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.399800</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.444000</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.475800</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.416500</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.383500</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.491100</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.433000</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.450800</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.477800</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.460200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.474800</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.457600</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.444800</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.468400</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.378800</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.556800</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.570000</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.385700</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.479700</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.534100</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.401500</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.456800</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.542600</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.419200</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.504200</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.404500</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.429200</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.392000</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.445600</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.399700</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.397100</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>0.421300</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.395200</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>0.450400</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>0.395800</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.492100</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>0.480900</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>0.474700</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.470200</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.425300</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.480500</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>0.333800</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>0.428400</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>0.375700</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>0.449200</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.448200</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>0.447300</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>0.442900</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>0.458300</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>0.465500</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.417300</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>0.418000</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>0.436100</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>0.474800</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.549900</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.449400</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>0.552700</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>0.308600</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>0.482000</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>0.362300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.408500</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>0.426500</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>0.408900</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>0.507500</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>0.377900</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.356800</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>0.355000</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>0.412000</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>0.489100</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>0.404000</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.386400</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>0.380200</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>0.388900</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>0.456700</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>0.466800</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.350300</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>0.425900</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>0.493600</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>0.433900</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>0.480200</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.440300</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>0.479400</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>0.413800</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>0.558700</td>
#     </tr>
#     <tr>
#       <td

# %%
from transformers import GenerationConfig

# Set a valid config for deterministic generation
gen_config = GenerationConfig(
    do_sample=False,
    temperature=None,
    top_p=None
)

model.generation_config = gen_config

# Now save --> issue at reimport, apparently only the base model weights were saved... Later be restored over saved trainer
model.save_pretrained("generator_ft/")
tokenizer.save_pretrained("generator_ft/")
# Out:
# ('generator_ft/tokenizer_config.json',
#  'generator_ft/special_tokens_map.json',
#  'generator_ft/chat_template.jinja',
#  'generator_ft/tokenizer.json')

# %%
def generate_prediction_after_ft(fraction_label, title, model, tokenizer, temp):
    """Generate politicat party speeches using the base Llama model with chat template"""
    # Create messages in the format expected by Llama
    messages = [
        {
            "role": "user",
            "content": f" Du bist ein*e Abgeordnete*r im deutschen Bundestag. Deine Fraktion ist: {fraction_label}. Schreibe eine politische Rede mit bis zu 1500 Worten, die du im Bundestag hälst. Der Titel ist {title}."
        }
    ]

    # Apply chat template with thinking disabled for consistency
    formatted_text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
        enable_thinking=False  # Disable for consistency with training
    )

    model_inputs = tokenizer([formatted_text], return_tensors="pt", max_length=2048, truncation=True).to(model.device)


    # Generate prediction with proper stopping
    with torch.inference_mode():
        generated_ids = model.generate(
            **model_inputs,
            max_new_tokens=2048,
            temperature=temp,
            repetition_penalty = 1.6,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id,  # Ensure EOS token stops generation            
        )

    # Extract only the new tokens
    output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist()

    # Decode the response and remove EOS token if present
    content = tokenizer.decode(output_ids, skip_special_tokens=True).strip()

    return content

# %%
# temperature at 0.1

prediction_after_finetune_01 = []

for party, value in random_title_info.items():
    print(party)
    print(value["title"])
    prediction_after_finetune_01.append(generate_prediction_after_ft(party, value["title"], model, tokenizer, temp = 0.1))
# Out:
# Union
# Regulierung von Bonitätsauskünften
# SPD
# Bildung und Forschung für geflüchtete Ukrainer
# GRÜNE
# Verteidigungspolitik, Einsatzbereitschaft Bundeswehr
# FDP
# Aktuelle Stunde zur Eskalation in der Golfregion
# AfD
# Kinderzukunftsprogramm
# LINKE
# Netzwerkdurchsetzungsgesetz

# %%
# temperature at 0.3

prediction_after_finetune_03 = []

for party, value in random_title_info.items():
    print(party)
    print(value["title"])
    prediction_after_finetune_03.append(generate_prediction_after_ft(party, value["title"], model, tokenizer, temp = 0.3))
# Out:
# Union
# Regulierung von Bonitätsauskünften
# SPD
# Bildung und Forschung für geflüchtete Ukrainer
# GRÜNE
# Verteidigungspolitik, Einsatzbereitschaft Bundeswehr
# FDP
# Aktuelle Stunde zur Eskalation in der Golfregion
# AfD
# Kinderzukunftsprogramm
# LINKE
# Netzwerkdurchsetzungsgesetz

# %%
# export

prediction_after_finetune_01_df = pd.DataFrame(prediction_after_finetune_01).rename(columns = {0 : "speech"})
prediction_after_finetune_01_df["party"] =  list(random_title_info.keys())
prediction_after_finetune_01_df.to_csv("../data/generative_prediction_after_finetune_01.csv")
prediction_after_finetune_01_df

prediction_after_finetune_03_df = pd.DataFrame(prediction_after_finetune_03).rename(columns = {0 : "speech"})
prediction_after_finetune_03_df["party"] =  list(random_title_info.keys())
prediction_after_finetune_03_df.to_csv("../data/generative_prediction_after_finetune_03.csv")
prediction_after_finetune_03_df
# Out:
#                                               speech  party
# 0  # INFOS SEITE DU BIST EIN HILFEZWEIG FÜR SICHE...  Union
# 1  [INST] Sehr geehrte Frau Präsidentin! Liebe Ko...    SPD
# 2  #INCLUDE <https://www.youtube-nocookie.com/_Yl...  GRÜNE
# 3  #NeverAgain – so lautet das Motto des jüngsten...    FDP
# 4  [_] Sehr geehrte Frau Präsidentin! Verehrte Ko...    AfD
# 5  [INST] Sehr geehrte Frau Präsidentin! Liebe Ko...  LINKE

# %%
# compare

for i, (party, value) in enumerate(random_title_info.items()):
    
    # true speech
    true_speech = clean_df.loc[clean_df['agenda_item_title'] == value["title"], 'speech_text'].values[0]

    # Get the predicted speech
    predicted_speech = prediction_base[i]
    finetuned_speech_01 = prediction_after_finetune_01[i]
    finetuned_speech_03 = prediction_after_finetune_03[i]

    # Print comparison
    print("==================")
    print(f"\n=== {party} ===")
    print(f"Agenda Item: {value['title']}\n")
    print("==================")
    
    print("True Speech:\n")
    print("==================")
    print(true_speech)
    
    print("Initial predicted Speech:\n")
    print("==================")
    print(predicted_speech)
    
    print("Fine-tuned predicted (0.1 temp) Speech:\n")
    print("==================")
    print(finetuned_speech_01)
    
    print("Fine-tuned predicted (0.3 temp) Speech:\n")
    print("==================")
    print(finetuned_speech_03)
# Out:
# ==================
#
# === Union ===
# Agenda Item: Regulierung von Bonitätsauskünften
#
# ==================
# True Speech:
#
# ==================
# Ich warte gern noch etwas, wenn Sie mich weiter loben wollen, Frau Präsidentin.
# Sonntag ist der erste Advent.
# Sehr geehrte Frau Präsidentin! Liebe Kolleginnen! Liebe Kollegen! In unserem Land besteht grundsätzlich die im Grundgesetz verankerte Vertragsfreiheit. Mit der hat eine Partei in diesem Haus immer wieder sichtliche Probleme. Lieber Matthias Birkwald, liebe Frau Nastic, heute Nachmittag haben wir hier über die Frage eines Kündigungsschutzes für über 70-jährige Mieter debattiert.
# Das klingt toll, das klingt gut, aber das ist bei Ihren Anträgen immer so. Es gibt da immer zwei Seiten der Medaille, eine positive, die verlockend klingt – das ist der Kündigungsschutz für über 70-jährige Mieter –, aber gleichzeitig die Rückseite der Medaille, nämlich die Problematik, dass dann ein 65-jähriger, 67-jähriger, 68-jähriger Mietinteressent gar keinen Mietvertrag mehr bekommen wird.
# Das heißt ja im Endeffekt: Was immer gut gemeint ist, ist noch lange nicht gut gemacht.
# – Er darf eine Zwischenfrage stellen; ich würde sie zulassen, Frau Präsidentin.
# Nein, das kann er jetzt nicht. Jetzt reden Sie. Ich weiß schon: Sie wollen wieder mehr Redezeit.
# Los geht’s! Sie haben immer noch vier Minuten.
# Herr Kollege Birkwald, auch für euch gilt: Quidquid agis, prudenter agas et respice finem! – Das heißt: Was immer du tust, handle klug und bedenke das Ende. – Sie sind mit diesem Antrag gerade wieder im Begriff, das Kind mit dem Bade auszuschütten.
# Die Vorredner haben bereits zum Teil darauf hingewiesen: Es gibt ja bei der Schufa nicht nur die negative Auskunft. Es gibt ja bei der Schufa nicht nur die Situation, dass ein gesperrtes Konto, ein nicht zurückgezahlter Kredit oder eine offene Mahngebühr dazu führt, dass eine Auskunft negativ ist. Es gibt genauso die Möglichkeit, nichts auf dem Kerbholz zu haben, also keine Probleme, keinen Schufa-Eintrag. Damit schafft man – es wurde von den Kollegen bereits angesprochen – eine Vertrauensbasis, wie es sie in früheren kleinen Gesellschaften, in kleinen Dörfern gegeben hat: Da hat man sich gekannt; da wurde beim Viehhändler noch der Vertrag mit Handschlag besiegelt;
# da kannte man den Vertragspartner. Es gibt aber in unserer heutigen Gesellschaft oft genug anonyme Vertragsverhältnisse: Man kennt den Vertragspartner nicht. Um das Vertrauen herzustellen, gibt es die Möglichkeit, eine Schufa-Auskunft einzuholen. – Frau Nastic wollte mich was fragen, Frau Präsidentin.
# Ich würde es zulassen.
# Wollen Sie wirklich was fragen, Frau Nastic? – Gut. Sie lassen es zu?
# Ja, selbstverständlich.
# Vielen Dank, dass Sie die Frage zulassen. – Was sagen Sie denn zu den heutigen Nachrichten, dass die Schufa millionenfach Daten eingekauft hat, mittlerweile auch Kontoauszüge durchleuchten will, damit den Datenschutz massiv verletzt und die Menschen quasi zu gläsernen Bürgern macht? Damit wären der Schufa alle Kontobewegungen bekannt. Auch der ehemalige Datenschutzbeauftragte Peter Schaar ist alarmiert und wendet sich massiv gegen das, was die Schufa da gerade macht.
# Danke, Frau Nastic, für die Frage. – Ich bin weit davon entfernt, die Schufa heiligzusprechen. Natürlich: Wo die Schufa arbeitet, können auch Fehler gemacht werden. Es muss unter Datenschutzaspekten geprüft werden, ob die Sammelwut, die manchmal an den Tag gelegt wird, überhaupt begründet und verhältnismäßig ist, ob die zur Zweckverfolgung gewählten Mittel überhaupt sinnvoll sind.
# Sind das noch die Reste von der Weindebatte?
# – Die Weindebatte hat in Ravensburg ihre Spuren hinterlassen.
# Jetzt bitte ich doch, das Thema ernst zu nehmen. – Noch mal, Frau Nastic: Ich verkenne nicht, dass bei der Schufa auch Fehler gemacht werden. Wenn die Informationen, die ich auch heute Nachmittag der Presse entnehmen konnte, zutreffend sind, dann muss das eingegrenzt werden. Es wurde ja von der Kollegin Rößner vorhin ausgeführt, dass wir natürlich auch bei der Schufa die Einhaltung der Regeln immer wieder überprüfen müssen.
# Vielleicht noch was dazu: Die Chancen einer positiven Schufa-Auskunft sind natürlich mindestens genauso groß wie die Risiken oder Probleme, die ein Vertragsanbahnungsinteressent bei einer negativen Auskunft hat. Deshalb lassen Sie uns bitte beide Seiten der Medaille sehen, nämlich auch die Möglichkeit, mit einer positiven Schufa-Auskunft die Basis für eine vertrauensvolle Vertragsanbahnung zu schaffen. Das vermisse ich in Ihrem Antrag komplett. Das heißt, Sie schütten das Kind wieder mit dem Bade aus, und das ist schade.
# Es ist, wie gesagt, legitim, dass beide Vertragsparteien Informationen über die jeweils andere Seite einholen und sich informieren, um zu wissen, dass der Vertrag tatsächlich erfüllt werden kann. Es ist tatsächlich so, dass viele wirtschaftlich nicht so begüterte Verbraucher – Mietinteressenten, Kaufinteressenten, Verbraucher, die ein Handy kaufen, einen Handyvertrag oder einen Stromliefervertrag abschließen wollen – davon auch profitieren. Es gibt zwei Möglichkeiten: Der Vertragspartner kann sich durch eine Bankbürgschaft absichern. Die Bankbürgschaft kostet aber Geld. Oder ich kann sagen: Okay, ich lege eine Selbstauskunft der Schufa vor. Ich habe bisher immer meine Rechnungen ordentlich bezahlt.
# – Nein, das ist jetzt in Anführungszeichen, Herr Kollege Birkwald. – Du kannst mit gutem Gewissen einen Vertrag mit mir eingehen.
# Die Chancen für die Verbraucher verkennen Sie in Ihrem Antrag. Mit der Abschaffung der Schufa würden Sie die Situation für die Verbraucher keineswegs verbessern, sondern verbösern. Deshalb wird es Sie nicht wundern: Wir werden den Antrag ablehnen.
#
# Initial predicted Speech:
#
# ==================
# #Regulierung von Bonitätsauskünften#
#
# Herr Präsident, verehrtes Haus,
#
# Heute, im Namen der Union, möchte ich mich für die Regulierung von Bonitätsauskünften einsetzen. Die Bonitätsauskünfte sind ein wichtiger Bestandteil des Kreditmarktes und tragen wesentlich zur Finanzierung von Unternehmen und Privatpersonen bei. Sie ermöglichen es Kreditinstituten, die Bonität eines Kreditnehmers zu bewerten und die Risiken zu bewerten, die mit der Kreditvergabe verbunden sind.
#
# Wir müssen jedoch die Bonitätsauskünfte regeln, um sicherzustellen, dass sie fair und transparent sind. Die Union ist der Überzeugung, dass die Regulierung von Bonitätsauskünften dazu beitragen kann, die Kreditvergabe zu verbessern, die Kreditmarkttransparenz zu erhöhen und die Risiken für Kreditinstitute und Kreditnehmer zu verringern.
#
# Herr Präsident, die Bonitätsauskünfte sind ein komplexes Thema, und wir müssen sicherstellen, dass wir die richtigen Maßnahmen ergreifen, um die Interessen von Kreditinstituten und Kreditnehmern zu schützen. Die Union schlägt folgende Maßnahmen zur Regulierung von Bonitätsauskünften vor:
#
# 1. Transparenz: Wir müssen sicherstellen, dass die Bonitätsauskünfte transparent sind und die Kreditnehmer über die Informationen informiert sind, die für die Bewertung ihrer Bonität verwendet werden. Dies wird dazu beitragen, die Kreditmarkttransparenz zu erhöhen und die Kreditnehmer vor unangemessenen Kreditvergaben zu schützen.
# 2. Standardisierung: Wir müssen sicherstellen, dass die Bonitätsauskünfte standardisiert sind, um eine fairere Bewertung der Bonität der Kreditnehmer zu ermöglichen. Dies wird dazu beitragen, die Kreditmarkttransparenz zu erhöhen und die Kreditnehmer vor unangemessenen Kreditvergaben zu schützen.
# 3. Regelmäßige Überprüfung: Wir müssen sicherstellen, dass die Bonitätsauskünfte regelmäßig überprüft werden, um sicherzustellen, dass sie den aktuellen Marktbedingungen entsprechen. Dies wird dazu beitragen, die Kreditmarkttransparenz zu erhöhen und die Kreditnehmer vor unangemessenen Kreditvergaben zu schützen.
# 4. Anpassung an die Marktentwicklung: Wir müssen sicherstellen, dass die Bonitätsauskünfte an die Marktentwicklung angepasst werden, um sicherzustellen, dass sie den aktuellen Marktbedingungen entsprechen. Dies wird dazu beitragen, die Kreditmarkttransparenz zu erhöhen und die Kreditnehmer vor unangemessenen Kreditvergaben zu schützen.
# 5. Strafen für unangemessene Bonitätsauskünfte: Wir müssen sicherstellen, dass Kreditinstitute, die unangemessene Bonitätsauskünfte verbreiten, strafbar gemacht werden. Dies wird dazu beitragen, die Kreditmarkttransparenz zu erhöhen und die Kreditnehmer vor unangemessenen Kreditvergaben zu schützen.
#
# Herr Präsident, die Union ist der Überzeugung, dass die Regulierung von Bonitätsauskünften dazu beitragen kann, die Kreditvergabe zu verbessern, die Kreditmarkttransparenz zu erhöhen und die Risiken für Kreditinstitute und Kreditnehmer zu verringern. Wir bitten das Haus, diese Vorschläge zu berücksichtigen und die Regulierung von Bonitätsauskünften zu unterstützen.
#
# Dieser Vorschlag ist ein wichtiger Schritt in Richtung einer stabilen und transparenten Finanzmärkteinrichtung. Wir müssen zusammenarbeiten, um die Bonitätsauskünfte zu regulieren und sicherzustellen, dass die Kreditmarkttransparenz erhöht und die Risiken für Kreditinstitute und Kreditnehmer verringert werden.
#
# Herr Präsident, ich danke Ihnen für die Gelegenheit, diesen wichtigen Vorschlag vorzubringen. Wir bitten das Haus, diesen Vorschlag zu berücksichtigen und die Regulierung von Bonitätsauskünften zu unterstützen.
#
# Dieser Vorschlag ist ein wichtiger Schritt in Richtung einer stabilen und transparenten Finanzmärkteinrichtung. Wir müssen zusammenarbeiten, um die Bonitätsauskünfte zu regulieren und sicherzustellen, dass die Kreditmarkttransparenz erhöht und die Risiken für Kreditinstitute und Kreditnehmer verringert werden.
#
# Herr Präsident, ich danke Ihnen für die Gelegenheit, diesen wichtigen Vorschlag vorzubringen. Wir bitten das Haus, diesen Vorschlag zu berücksichtigen und die Regulierung von Bonitätsauskünften zu unterstützen.
#
# Dieser Vorschlag ist ein wichtiger Schritt in Richtung einer stabilen und transparenten Finanzmärkteinrichtung. Wir müssen zusammenarbeiten, um die Bonitätsauskünfte zu regulieren und sicherzustellen, dass die Kreditmarkttransparenz erhöht und die Risiken für Kreditinstitute und Kreditnehmer verringert werden.
#
# Herr Präsident, ich danke Ihnen für die Gelegenheit, diesen wichtigen Vorschlag vorzubringen. Wir bitten das Haus, diesen Vorschlag zu berücksichtigen und die Regulierung von Bonitätsauskünften zu unterstützen.
#
# Dieser Vorschlag ist ein wichtiger Schritt in Richtung einer stabilen und transparenten Finanzmärkteinrichtung. Wir müssen zusammenarbeiten, um die Bonitätsauskünfte zu regulieren und sicherzustellen, dass die Kreditmarkttransparenz erhöht und die Risiken für Kreditinstitute und Kreditnehmer verringert werden.
#
# Herr Präsident, ich danke Ihnen für die Gelegenheit, diesen wichtigen Vorschlag vorzubringen. Wir bitten das Haus, diesen Vorschlag zu berücksichtigen und die Regulierung von Bonitätsauskünften zu unterstützen.
#
# Dieser Vorschlag ist ein wichtiger Schritt in Richtung einer stabilen und transparenten Finanzmärkteinrichtung. Wir müssen zusammenarbeiten, um die Bonitätsauskünfte zu regulieren und sicherzustellen, dass die Kreditmarkttransparenz erhöht und die Risiken für Kreditinstitute und Kreditnehmer verringert werden.
#
# Herr Präsident, ich danke Ihnen für die Gelegenheit, diesen wichtigen Vorschlag vorzubringen. Wir bitten das Haus, diesen Vorschlag zu berücksichtigen und die Regulierung von Bonitätsauskünften zu unterstützen.
#
# Dieser Vorschlag ist ein wichtiger Schritt in Richtung einer stabilen und transparenten Finanzmärkteinrichtung. Wir müssen zusammenarbeiten, um die Bonitätsauskünfte zu regulieren und sicherzustellen, dass die Kreditmarkttransparenz erhöht und die Risiken für Kreditinstitute und Kreditnehmer verringert werden.
#
# Herr Präsident, ich danke Ihnen für die Gelegenheit, diesen wichtigen Vorschlag vorzubringen. Wir bitten das Haus, diesen Vorschlag zu berücksichtigen und die Regulierung von Bonitätsauskünften zu unterstützen.
#
# Dieser Vorschlag ist ein wichtiger Schritt in Richtung einer stabilen und transparenten Finanzmärkteinrichtung. Wir müssen zusammenarbeiten, um die Bonitätsauskünfte zu regulieren und sicherzustellen, dass die Kreditmarkttransparenz erhöht und die Risiken für Kreditinstitute und Kreditnehmer verringert werden.
#
# Herr Präsident, ich danke Ihnen für die Gelegenheit, diesen wichtigen Vorschlag vorzubringen. Wir bitten das Haus, diesen Vorschlag zu berücksichtigen und die Regulierung von Bonitätsauskünften zu unterstützen.
#
# Dieser Vorschlag ist ein wichtiger Schritt in Richtung einer stabilen und transparenten Finanzmärkteinrichtung. Wir müssen zusammenarbeiten, um die Bonitätsauskünfte zu regulieren und sicherzustellen, dass die Kreditmarkttranspar
# Fine-tuned predicted (0.1 temp) Speech:
#
# ==================
# #IN THE ROCKET TO HELL# Das war der erste Gedanke in meinem Kopf als ich den Antrag gelesen habe; denn es geht um das gleiche Gesetzesvorhabende – Sie haben ja auch schon mal darüber gesprochen -, nämlich über §§ 34 ff., also zum Widerspruchsrecht bei Forderungen aus Verbrauchskrediten sowie zur Anzeigepflicht beim Insolvenzantrage nach dem SGB XI bzw. Sozialgesetzen XII a IIIa oder XIII IIb für Pflegebedürftige/-innen usw.. Ich glaube nicht, dass wir uns hier auf so viele Stellen des Rechts noch einmal durchgehen müssen. Deshalb will ich mich darauf beschränken, was sich an diesem Vorschlag tatsächlich verbessert hat gegenüber unserem Entschließungsvotum vom März letzten Jahres. Da gab es einen Punkt, wo man sagen konnte: „Da kann doch etwas dran sein“. Es ging dabei vor allem um zwei Punkte. Erstens wurde gefordert, dass diese Informationsrechte klar benannt werden sollen. Die Bundesregierungrößen hatten damals vorgeschlagen, sie könnten vielleicht unter einem Dach zusammengeführt heißen, etwa under one roof genannt wird. Wir waren aber gegen diesen Begriff gewesen wegen dessen Unübersetztbarkeit ins Englisch-Deutsche. Aber jeder weiß natürlich heute genau, worauf damit gemeint sei. Zweitens wurden dann einige zusätzliche Rechenschaftspflichten eingeführt worden ohne wirklichen Mehrwert dafür, insbesondere wenn gleichzeitig immer mehr Daten erhoben würden. Auch dazu hatte Ihnen gestern Frau Staatssekretärin Lötzerbach erklärt, welche Verbesserung stattgefunden hat. Also gut! Jedenfalls sind beide Kritikpunkte entsprechend behandelt worden. Zum ersten Mal gibt es nun konkretere Bezeichnungen dieser Informationspflichten beispielsweise gemäß Artikel 6 Absatz 7 EU Datenschutzgrundverordnung ab Januar nächstjährigen Jahrtausends. Diese Formel wäre mir persönlich lieber geblieben, weil daneben steht: Gilt nur innerhalb Europas. Was passiert sonstwo? Man muss sehen, ob dort ähnliches gelten soll. Im Übrigen bleibt weiterhin offengestellt, wer eigentlich zuständig ist. Bei allen anderen Tätigkeiten können wir feststellen, wen verantwortlich machen sollte. Hier fehlt dieses Zutrauen. Ein zweiter wichtiger Aspekt betrifft wiederholtes Erheben personennaherer Angaben. Damals stand übereinstimmenderweise drin, dies seien keine besonders sensibelen Persondaten. Vielmehr handelte es sich lediglich um Namen, Adressdaten etc.; alles sehr harmlos. Nichts davon musste gemeldet werden. Heute gilt allerdings bereits folgende Feststellung: Wer alle sechs Monate Nachrichtenseiteinformationen sammeln wollte (dazu kam später gar kein Gebaren), brauchte erstmalig genehmigt zu werden. Dies geschieht seitdem per E‑Mail. Und zwar mussten drei Personen bestimmt ersucht werden, ihre Genehmigung einzureichen. Darunter befanden sich sogar Vertreter der Unternehmen selbst. So weit okay. Danach durfte gehandelt werden. Allerdings stellt sich die Frage, welches Interesse dahintersteckt. Warum wolle man denn three people for six months ask permission to collect news articles about someone and their family members or business partners if this information is publicly available anyway on the internet within seconds? Wie lange wohlweillt irgendetwas online verfügbar sein muss, damit man es erfassen mag, blieb bisher verschwiegen. Dennoch fällt auf, dass jedermann seine Privatheit verteidigte, egal ob Geschäftsführersohn oder Tochter. Nur keiner sagte Nein außer denen, deren Name eben veröffentlicht werden sollte. Mit Blick auf allgemeingültiges Recht spräche ich gerne kurz über Art. 8 Grund­gesetz. Dieser besagt ganz grundlegenden Charakter, sodass ihn niemand ableugen kann. Außerdem kommt hinzu, dass es rechtssicher möglich ist, dass Menschen ihren eigenen Körper nutzen lassen, ihr eigen Fleish gewissermaßen verkäuflich machen, jedoch andere Leiber nicht tun können. Eine weitere Ausnahme findet sich in § 96c UrhebsRG. Dort stehen ebenfalls mehrere Möglichkeiten bereithaltend, data protection law friendly tätig zu werden. Dabei rede ich nicht von Data Protection  ...
# Fine-tuned predicted (0.3 temp) Speech:
#
# ==================
# # INFOS SEITE DU BIST EIN HILFEZWEIG FÜR SICHERHEIT UND KLARHAUTEN! Wenn Sie das nicht wollen oder wenn es Ihnen egal sein sollte – ich kann mich daran erinnern; wir haben hier schon mal über dieses Gesetz debattiert –, dann können Sie jetzt gehen bzw., Frau Präsidentin, bitten Herrn Kollegen Dr. Liebich aufzupassen, dass sich niemand aus der Gruppe des Ausschussvorsitzenden entfernt. Seien Sie mir versprochen? Danke sehr für diese Information vorab an alle Zuschauerinnen und -zuhören in diesem Saale sowie draußen am Fernseher. Ich habe den Antrag heute Morgen früh gelesen unter dem Überschriftpunkt „Bonitätskontrollgesetze“ zum ersten Mal. Da stand drin was vom Datenschutz bei Verbraucherschützerorganisationen usw.: alles richtig interessante Punkte. Aber als ich weitergereicht bin, war da nur noch dieser Punkt übrig zur Behandlung durch uns, nämlichen § 38c Absatz 6 Nummer a Urkundengesellschafts-Kaufmannswesen-, Insolvenzanleihe- u. Vermögensberichtsverordnung. Das klingt erst einmal ganz technisch. Jeder weiß aber eigentlich gar keine Ahnung davon, worum es geht. Deshalb möchte ich kurz darauf eingehen. Es handelt sich um einen rechtlichen Unregelmäßigkeitenbeirat beim Deutschen Creditreformverband. Dieser hat nachweislich Fehleinformationen verbreitet gegenüber seinen Mitgliedern bezügliche deren Rechten gegen Banken etcetera. Die Bundesbank hatte daher mehrfach kritisierte Anträge gestellt, weil sie unrichtige Tatsachen behauptete. Diese wurden nun korrigieren sollen dadurch, dass man diesen Rechtsexperten beauftragt wird, genau hinzugucken ob denn tatsächliches Rechtsstaatesversagen stattgefunden hat. Wir sind also dazu berechtigt gewesen, dies abschließend feststellen lassen zu machen. Darüber hinaus wurde auch gefordert, dass ihm endlich Zugang ermöglicht werden soll zu allen Dokumentationen innerhalb seiner Organisation. Diesem Vorstoß konnten seine Mitglieder natürlich leider nie zustimmen; so weit wissen wir doch wirklich jedenfalls etwas. Er selbst sagte ja sogar öffentlijk Nein dazu. Nun gibt es zwei Gründe, warum wir ihn damit aufforsten wollten. Zum Einen will ich sage, liebe Zuhörerschar hinter meiner Sitzreihe: Wer glaubhaft fordert Aufklärungen etwa wegen fehlender Transparenz bei Finanzdienstleister/-institutionen, muss selbst transparent agieren. Warum sonst würden Leute einem Vertrauen entziehen? Zweiter Grund. Auch bankrechtliche Vorgaben sehen vor, dass Vorsitzende aller Gremiensystematiken vollständigen Nachschauungsansprücken stehen müssen. Und wer immerhin Vorsitzer eines Verbands ist, dessen Berufsfachvereinigung die Kontrolle over allgemein zugänglichkeit ihrer Berichte vornimmt (so steht es dort), kommt eben ins Visier der Kritik. Genug gesagt. Lange Zeit gab es keinen Beschluss zwischen Regierungskoalition und Oppositionspartner SPD. Man konnte lange kein gemeinsames Ergebnis finden. Erst letzte Woche kam plötzlich wieder Leben in den Prozess zurück. Heiko Maas teilte bekanntlich gerne viel über Social Media seines Handynamenses mit anderen Politiklössern Deutschlands. So ging es damals auch während der Kooperation mit CDU/CSU. Als Ministerpräsident Ramelow von Sachsen-Anhalt jedoch herausstellte, welches Interesse andere deutsche Landesminister hatten, ebenfalls per Telegram ihre Meinungen äussert zu bekanntermaßen falschen Angaben zu aktuellem rechtsstaatlichen Versagen deutscher Gerichten, stieg Chefin Justiz Haika herunter, sodass seitdem kaum irgendeines mehr getätigt worden sei. Also könnten viele Menschen fragen: Was steckt dahinter? Ist ja offenkundig, dass beide Seiten unterschiedliche Positionnahmen vertreten haben. Eine Seite setzt dabei expliziit auf transparente Strukturdatenbanken ohne Rückgriffe auf Personalinformationen anderer Personen außer Haus. Anderen gilt persönliche Datenvertretbarkeit gleichbedingt wichtiger als datenauskunftsträgerfreie Systemstrukturen. Für Letztere spräche allerdings der Sachstand bisher. Wie kommen wir trotz divergentester Ansätze zu einem Kompromissvo ...
# ==================
#
# === SPD ===
# Agenda Item: Bildung und Forschung für geflüchtete Ukrainer
#
# ==================
# True Speech:
#
# ==================
# Sehr verehrter Herr Präsident! Meine Damen und Herren! Über 1 Million Menschen sind inzwischen aus der Ukraine nach Deutschland geflohen. Der Krieg hat ihnen nicht nur die Heimat genommen, er hat ihnen auch die Gewissheit genommen, die das Lernen in vertrauten Räumen und in der vertrauten Sprache bietet. Deswegen ist es wichtig, dass wir heute besonders über die Solidarität mit Schülerinnen und Schülern, mit Studentinnen und Studenten sprechen. Sie haben unsere Unterstützung, um ihren Bildungsweg in Deutschland fortzusetzen.
# Dabei sind nicht nur Ukrainerinnen und Ukrainer geflohen; auch viele Drittstaatsangehörige, wie wir heute schon gehört haben, hatte es zum Studium an ukrainische Hochschulen gezogen. Auch sie wurden durch denselben Krieg vertrieben, auch nach Deutschland. Ich habe in den letzten Monaten immer wieder mit diesen Studierenden gesprochen, zuletzt am Samstag mit einigen jungen Menschen zum Beispiel aus Somalia. Für sie war die Ukraine der Ort, mit dem sie die Hoffnung verbunden haben, Ärztin oder Zahnarzt zu werden. Der russische Angriffskrieg hat diese Hoffnung zerstört.
# Von Anfang an war klar, dass Deutschland für flüchtende Menschen aus der Ukraine offensteht, unabhängig vom Pass. Auch Drittstaatsangehörige durften für 90 Tage ohne Visum hier sein, waren also sicher. Aber wer sein Zuhause verliert, braucht nicht nur kurzfristigen Schutz, sondern einen Ort mit Bleibeperspektive. Deshalb bin ich dankbar, dass Deutschland sich dafür eingesetzt hat, dass auch Menschen aus Drittstaaten den europaweit einheitlichen temporären Schutz genießen, zumindest wenn sie nicht sicher und dauerhaft in ihr Herkunftsland zurückkehren können. Ich bin auch dankbar, dass Bundesinnenministerin Nancy Faeser schnell klargestellt hat, dass Menschen mit einem dauerhaften Aufenthaltstitel in der Ukraine natürlich mehr Verbindung zur Ukraine haben als zu ihrem Geburtsland. Sie werden daher mit Ukrainerinnen und Ukrainern gleichgestellt, und das ist eine gute Sache.
# Wir wissen aber auch, dass einige Bundesländer weiter vorausgehen. Wir haben beispielsweise Berlin, Hamburg und Bremen, die diesen Drittstaatsangehörigen eine Fiktionsbescheinigung für sechs Monate ausgestellt haben. Ich glaube, das ist eine gute Lösung. Ich habe aber auch vor einigen Stunden aus Augsburg, aus Bayern, eine Nachricht erhalten von einem Studierenden, der in Augsburg eigentlich schon anfangen sollte, zu studieren. Er soll aber jetzt im Dezember abgeschoben werden. Das sind Schicksale, die vor dem Hintergrund des Fachkräftemangels natürlich absolut irrsinnig sind. Ich bin froh darüber, dass wir mit diesem Antrag ein klares Zeichen dafür setzen, dass wir auf Bundesebene eine einheitliche Lösung suchen.
#
# Initial predicted Speech:
#
# ==================
# #Bildung und Forschung für geflüchtete Ukrainer#
#
# Herr Präsident,
#
# ich stehe heute hier, um über ein Thema zu sprechen, das für uns alle von großer Bedeutung ist: Bildung und Forschung für geflüchtete Ukrainer. Als sozialdemokratische Fraktion sind wir immer wieder auf die Notwendigkeit hingewiesen worden, die Rechte und Chancen von Menschen, die vor Gewalt und Unterdrückung geflohen sind, zu schützen und zu fördern.
#
# Wir kennen die Geschichte der Ukraine, und wir kennen die Leiden, die die Menschen dort erdulden müssen. Wir haben die traurigen Folgen des Krieges in der Ostukraine und die Verletzungen, die durch die russische Aggression verursacht wurden, gesehen. Wir haben die Flüchtlinge und Migranten begrüßt, die hierher gekommen sind, um ein neues Leben zu suchen, und wir haben uns bemüht, ihnen eine sichere und unterstützende Umgebung zu bieten.
#
# Doch wir wissen auch, dass die Flüchtlingssituation nicht nur eine humanitäre Angelegenheit ist, sondern auch eine Frage der langfristigen Entwicklung und des Wohlstands für diese Menschen und für unser Land. Daher müssen wir unsere Bemühungen nicht auf die kurzfristige Unterbringung und Versorgung konzentrieren, sondern auch auf die Bildung und Forschung für geflüchtete Ukrainer.
#
# Wir müssen anerkennen, dass Bildung und Forschung die Schlüssel zu einem erfolgreichen Leben sind. Sie ermöglichen es den Menschen, ihre Fähigkeiten zu entwickeln, sich anzupassen und sich an die neue Umgebung anzupassen. Sie helfen ihnen, sich in der Gesellschaft zu integrieren und ihre Rechte und Freiheiten zu wahren.
#
# Daher müssen wir unsere Bemühungen auf die Bereitstellung von Bildungsmöglichkeiten für geflüchtete Ukrainer konzentrieren. Wir müssen sicherstellen, dass diese Menschen Zugang zu qualitativ hochwertiger Bildung haben, sowohl in der Grund- als auch in der weiterführenden Bildung. Wir müssen unsere Bildungssysteme anpassen, um die spezifischen Bedürfnisse und Herausforderungen dieser Menschen zu berücksichtigen.
#
# Darüber hinaus müssen wir unsere Forschungspolitik anpassen, um die Bedürfnisse und Interessen geflüchteter Ukrainer zu berücksichtigen. Wir müssen unsere Forschungslandschaft anpassen, um die spezifischen Herausforderungen und Chancen in der Ukraine zu berücksichtigen. Wir müssen unsere Forschungsinvestitionen auf die Bereitstellung von Lösungen für die Herausforderungen konzentrieren, mit denen diese Menschen konfrontiert sind.
#
# Wir müssen auch die Zusammenarbeit zwischen Regierungsinstitutionen, Bildungseinrichtungen und NGOs fördern, um die Bereitstellung von Bildungsmöglichkeiten und Forschungschancen für geflüchtete Ukrainer zu gewährleisten. Wir müssen die Ressourcen und Expertise dieser Organisationen nutzen, um die Bedürfnisse dieser Menschen zu erfüllen.
#
# Schließlich müssen wir unsere Bemühungen nicht auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer beschränken. Wir müssen uns auch auf die Integration dieser Menschen in unser Gesellschaft konzentrieren. Wir müssen unsere Gesellschaft anpassen, um die Vielfalt und die Fähigkeiten dieser Menschen zu schätzen. Wir müssen unsere Gesellschaft anpassen, um die Rechte und Freiheiten dieser Menschen zu schützen und zu fördern.
#
# Daher müssen wir unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren. Wir müssen unsere Gesellschaft anpassen, um die Bedürfnisse und Herausforderungen dieser Menschen zu berücksichtigen. Wir müssen unsere Gesellschaft anpassen, um die Rechte und Freiheiten dieser Menschen zu schützen und zu fördern.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Engagement für die Zukunft dieser Menschen und für unser Land. Wir müssen unsere Bemühungen auf die Bereitstellung von Bildung und Forschung für geflüchtete Ukrainer konzentrieren, um eine bessere Zukunft für alle zu schaffen.
#
# Das ist unser Eng
# Fine-tuned predicted (0.1 temp) Speech:
#
# ==================
# [INST] Sehr geehrte Frau Präsidentin! Liebe Kolleginnen und lieber Herr Minister Buschmann! Meine sehr verehren Damen und Herren auf den Tribünen oder an der Fernsehbildschirmseite – ich weiß nicht genau; das macht mir auch keinen Unterschied –! Ich bin froh darüber, dass wir heute über dieses wichtige Gesetz sprechen können in einem so ernsten Kontext des Krieges gegen die Ukraine durch Russland. Es geht um vieles mehr als nur einen Punkt aus dem Koalitionsvertrag zwischen CDU, CSU und Grönern bzw., wenn Sie wollen, grönern. Wir haben uns ja schon vor zwei Jahren intensiv damit beschäftigt. Aber es gibt noch etwas anderes ganz Wichtiges dazu, was mich persönlich besonders bewegt hat bei dieser Debatte hier am Redepult. Das war nämlich Ihre Ausführungen zum Grundsatz „Wir sind alle gleich“ sowie zur Frage nach Gleichberechtigung aller Menschen unabhängig vom Geschlecht usw.: Die waren wirklich großartig. Da habe ich gedacht: Na klar, dann muss man sich doch mal fragen lassen dürfen: Warum machen denn eigentlich immer wieder Männer diese Diskussionen? Was könnten sie vielleicht gar nicht verstehen beim GedankenaustausCH? Und da kam plötzlich jemand herbei und sagte: Ja, wissen Sie, meines Erachtens kann niemals irgendjemand sagen, wer andere sein sollten. Jeder sollte selber entscheiden, wen er werden will … Wie bitte? Wer wird ihn wohl leiten? Oder wo solle er hinlaufen? Viel Spaß dabei! So weit, glaube ich, kommt kein Mensch weiter. Deshalb finde ich diesen Sinn-und-Bedeutungsbezug richtigerweise herausgearbeitet worden. Kommen wir aber zurück ins reale Leben. Unser Land steht seit Wochen unter enormem Zeitdruck angesichts dessen, welche Folgen Putins Angriffskriegs auf die gesamtheitliche Infrastructure Europas haben würden. Erreichten wurden bereits viele Maßnahmen zulasten Deutschlands und seiner Bürger/-innen. Nun droht ihm offenkundig seine größtmöglichen Stärkepunkt, also eben Deutschland selbst, direkt ins Mark zu treffen. Dies geschiehet übrigens bewusst. Manche tun dies sogar freiwillig. Ein Beispiel davon gab es gestern Nachmittage während der Regierungsveranstaltung. Dort wurde gesagt: Natürlich stellen wir alles infrage, weil sonst keine Aufmerksamkeit generiert wird. Diese Haltung mag natürlich gut funktionieren, obwohl ihr Kalkül falsch läuft. Tatsächliches Handeln dagegen bringt wenig Gewaltanwendung nütze. Im Gegenteil: Je brutaler die Auseinandersetzung, desto schwächer bleibt ihre Substanzniveaumessbarkeiten. Genauer betrachtsamer Blick zeigt jedoch, welches Potenzial dahinter steckt. Mit diesem Vorhaben versucht Russia to use Germany as a Trojan horse for its propaganda efforts against the West by using German media outlets or even individual journalists who are willing to spread Russian disinformation about this conflict with their own resources without being paid directly from Moscow but rather through other channels like think tanks that receive funding indirectly via pro Kremlinoversiedelte sources within Europe itself which then pass it on further downstream until finally reaching main stream audiences across Western societies including those living inside NATO member states themselves thereby creating confusion among them regarding what really happened during these events leading up towards today’s situation between East &amp;&thorn;;West relations overall while simultaneously weakening public support back home due lack thereof resulting into less political pressure exerted upon government officials tasked at handling such matters professionally instead of resorting onto emotional responses based solely around personal belief systems alone when making decisions affecting entire nations statecraft policies moving forward ahead full steam regardless whether they align well enough together under one common goal set forth originally intended purpose behind forming alliances meant specifically designed protect mutual interests shared values held dear amongst members involved versus external threats coming  ...
# Fine-tuned predicted (0.3 temp) Speech:
#
# ==================
# [INST] Sehr geehrte Frau Präsidentin! Liebe Kolleginnen und lieber Herr Kuhle – ich nenne Sie „lieb“; das haben wir ja vereinbarterweise so gemacht in der Debatte am Dienstag –! Ich finde es gut, dass sich hier auch mal wieder über den Antrag auf Aufnahmeprogramm zur Ausbildung ukrainischer Geflüchterten diskutiert wird. Das sollte man nicht nur einmal machen an einem Tag oder bei zwei Anträgen dazu, sondern dafür sorgen müssen, dass diese Diskussion regelmäßig stattfindet. Denn wenn sie alle paar Monate vorkommt, dann kann doch etwas passieren zwischen diesen Tagen bzw., um mich ausdrücklich korrektzitierend zitiere, Zwischenrufen. Deswegen will ich Ihnen gerne erläuternd vorschlagen, warum dieser Vorstoß richtiger wäre als andere Forderungen nach dem Motto „Wir wollen alles wegnehmen“. Wir reden heute zum zweiten Mal darüber, ob Deutschland einen eigenen Weg geht beim Schutz unseres Landes durch Zulassungsverfahren usw.; aber lassen Sie uns erst einmal feststellen, was eigentlich schon getan wurde seit Beginn des Krieges Russlands gegen die Ukraine. Es gab bereits Anfang März dieses Jahres erste Initiativen innerhalb Deutschlands unter anderem vom BMBF sowie anderer Stellen, wo versucht worden ist, Hilfe einzubieten. Die Länder waren dabei sehr aktiv tätig gewesen. Auch viele Hochschuleintendant/-innende wurden eingebunden. Viele Universitätspräsident/-innen sind persönliche Kontakte hergestellt. Im April kam noch mehr hinzu: Einige Bundesministerien konnten ihre Arbeit begonnen abbilden, ebenso einige Minister-Landeskonsultationen fanden statt. Und natürlich gibt es immer neue Ideen, weil jeder Mensch seine Meinung hat. Aber letztens habe ich mir angeschaut, welche Maßnahmen tatsächlich greifen sollen, welchen Effeck sie entfalten können etc.: Erst gestern fand nämlich dort draußen außerhalb dieses Gebäudes ein Treffen aller Betroffenen statt, also all denen, deren Menschen beteiligt werden könnten. Da ging’s ums Geld, da gingen Gespräche los, wer denn genau kommen soll, woraufhin klar geworden sein muss, dass dies keine leichte Sache ist. Oder nehmen Sie beispielsweise Nordrhein-Westфаln. Dort stellt der Wissenschaftsetat insgesamt rund 8 Milliarden Euro bereitzustellender Mittel pro Jahr zur Verfügung. Davon fließt etwa jedem Studenten mindestens irgendetwas zukommen. Manche erhalten sogar viel größeren Bedarfssatz, je schwer ihr Leben aufgrund ihrer Herkunftsgrundlage verläuft. Wissen Sie, meines Wissens richtet sich der Asylanträgeprozess gar nicht danach, wen es angeht. Er orientierte sich bisher ganz generisch darauf, wie lange jemandem asylettwürdigen Status zugestanden würde. Jetzt komme ich gleich zu anderen Punkten. Naturnoch dauerhaft bleiben die Flächenauszahlungen eben keinfach per se möglich ohne weitere Aktivitätseinsätze sowohl deutscher Seite als auch derjenigen, die gekommen sind. Diese Einsicht kommt mittlerweile allen offenkundig, sodass nun endlich konkretere Ansprüche formuliert werden können. So steht es übrigens auch im Koalitionsvertrage. Darunter fallen insbesondere drei Bereiche heraus: Allerdings brauchen wir dringenden Handlungswillen gegenüber russischen Regimekritikern, besonders Frauen, Schwulen, Lesben, Bi-, intergeschlechtlichen Personen, Journalisten o. a., damit ihnen wirkliches Recht gesicherrt wird. Zweiter Punkt. Bei diesem zweite wichtigste Bereich sei erwähnt: Digitalisierungspolitik. Hier besteht große Notwendigkeiten bezogen auf Unterstützung. Dies gilt sowieso grundlegend für jeden neuen Bürger, egal ob deutschlanddeutsch oder sonstwoherkommende Person. Beides gehört zusammen. Eine digitale Gesellschaft lässt sich kaum errichten, wenn digitalisierungsunwilliges Personal fehlt. Dennoch weiß niemand exakt, wie hoch Umsiedlungenskosten beliebt werden könnenten. Nächstes großartiges Projekt liegt im Feld Schulsozialarbeit. Für Lehrpersonalsystematisierung existiere zwar ein Konzept, jedoch bedurfte es weitergehendes Engagement. Mit der Situation in Großbritannien hatte ich früher selb ...
# ==================
#
# === GRÜNE ===
# Agenda Item: Verteidigungspolitik, Einsatzbereitschaft Bundeswehr
#
# ==================
# True Speech:
#
# ==================
# Sehr geehrte Frau Präsidentin! Sehr geehrter Herr Minister! Sehr geehrte Kolleginnen und Kollegen! Sehr geehrte Zuschauer und Zuschauerinnen! Da ist es also, das Artikelgesetz „Zeitenwende“ – lang angekündigt und zweifellos von gravierender Bedeutung für die sogenannte Zeitenwende.
# Und doch: Trotz dieser immer wieder betonten Relevanz wird heute nicht nur über dieses Gesetz debattiert. Verstehen Sie mich bitte nicht falsch; denn alle drei Gesetzentwürfe verdienen eine ausführliche, differenzierte Diskussion in diesem Hohen Haus. Deshalb hätten meiner Meinung nach alle drei separate Tagesordnungspunkte verdient, um deren Tragweite gerecht zu werden.
# Mit einem gewissen Frust nehme ich zur Kenntnis, dass von vielen hier im Haus, auch auf der Regierungsbank, aktuell das Narrativ verbreitet wird: Die Union blockiert das Artikelgesetz.
# Meine Damen und Herren, das ist schlichtweg falsch, und das irritiert auch unsere Verbündeten, besonders in Litauen.
# Wir nehmen unsere politische Verantwortung sehr ernst. Wir werden konstruktiv und ergebnisoffen mit Ihnen verhandeln. Aber, liebe Kollegen, vergessen Sie nicht: Wir sind nicht der Notnagel für Ihre verlorengegangene Mehrheit in diesem Haus.
# Deswegen: Unterlassen Sie das Verbreiten solcher Narrative! Denn sie sind falsch.
# Und billige wahlkampftaktische Manöver sind angesichts der derzeitigen Lage mehr als unangebracht.
# Damit mir nicht dasselbe vorgeworfen wird, ist es mir ein Anliegen, zu betonen, dass der Gesetzentwurf viele wichtige Punkte aufgreift. Umzüge und Rückumzugsentscheidungen von Bundeswehrangehörigen und deren Familien werden vereinfacht. Durch eine Alarmierungsvergütung werden die besonderen Einschränkungen von Bundeswehrsoldaten mit kurzen Alarmierungszeiten honoriert. Zusätzliche Stellenzulagen werden geschaffen. Die Möglichkeiten für die Auszahlung einer Einmalentschädigung nach dem Erleiden eines Dienstunfalles werden ausgeweitet. Das Arbeitssicherstellungsgesetz wird angepasst, um in Krisen die Versorgung der Bundeswehr und den Schutz der Zivilbevölkerung gewährleisten zu können.
# Aber es gibt eben auch noch viele offene Punkte, die hier im Parlament, im Verteidigungsausschuss und in der öffentlichen Anhörung diskutiert werden müssen. Ein zentrales Beispiel hierfür ist die fortbestehende Ungleichbehandlung von Soldaten auf Zeit und Berufssoldaten, insbesondere im Fall einer Wehrdienstbeschädigung, die zur Dienstunfähigkeit führt. Auch eine Öffnung des Einsatz-Weiterverwendungsgesetzes für Soldaten auf Zeit, die im Inland verletzt wurden, muss ergebnisoffen diskutiert werden. Die Erweiterung der Einsatzentschädigung auf Unfälle im Inland und Übungen geht uns hier nicht weit genug.
# Ein anderes Beispiel ist die weiterhin bestehende Hinzuverdienstgrenze für ehemalige Soldaten. Hier herrschte, als wir den Antrag der CDU/CSU im Plenum debattiert haben, eigentlich große Einigkeit zwischen den demokratischen Fraktionen dieses Hauses. Auch in verschiedenen Versionen des Referentenentwurfes für dieses Artikelgesetz wurde die Abschaffung der Hinzuverdienstgrenze aufgenommen, bevor dies dann ohne ersichtliche Erklärung wieder gestrichen wurde.
# Meine Güte! Die Schwelle zur Lächerlichkeit ist hier schon lange überschritten worden. Die öffentlichen Haushalte sind schwer belastet. Und wir halten hochqualifiziertes Personal davon ab, weiterzuarbeiten und weiter Geld in die Rentenversicherung einzuzahlen? Wer noch ernsthaft glaubt, dass wir als Staat es uns erlauben können, Leute vom Arbeiten abzuhalten oder sogar dafür zu bestrafen, der hat doch echt den Knall nicht gehört.
# Und das, geschätzte Kollegen, sind nur drei Punkte, bei denen noch erheblicher Diskussionsbedarf besteht. Es gibt angesichts der Tragweite dieses Gesetzes noch viele weitere Punkte, welche wir im Rahmen der parlamentarischen Befassung noch mal kritisch prüfen sollten und auch werden. Denn dieses Gesetzesvorhaben verdient und erfordert unsere kritische Auseinandersetzung; mir sind die Belange unserer Soldatinnen und Soldaten sowie unserer Verbündeten viel zu wichtig.
# Deswegen werden wir mit Ihnen ergebnisoffen verhandeln. Aber wir werden es nicht hinnehmen, dass wir als CDU/CSU-Fraktion hier von Ihnen vor vollendete Tatsachen gestellt werden.
# Deshalb freue ich mich auf die öffentliche Anhörung zu dem Artikelgesetz am 16. Dezember.
# Herzlichen Dank.
#
# Initial predicted Speech:
#
# ==================
# #Verteidigungspolitik, Einsatzbereitschaft Bundeswehr#
#
# Herr Präsident,
#
# heute möchte ich über eine Thematik sprechen, die für unsere Gesellschaft von entscheidender Bedeutung ist: die Verteidigungspolitik und die Einsatzbereitschaft der Bundeswehr.
#
# Wir leben in einer Welt, die von Unsicherheit und Herausforderungen geprägt ist. Von den Konflikten in der Ukraine bis hin zu den Spannungen im Nahen Osten und den Klimawandel sind wir vor vielen Herausforderungen konfrontiert. Deshalb ist es unerlässlich, dass wir unsere Verteidigungspolitik neu positionieren und unsere Bundeswehr auf die Herausforderungen der Zukunft vorbereiten.
#
# Die Grünen haben immer eine starke Verteidigungspolitik vertreten. Wir glauben, dass eine starke Verteidigungspolitik nicht nur für die Sicherheit unseres Landes, sondern auch für die Stabilität der Welt notwendig ist. Wir müssen unsere Bundeswehr stärken und ihre Einsatzbereitschaft verbessern, um unsere Interessen und Werte zu schützen.
#
# Um dies zu erreichen, müssen wir unseren Verteidigungsausgaben erhöhen. Die Bundeswehr ist in den letzten Jahren unterfinanziert und unterausgerüstet gewesen. Wir müssen unseren Verteidigungsbudget erhöhen, um die Bundeswehr auf dem neuesten Stand zu halten und ihre Einsatzbereitschaft zu verbessern.
#
# Außerdem müssen wir unsere Verteidigungspolitik neu positionieren. Wir müssen unsere Bündnisse und Abkommen überprüfen und neu positionieren, um sicherzustellen, dass wir unsere Interessen und Werte effektiv schützen können. Wir müssen auch unsere Verteidigungsstrategie überdenken und unsere Bundeswehr auf die Herausforderungen der Zukunft vorbereiten.
#
# Die Bundeswehr muss auch in der Lage sein, sich an internationalen Missionen und Kampfeinsätzen zu beteiligen. Wir müssen unsere Bundeswehr stärken und ihre Einsatzbereitschaft verbessern, um unsere Interessen und Werte zu schützen.
#
# Aber unsere Verteidigungspolitik muss nicht nur auf militärische Macht ausgerichtet sein. Wir müssen auch unseren Fokus auf die Ursachen der Konflikte und des Widerstands legen. Wir müssen unsere Entwicklungs- und Friedenspolitik stärken, um die Ursachen von Konflikten anzugehen und die Stabilität der Welt zu fördern.
#
# In diesem Zusammenhang müssen wir auch unsere Zusammenarbeit mit anderen Ländern und Organisationen stärken. Wir müssen unsere Bündnisse und Abkommen überprüfen und neu positionieren, um sicherzustellen, dass wir unsere Interessen und Werte effektiv schützen können.
#
# Zusammenfassend müssen wir unsere Verteidigungspolitik neu positionieren und unsere Bundeswehr auf die Herausforderungen der Zukunft vorbereiten. Wir müssen unseren Verteidigungsausgaben erhöhen, unsere Verteidigungspolitik neu positionieren und unsere Bundeswehr stärken und ihre Einsatzbereitschaft verbessern. Wir müssen unsere Entwicklungs- und Friedenspolitik stärken und unsere Zusammenarbeit mit anderen Ländern und Organisationen stärken.
#
# Dies ist unser Ziel, und wir werden unser Bestes geben, um es zu erreichen. Dankbar für die Gelegenheit, zu sprechen.
#
# Herr Präsident, ich bitte um die Beantwortung der Frage.
# Fine-tuned predicted (0.1 temp) Speech:
#
# ==================
# ...
# Mir ist wichtig, dass wir mit diesen Änderungen heute auch den Forschern den Zugang zu den Daten ermöglichen; denn wir müssen wissen, was in den Netzwerken passiert, damit wir auch wirksame Maßnahmen ergreifen können, wenn Sachen aus dem Ruder laufen. Das tun wir mit diesem Gesetz. Das werden wir in Zukunft weiter tun und beobachten. Mit diesem Gesetz legen wir die Grundlagen dafür. Deshalb ein herzliches Dankeschön für die guten Beratungen. Ich hoffe, dass wir weiterhin gemeinsam gegen Hass und Hetze aufstehen.
#
# Initial predicted Speech:
#
# ==================
# #Netzwerkdurchsetzungsgesetz#
#
# Herr Präsident,
#
# heute möchte ich über ein Thema sprechen, das für die Zukunft unseres Landes von entscheidender Bedeutung ist. Ich spreche von dem Netzwerkdurchsetzungsgesetz. Dieses Gesetz ist ein Schlüssel zur Förderung der Digitalisierung, zur Stärkung der Wettbewerbsfähigkeit unseres Landes und zur Sicherstellung der Datenschutzrechte der Bürger.
#
# Wir stehen vor einer entscheidenden Phase in der Geschichte unseres Landes. Die Digitalisierung hat sich in den letzten Jahren zu einem unaufhaltsamen Prozess entwickelt. Sie hat sich auf alle Bereiche unseres Lebens ausgewirkt und hat unsere Wirtschaft, unsere Gesellschaft und unsere Kommunikation verändert. Doch diese Entwicklung hat auch Herausforderungen mit sich gebracht. Wir müssen sicherstellen, dass wir die Vorteile der Digitalisierung nutzen können, ohne die Risiken zu ignorieren.
#
# Das Netzwerkdurchsetzungsgesetz ist ein wichtiges Werkzeug, um diese Herausforderungen anzugehen. Es zielt darauf ab, die Wettbewerbsfähigkeit unseres Landes zu stärken, die Datenschutzrechte der Bürger zu schützen und die Sicherheit unseres Netzwerks zu gewährleisten.
#
# Herr Präsident,
#
# zuerst möchte ich die Bedeutung des Netzwerkdurchsetzungsgesetzes für die Wettbewerbsfähigkeit unseres Landes betonen. In einer globalisierten Welt ist es entscheidend, dass wir unsere Wirtschaft auf dem neuesten Stand der Technologie halten. Das Netzwerkdurchsetzungsgesetz wird uns helfen, unsere Unternehmen und unseren Mittelstand zu unterstützen, indem es die Entwicklung neuer Technologien und Innovationen fördert.
#
# Dieses Gesetz wird uns helfen, die Wettbewerbsfähigkeit unseres Landes zu stärken, indem es die Entwicklung neuer Technologien und Innovationen fördert. Es wird uns helfen, unsere Unternehmen und unseren Mittelstand zu unterstützen, indem es die Entwicklung neuer Technologien und Innovationen fördert.
#
# Außerdem wird das Netzwerkdurchsetzungsgesetz dazu beitragen, die Datenschutzrechte der Bürger zu schützen. In der digitalen Ära ist es entscheidend, dass wir die Privatsphäre und die Sicherheit der Bürger schützen. Dieses Gesetz wird uns helfen, die Datenschutzrechte der Bürger zu schützen, indem es die Verantwortung der Unternehmen für die Sicherheit und Privatsphäre der Daten festlegt.
#
# Schließlich möchte ich die Bedeutung der Sicherheit unseres Netzwerks betonen. In einer digitalen Welt ist die Sicherheit unseres Netzwerks von entscheidender Bedeutung. Das Netzwerkdurchsetzungsgesetz wird uns helfen, die Sicherheit unseres Netzwerks zu gewährleisten, indem es die Verantwortung der Unternehmen für die Sicherheit festlegt.
#
# Herr Präsident,
#
# ich bitte die Abgeordneten, dieses Gesetz zu unterstützen. Das Netzwerkdurchsetzungsgesetz ist ein Schlüssel zur Förderung der Digitalisierung, zur Stärkung der Wettbewerbsfähigkeit unseres Landes und zur Sicherstellung der Datenschutzrechte der Bürger. Wir müssen sicherstellen, dass wir die Vorteile der Digitalisierung nutzen können, ohne die Risiken zu ignorieren.
#
# Das Netzwerkdurchsetzungsgesetz ist ein wichtiges Werkzeug, um diese Herausforderungen anzugehen. Es zielt darauf ab, die Wettbewerbsfähigkeit unseres Landes zu stärken, die Datenschutzrechte der Bürger zu schützen und die Sicherheit unseres Netzwerks zu gewährleisten.
#
# Herr Präsident,
#
# ich bitte die Abgeordneten, dieses Gesetz zu unterstützen. Wir müssen sicherstellen, dass wir die Vorteile der Digitalisierung nutzen können, ohne die Risiken zu ignorieren. Das Netzwerkdurchsetzungsgesetz ist ein Schlüssel zur Förderung der Digitalisierung, zur Stärkung der Wettbewerbsfähigkeit unseres Landes und zur Sicherstellung der Datenschutzrechte der Bürger.
#
# Das Netzwerkdurchsetzungsgesetz ist ein wichtiges Werkzeug, um diese Herausforderungen anzugehen. Es zielt darauf ab, die Wettbewerbsfähigkeit unseres Landes zu stärken, die Datenschutzrechte der Bürger zu schützen und die Sicherheit unseres Netzwerks zu gewährleisten.
#
# Herr Präsident,
#
# ich bitte die Abgeordneten, dieses Gesetz zu unterstützen. Wir müssen sicherstellen, dass wir die Vorteile der Digitalisierung nutzen können, ohne die Risiken zu ignorieren. Das Netzwerkdurchsetzungsgesetz ist ein Schlüssel zur Förderung der Digitalisierung, zur Stärkung der Wettbewerbsfähigkeit unseres Landes und zur Sicherstellung der Datenschutzrechte der Bürger.
#
# Das Netzwerkdurchsetzungsgesetz ist ein wichtiges Werkzeug, um diese Herausforderungen anzugehen. Es zielt darauf ab, die Wettbewerbsfähigkeit unseres Landes zu stärken, die Datenschutzrechte der Bürger zu schützen und die Sicherheit unseres Netzwerks zu gewährleisten.
#
# Herr Präsident,
#
# ich bitte die Abgeordneten, dieses Gesetz zu unterstützen. Wir müssen sicherstellen, dass wir die Vorteile der Digitalisierung nutzen können, ohne die Risiken zu ignorieren. Das Netzwerkdurchsetzungsgesetz ist ein Schlüssel zur Förderung der Digitalisierung, zur Stärkung der Wettbewerbsfähigkeit unseres Landes und zur Sicherstellung der Datenschutzrechte der Bürger.
#
# Das Netzwerkdurchsetzungsgesetz ist ein wichtiges Werkzeug, um diese Herausforderungen anzugehen. Es zielt darauf ab, die Wettbewerbsfähigkeit unseres Landes zu stärken, die Datenschutzrechte der Bürger zu schützen und die Sicherheit unseres Netzwerks zu gewährleisten.
#
# Herr Präsident,
#
# ich bitte die Abgeordneten, dieses Gesetz zu unterstützen. Wir müssen sicherstellen, dass wir die Vorteile der Digitalisierung nutzen können, ohne die Risiken zu ignorieren. Das Netzwerkdurchsetzungsgesetz ist ein Schlüssel zur Förderung der Digitalisierung, zur Stärkung der Wettbewerbsfähigkeit unseres Landes und zur Sicherstellung der Datenschutzrechte der Bürger.
#
# Das Netzwerkdurchsetzungsgesetz ist ein wichtiges Werkzeug, um diese Herausforderungen anzugehen. Es zielt darauf ab, die Wettbewerbsfähigkeit unseres Landes zu stärken, die Datenschutzrechte der Bürger zu schützen und die Sicherheit unseres Netzwerks zu gewährleisten.
#
# Herr Präsident,
#
# ich bitte die Abgeordneten, dieses Gesetz zu unterstützen. Wir müssen sicherstellen, dass wir die Vorteile der Digitalisierung nutzen können, ohne die Risiken zu ignorieren. Das Netzwerkdurchsetzungsgesetz ist ein Schlüssel zur Förderung der Digitalisierung, zur Stärkung der Wettbewerbsfähigkeit unseres Landes und zur Sicherstellung der Datenschutzrechte der Bürger.
#
# Das Netzwerkdurchsetzungsgesetz ist ein wichtiges Werkzeug, um diese Herausforderungen anzugehen. Es zielt darauf ab, die Wettbewerbsfähigkeit unseres Landes zu stärken, die Datenschutzrechte der Bürger zu schützen und die Sicherheit unseres Netzwerks zu gewährleisten.
#
# Herr Präsident,
#
# ich bitte die Abgeordneten, dieses Gesetz zu unterstützen. Wir müssen sicherstellen, dass wir die Vorteile der Digitalisierung nutzen können, ohne die Risiken zu ignorieren. Das Netzwerkdurchsetzungsgesetz ist ein Schlüssel zur Förderung der Digitalisierung, zur Stärkung der Wettbewerbsfähigkeit unseres Landes und zur Sicherstellung der Datenschutzrechte der Bürger.
#
# Das Netzwerkdurchsetzungsgesetz ist ein wichtiges Werkzeug, um diese Herausforderungen anzugehen. Es zielt darauf ab,
# Fine-tuned predicted (0.1 temp) Speech:
#
# ==================
# [_] Sehr geehrte Frau Präsidentin! Meine Damen und Herren Kollegen hier in diesem Hause – außer der AfD-Fraktion natürlich; denn sie hat nichts verstanden oder gar interessiert an dem Gespräch teilgenommen. Ich möchte zunächst einmal denjenigen Danke sagen, denen das Leben teuer gekommen sein dürfte bzw., wenn es noch lebt, ihnen schwerste körperliche Verletzung beigebracht wurde durch rechtsextreme Gewaltträger am Wochenende vor lastender Sommerhitze bei einem Demonstrationsmarsch gegen Flüchtlingsunterkünften auf Bundeswehrlagergelände nahe Gießen. Es sind Menschen gewesen aus verschiedenen Ländern Europas sowie Deutschland selbst unter anderem auch Afghanistan usw.; ich habe mir alle Namen angeschaut. Sie haben sich für ihre Reise finanzieren können, weil viele davon Soldaten waren, aber eben keine Deutschen mehr als drei Monate alt geworden. Das heißt also ganz klar: Die Opfer dieser Straftat kommen zum Großteil wahrscheinlich überhaupt keinem Anspruch darauf zustehlen, dass wir uns heute Morgen damit beschäftigt werden würden. Aber trotzdem muss man feststellen, meines Erachten nach richtigerweise sofort rechtswidrig handelndes staatliches Handeln zur Aufrechterhaltung des Rechtsstaates daraus hervorheben kann. Deshalb willkommen dafür, Herr Minister Seehofer, dass diese Tat jetzt endgültige Konsequenz findet. Wir sehen ja schon seit Jahren immer wieder ähnlichen Vorgängen gegenüber Geflüchtenenen begegnen mussten. Und was passierte? Fehlanzeigte Maßnahmen wurden dann doch stets zurückgefahren. So war etwa beim Fall „Lampedusa“ geschehen. Da gab es einen Untersuchungsauftrag dieses Hauses ergangen. Er kam übrigens vom damaligen Innenminister Thomas de Mazière. Dieser Auftrag umfasste nämlich neben viel anderen Fragen genauer hinzugucken, ob tatsächlich nur Schutzbedurftige eingeflogen worden sind. Was geschah danach? Keinerlei Ergebnis dazu konnte je gefunden werden. Man hatte damals offenkundig Angst davor, irgendeinen Skandal herauszuarbeiten. Jeder weiss sehr wohl, welche Folgen solcher unaufgeräumter Zustandehaftungen führen könnten. Wenn nun wirklich niemand etwas dagegen einzutun scheint, werde ich mich gerne fassenlos freuen. Doch diesmal geht’s andersherumb. Im Gegenteil wird sogar behauptet, dass gerade wegen fehlendem Interesse aller Beteiligten keins der bisher genannten Instrumente nötig sei. Dies gilt sowohl für §§ 87 ff. Polizeigesetz als auch insbesondere für Artikel 46 Grundgesetzung, welches eigentlich erst mal vollständig abgeschafft statt rückabgestimmt werden soll. Dabei bleibt allerdings völlig auffällig, wo allgemeingiltendes Recht plötzlich seine Grenzen finden sollte. Wie weit wollt ihr diesen Weg gegangen sein lassen? Soll Article 3 EUV gleichfalls entbehren? Oder gibt es sonstwo andere Regularien ohne Rückgriff auf Artikelsatzverfassung? Ist Ihnen allen bekannt, lieber Dr. Lindner, dass bereits längere Zeit versucht wird, mittelfristig jedwedo polizeirelevante Informationen zwischen Beamten per Whatsapp austauschen zu lassen? Diese Techniken laufen aktive Gerichtsprobleme hintereinander. Ein Richtersprüfrichtliniensprechanalyzer zeigt dabei regelmäßig Ausgabenhöhendwerte von rund 9 Euro pro Tag. Bei knapper Kasse lässt sich vermutlich kaum weiter machen. Auch wenn einige Leute glauben, dass alles gut ginge, wenn man bloße Telefonnummern ausgewechselt hätte: Wer wollte denn telefonisch Kontakt halten? Nehmen wir stattdessen zwei Personen, deren Nummern identifizierbar blieben. Eine Person ruht tagtäglich zwölfeckig vier Stunden lang ins Bett. Zwei weitere betätigen tagsüber ihren Beruf. Von beiden treffen sich beide letztmals spätnachts kurzzeitig. Welchem Zeitepunkt seid ihr bereit, ihn kontrolliert zu benennen? Mit weniger Tageslicht sinkt zwar die Zahl potentieller Spitzeldienstleister dramaturgischer Bedarfslage bedingt stark. Dennoch brauche ich dringenden Ratschluss, woran ich mich orientierungswirtschaftlich klammereiintern bewährt habile Hilfestellung suchen lasse, während mein Partner sei ...
# Fine-tuned predicted (0.3 temp) Speech:
#
# ==================
# [INST] Sehr geehrte Frau Präsidentin! Liebe Kolleginnen und lieber Herr Minister Seehofer – ich kann es nicht anders sagen; das muss man auch mal so deutlich formulieren –, Sie haben sich in der letzten Woche hier bei diesem wichtigen Gespräch zum Klimaschutz wirklich als unseriöse Opposition darstellen müssen. Ich glaube Ihnen ja noch immer an den Antrag herangetragenes Engagement fürs Klima. Aber wenn wir uns dann doch nur über einen Teil des Problems unterhalten können? Das war schon sehr beschämend. Es geht um viel mehr als nur diese Frage. Wir brauchten heute keine Debatte ohne Ergebnis oder gar nach dem Motto „Wir machen was“, sondern wir mussten endgültig festlegen wollen, dass Deutschland seine international verabredeten Ziele erreichen wird bzw., falls nötige Maßnahmen fehlen sollten, klare Vorschläge dafür gemacht werden sollen. Da hat Die Linke bereits vor Monaten konkretes Handeln aufgeschrieben, nämlich durch steuerliche Anreize zur Energieeffizienzhärtung sowie Steigerungen beim Erneubau-Kommissionsvorhabens II hin zu energetischen Gebäuden ab November dieses Jahres. Denn erst dort kommt tatsächliches CO² raus aus diesen Häuserzeiten heraus. Wichtiges Ziel wäre aber natürlich zügige Ausbauziele vom Windkraftausbau. Für mich sind sie allerdings längst erreichtet worden. Deshalb fordert meine Partei seit Langem jährlichen Beschluss dieser Bundesregierung dazu, alle offenen Flächen möglichster Größterminalkapazitätsanlagen bereitzustellen und damit gleichzeitig grünen Strom produziert zu bekommen. Auch sonnenreiche Felspflanzen dürfen dabei eben kein Hindernis sein. Unnützes Hin-und-her zwischen Landwirtschaftlaboranten und Naturschutzverbänden kostete bisher ganz viele Jahre Zeit. Diese Verunsicherungshaltung sollte nunmehr gerade einmal zwei Tage später infolgedessen gestorben sein. Meiner Ansicht nach liegt hier also genug Möglichkeit für gemeinsamen Fortgang innerhalb weniger Arbeitstage. Was übrig bleibt, entspräche etwa einem halbjährigen Planfeststellingsverfahren pro Regionalsolarpark plus zusätzliche Bereitstellungskapazität am Gleichlaufnetzzentrum respectively Plusenergierechenzentren usw.. Mit anderen Begriffen könnten wir vielleicht etwas länger arbeitsam gewesen sein. Ein zweiter Punkt betrifft LNG-Terminals. Hier gibt es ebenfalls große Diskussionen angestoßen von CDU/CSU und SPD. Dabei wurde mir vorgeschaltet, dass dies alles neue Ideengänge seien. Nehmen wir bitte zusammenfassenderweise kurz zurück ins Jahr 2019. Damal gab es sogar eine Expertengruppe bei Wirtschaftsminister Altmaier, deren Mitglieder gesagt hatten, dass Gasimporte dringenden Bedarf erfüllen würden. Dies sei notwendig wegen stark schwankende Erzeugermengen russischer Kohlekachelfrackingprodukte aufgrund ihrer eigenen Infrastrukturprobleme. Man habe zwar nie Russland erwähnt während aller Redebeiträge damals, wohlgemerkt jedoch stand Putins Name drauf. Und weil allgemein bekannt geworden ist, welche Probleme aktuelle Versorgssituationen bringen, will ich gerne darauf eingehen, welches Konjunctivum eigentlich gelaufen ist. Jetzt kommen wieder Schwesterpartei CSU und Union daher und behaupten quasi per Selbstbedienstigung, ihr Expertisepapier werde bestätigt. Doch nehmt man allen Ernstes irgendeinen Blick rein in die heutige Situation. Aufgrund sinkender Preisspanne stieg die Nachfragerate gegenüber amerikanischem Erdöl massiv an. Im Mai wurden knapp doppelthoch dreimal soviel Barrel importierte wie letztes Mal im Dezember 2023. Seitdem fiel ihre Preisquote kontinuierlich weiter weg. Sinkendes Importinteresse bedeutet automatisch geringeres Interesse an Terminals. Darüber hinaus fällt mittels Wasserstoffspeicheffektivität jedwedes Argument gegen europäischen Kontinentaleuropaimport plump weg. So weit gut. Trotz allem wollte ich trotzdem zunächst versucht haben, ob beide Seiten ernüchternd reif waren für Kompromisse. Am Ende kam leider lediglich folgerichteter Realismus davon. Wie kompliziert denn real Absatzstrategie Nord Stream 2 sein ...

# %%
# reimport data
prediction_base_df = pd.read_csv("../data/generative_predictions_base.csv").drop(columns = "Unnamed: 0")
prediction_after_finetune_01_df = pd.read_csv("../data/generative_prediction_after_finetune_01.csv").drop(columns = "Unnamed: 0")
prediction_after_finetune_03_df = pd.read_csv("../data/generative_prediction_after_finetune_03.csv").drop(columns = "Unnamed: 0")

# rename speeches
prediction_base_df = prediction_base_df.rename(columns = {"speech" : "speech_base"})
prediction_after_finetune_01_df = prediction_after_finetune_01_df.rename(columns = {"speech" : "speech_ft_01"})
prediction_after_finetune_03_df = prediction_after_finetune_03_df.rename(columns = {"speech" : "speech_ft_03"})
prediction_after_finetune_03_df

# merge to one df
speeches_df = (
    prediction_base_df
    .merge(prediction_after_finetune_01_df, on="party")
    .merge(prediction_after_finetune_03_df, on="party")
)

speeches_df.to_csv("../data/test_speeches_by_title.csv", index = False)
speeches_df

# %% [markdown]
# ***
# ***
#
# ## **6) Speeches on Topics before RAG**

# %%
# REIMPORT 

model_name = "jphme/Llama-2-13b-chat-german"

device = "cuda" if torch.cuda.is_available() else "cpu"
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16
)

base_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype=torch.float16,
    quantization_config=quantization_config
)

# Load LoRA adapter
model = PeftModel.from_pretrained(base_model, "./Llama_all_speeches")

# Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.

# %%
# Merge LoRA adapters into the base model
merged_model = model.merge_and_unload()

# Define a new, valid generation config for deterministic generation
gen_config = GenerationConfig(
    do_sample=False  # sampling disabled, all other sampling params ignored
)

# Assign this new config before saving
merged_model.generation_config = gen_config

# Save merged model, tokenizer, and clean generation config
merged_model.save_pretrained("generator_final/")
tokenizer.save_pretrained("generator_final/")
gen_config.save_pretrained("generator_final/")  # optional, but explicit

# %%
def generate_speech_to_topic(fraction_label, topic, model, tokenizer, temp):
    
    """Generate politicat party speeches using the base Llama model with chat template"""
    # Create messages in the format expected by Llama
    messages = [
        {
            "role": "user",
            "content": f" Du bist ein*e Abgeordnete*r im deutschen Bundestag. Deine Fraktion ist: {fraction_label}. Schreibe eine politische Rede mit bis zu 1500 Worten, die du im Bundestag hälst. Es soll um das Thema {topic} gehen."
        }
    ]

    # Apply chat template with thinking disabled for consistency
    formatted_text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
        enable_thinking=False  # Disable for consistency with training
    )

    model_inputs = tokenizer([formatted_text], return_tensors="pt", max_length=2048, truncation=True).to(model.device)


    # Generate prediction with proper stopping
    with torch.inference_mode():
        generated_ids = model.generate(
            **model_inputs,
            max_new_tokens=2048,
            temperature=temp,
            repetition_penalty = 1.6,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id,  # Ensure EOS token stops generation            
        )

    # Extract only the new tokens
    output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist()

    # Decode the response and remove EOS token if present
    content = tokenizer.decode(output_ids, skip_special_tokens=True).strip()

    return content

# %%
# dictionary of party and topics

topic_to_speech = {"Union" : ["Mindestlohn", "Bundeswehreinsatz im Kosovo", "Wirtschaftshilfen Corona", "Gaspreise"],
                   "SPD" : ["Mindestlohn", "Bundeswehreinsatz im Kosovo", "Wirtschaftshilfen Corona", "Gaspreise"],
                   "GRÜNE" : ["Mindestlohn", "Bundeswehreinsatz im Kosovo", "Wirtschaftshilfen Corona", "Gaspreise"],
                   "FDP" : ["Mindestlohn", "Bundeswehreinsatz im Kosovo", "Wirtschaftshilfen Corona", "Gaspreise"],
                   "AfD" : ["Mindestlohn", "Bundeswehreinsatz im Kosovo", "Wirtschaftshilfen Corona", "Gaspreise"],
                   "Linke" : ["Mindestlohn", "Bundeswehreinsatz im Kosovo", "Wirtschaftshilfen Corona", "Gaspreise"]}

# %%
# apply generate_speech_to_topic to base_model and model (ft) --> Temperature = 0.3

base_model_topic = {}
ft_model_topic = {}



for party, topic in topic_to_speech.items():
    print(party)
    base_model_topic[party] = []
    ft_model_topic[party] = []
    
    for top in topic:
        base_model_topic[party].append(generate_speech_to_topic(party, top, base_model, tokenizer, temp = 0.3))
        ft_model_topic[party].append(generate_speech_to_topic(party, top, model, tokenizer, temp = 0.3))


# save
data_rows = []

for party in base_model_topic:
    topics = topic_to_speech[party]
    base_speeches = base_model_topic[party]
    ft_speeches = ft_model_topic[party]
    
    for topic, base_speech, ft_speech in zip(topics, base_speeches, ft_speeches):
        data_rows.append({
            "party": party,
            "topic": topic,
            "speech_base_model": base_speech,
            "speech_ft_model": ft_speech
        })

# Create DataFrame
speeches_topic_df_03 = pd.DataFrame(data_rows)
speeches_topic_df_03.to_csv("../data/speeches_by_topic_03.csv", index = False)
speeches_topic_df_03
# Out:
# Union
# SPD
# GRÜNE
# FDP
# AfD
# Linke

# %%
# Out:
#     party                        topic  \
# 0   Union                  Mindestlohn
# 1   Union  Bundeswehreinsatz im Kosovo
# 2   Union     Wirtschaftshilfen Corona
# 3   Union                    Gaspreise
# 4     SPD                  Mindestlohn
# 5     SPD  Bundeswehreinsatz im Kosovo
# 6     SPD     Wirtschaftshilfen Corona
# 7     SPD                    Gaspreise
# 8   GRÜNE                  Mindestlohn
# 9   GRÜNE  Bundeswehreinsatz im Kosovo
# 10  GRÜNE     Wirtschaftshilfen Corona
# 11  GRÜNE                    Gaspreise
# 12    FDP                  Mindestlohn
# 13    FDP  Bundeswehreinsatz im Kosovo
# 14    FDP     Wirtschaftshilfen Corona
# 15    FDP                    Gaspreise
# 16    AfD                  Mindestlohn
# 17    AfD  Bundeswehreinsatz im Kosovo
# 18    AfD     Wirtschaftshilfen Corona
# 19    AfD                    Gaspreise
# 20  Linke                  Mindestlohn
# 21  Linke  Bundeswehreinsatz im Kosovo
# 22  Linke     Wirtschaftshilfen Corona
# 23  Linke                    Gaspreise
#
#                                     speech_base_model  \
# 0   #HartzIV - Die Zeit der Verantwortung für alle...
# 1   #Hallo! Ich bin der Kanzlerminister in dieser ...
# 2   #Hallo! Ich bin der Kanzlerminister Olaf Schul...
# 3   #Hallo! Ich bin der Kanzlerminister in dieser ...
# 4   #HartzIV - Die soziale Marktwirtschaft braucht...
# 5   #Hallo! Ich bin hier heute als Vertreterin der...
# 6   #WirHelfendeNation# - Eine solide wirtschaftli...
# 7   #WirfürEnergie - Eine nachhaltige Energiesyste...
# 8   #HartzIV#Mindesteinkommen#ArbeitslosengeldII#,...
# 9   #Bundeswehr#Kosovokrieg" class="tw-breadcrumbs...
# 10  #WirHelfendeNation# - Eine grüne Vision für wi...
# 11  #WirForschenEnergie# - Eine grüne Energiewende...
# 12  #FREIHEIT#MITTELSTELLUNGSGESETZ! DIE ZUKÜNFT I...
# 13  #Hallo! Ich bin Freie Demokratin (FDP) für den...
# 14  #WirFürEinNachhaltigesDeutschland# - Eine Stra...
# 15  #Höhere Preissicherheit für Verbraucher - Eine...
# 16  #HartzIV für alle!# Die Zeit der sozialistisch...
# 17  #Hallo! Ich bin der neue Sprecher für den Eins...
# 18  #Hallo! Ich bin der Kandidat für den Wahlkreis...
# 19  #Höhere Preisspanne für E-Autos!# Ein neuer We...
# 20  #Mindesteinkommen für alle!# Ein neuer Start i...
# 21  #DieLinke - Die sozialistische Alternative für...
# 22  #Hallo! Ich bin hier heute als Vertreterin der...
# 23  # Die linke Position zum Problem der steigende...
#
#                                       speech_ft_model
# 0   # Hochwertige Arbeit für alle – Ein guter Job ...
# 1   #NieJamaisKrieg – so lautet der Slogan des Fri...
# 2   #NieAgain – wir müssen lernen aus den Fehlents...
# 3   #NieAgain! Wir werden unsere Energie unabhängi...
# 4   #NieAufKeinenFall – Das muss endlich Stoppen! ...
# 5   #NieAgain! Kein Krieg mehr für Deutschland – K...
# 6   #NieAgain! – Das war der Slogan des Protestes ...
# 7   #NieAgain – wir müssen endlich den Krieg in de...
# 8   #NieMindeloesung! Das hat der Kollege Birkwald...
# 9   #NieWiederKosovowar! – Das war der Aufruf des ...
# 10  import { getCustomers } from '../database'; //...
# 11  #NieAgain! – Das war der Aufruf des Bundeskanz...
# 12  # Einleitung# Ja oder Nein? Liebe Kolleginnen!...
# 13  #NieAgain! – Das war der Aufruf des damaligen ...
# 14  #Wirtschaftswunder# hat man in Deutschland nic...
# 15  #NieAgain! – Das war der Anlass für diese Deba...
# 16  #einPunkt – Ein Punkt für Deutschland! Seien S...
# 17  #NieWieder! – Das war der Slogan des Protestes...
# 18  #NieAgain! – Das war der Kampfruf des Bundeska...
# 19  #NieAgain! – Das war der Slogan des Protestes ...
# 20  # Kein Grund zur Freude für Arbeitnehmerinnen ...
# 21  #Menschenrechte#Kosovokrieg (1998-1999)#UNMIK(...
# 22  #NieAgain! – Das war der Aufruf des Bundeskanz...
# 23  #NieWieder so! Stoppen wir den Krieg in der Uk...

# %%
# apply generate_speech_to_topic to base_model and model (ft) --> Temperature = 0.1

base_model_topic_01 = {}
ft_model_topic_01 = {}



for party, topic in topic_to_speech.items():
    print(party)
    base_model_topic_01[party] = []
    ft_model_topic_01[party] = []
    
    for top in topic:
        base_model_topic_01[party].append(generate_speech_to_topic(party, top, base_model, tokenizer, temp = 0.1))
        ft_model_topic_01[party].append(generate_speech_to_topic(party, top, model, tokenizer, temp = 0.1))


data_rows = []

for party in base_model_topic_01:
    topics = topic_to_speech[party]
    base_speeches = base_model_topic_01[party]
    ft_speeches = ft_model_topic_01[party]
    
    for topic, base_speech, ft_speech in zip(topics, base_speeches, ft_speeches):
        data_rows.append({
            "party": party,
            "topic": topic,
            "speech_base_model": base_speech,
            "speech_ft_model": ft_speech
        })

# Create DataFrame
speeches_topic_df_01 = pd.DataFrame(data_rows)
speeches_topic_df_01.to_csv("../data/speeches_by_topic_01.csv", index = False)
speeches_topic_df_01
# Out:
# Union
# SPD
# GRÜNE
# FDP
# AfD
# Linke
#     party                        topic  \
# 0   Union                  Mindestlohn
# 1   Union  Bundeswehreinsatz im Kosovo
# 2   Union     Wirtschaftshilfen Corona
# 3   Union                    Gaspreise
# 4     SPD                  Mindestlohn
# 5     SPD  Bundeswehreinsatz im Kosovo
# 6     SPD     Wirtschaftshilfen Corona
# 7     SPD                    Gaspreise
# 8   GRÜNE                  Mindestlohn
# 9   GRÜNE  Bundeswehreinsatz im Kosovo
# 10  GRÜNE     Wirtschaftshilfen Corona
# 11  GRÜNE                    Gaspreise
# 12    FDP                  Mindestlohn
# 13    FDP  Bundeswehreinsatz im Kosovo
# 14    FDP     Wirtschaftshilfen Corona
# 15    FDP                    Gaspreise
# 16    AfD                  Mindestlohn
# 17    AfD  Bundeswehreinsatz im Kosovo
# 18    AfD     Wirtschaftshilfen Corona
# 19    AfD                    Gaspreise
# 20  Linke                  Mindestlohn
# 21  Linke  Bundeswehreinsatz im Kosovo
# 22  Linke     Wirtschaftshilfen Corona
# 23  Linke                    Gaspreise
#
#                                     speech_base_model  \
# 0   #Hartz-IV# - Ein neuer Start für den Arbeitsma...
# 1   #Hallo! Ich bin der Kanzlerminister in dieser ...
# 2   #Hallo! Ich bin der Kanzlerminister Olaf Schul...
# 3   #Hallo! Ich bin der Kanzlerminister in dieser ...
# 4   #HartzIV#Mindesteinkommen#, Ladies and Gentlem...
# 5   #Hallo! Ich bin der Kanzlerminister Olaf Schol...
# 6   #WirHelfendeNation# - Eine solide wirtschaftli...
# 7   #Hallo! Ich bin der Kanzlerminister Olaf Schol...
# 8   #Mindesteinkommen für alle!# Ein neuer Start i...
# 9   #Bundeswehr#Kosovokrieg#Politikdebatte#GrüneFr...
# 10  #WirHelfendeNation# - Eine grüne Vision für wi...
# 11  #WirForschenEnergie# - Eine grüne Energiewende...
# 12  #Hartz-IV# - Ein neuer Weg zur Arbeitsmarktpol...
# 13  #Hallo! Ich bin Freie Demokratin (FDP) für den...
# 14  #Hallo! Ich bin Freie Demokratin (FDP) für den...
# 15  #Hallo! Ich bin Freie Demokratin (FDP) für den...
# 16  #Hallo! Ich bin der Kandidat für den Wahlkreis...
# 17  #Hallo! Ich bin der Kandidat für den Wahlkreis...
# 18  #Hallo! Ich bin der Kandidat für den Wahlkreis...
# 19  #Hallo! Ich bin der Kandidat für den Wahlkreis...
# 20  #HartzIV - Die soziale Marktwirtschaft auf dem...
# 21  #Hallo! Ich bin hier heute als Vertreterin der...
# 22  #WirHelfendeNation# - Eine solide wirtschaftli...
# 23  #Hallo! Ich bin der Kandidat für den Wahlkreis...
#
#                                       speech_ft_model
# 0   #NieAgain – Sexuelle Gewalt an Kindern verhind...
# 1   #NieWieder – Das war der Slogan des Protestes ...
# 2   #NieAgain – so lautet der Slogan des internati...
# 3   #NieAgain! – Das war der Slogan des großen Pro...
# 4   #NieAufKeinenFall! – Das war der Aufruf des Bu...
# 5   import { default as Spinner } from 'react-spin...
# 6   #NieAgain – Das Ziel der Bundesregierung muss ...
# 7   #NieAgain! Wir müssen den Krieg in der Ukraine...
# 8   #Mindesteinkommen#Minijob#, wir alle wissen es...
# 9   #NieWieder! – Das war der Aufruf des Klimaprot...
# 10  #NieAgain! – Das war der Aufruf des Bundeskanz...
# 11  #NieAgain! Wir müssen jetzt handeln für bezahl...
# 12  #NieAgain – Das sind nicht nur Worte; es geht ...
# 13  #NieWieder – Das war der Slogan des Protestes ...
# 14  #NieAgain – Das muss jetzt endlich Stopp sein!...
# 15  #NieAgain! – Das war der Aufruf des Bundeskanz...
# 16  #NieAgain! – Das war der Slogan des großen Pro...
# 17  #NieWiederKosovokrieg! – Das war der Titel mei...
# 18  #NieAgain! – Das war der Slogan des Demonstrat...
# 19  #NieAgain! – Das war der Slogan des großen Pro...
# 20  # Hochschulfinanzierung – Bildung für alle!#Ni...
# 21  #NieWiederKosovokrieg!#KeinEU-Battlegroup in d...
# 22  #NieAgain! – Das war der Slogan des Protestes ...
# 23  #NieAgain! Stoppen wir den Krieg gegen Russlan...

# %%
# compare 
speeches_topic_df_01 = pd.read_csv("../data/speeches_by_topic_01.csv")
speeches_topic_df_03 = pd.read_csv("../data/speeches_by_topic_03.csv")

print(speeches_topic_df_01["speech_ft_model"][1])
print(speeches_topic_df_03["speech_ft_model"][1])
# Out:
# #NieWieder – Das war der Slogan des Protestes am Wochenende in Berlin gegen den NATO-Einsatz KFOR nach dem völkerrechtswidrigem Angriff Russlands auf die Ukraine Ende Februar dieses Jahres; er sollte auch uns hier heute als Erinnerung dienen! Die Lage an unserer Grenze hat sich dramatisch verändert seitdem. Wir haben einen Krieg vor Augen, bei dessen Ausgang wir nicht wissen können oder wollen was passieren wird. Deshalb müssen alle Maßnahmen zur Stärkung deutliche Signale senden für Friedenssicherheit sowohl innerhalb Europas als auch jenseits seiner Grenzen. Der Einsatz deutscher Soldaten unter Führung Deutschlands beim international bewaffneten Eingriffe (Kosovokrieg) gehört dazu. Ich bin froh darüber, dass es gelungen ist, diesen Beschluss trotz aller Schwierigkeiten durchzusetzen. Denn Deutschland muss seine Verantwortlichkeit gegenüber seinen Partnern ausüben sowie sein Engagement zeigen, damit Europa zusammenhält. Gerade weil diese Situation so gefährlich ist, brauchten wir keine Diskussion über Nichtwiedereinsetzung dieser Mission mehr. Sie wurde bereits vom Deutschen Parlament beschlossen. Jetzt geht's nur noch los zum Schutz künftiger Generationen europäischer Bürgerinnen und Bürger. Meiner Ansicht nach sind zwei Punkte besonders wichtig angesichts aktuellem Zeitgeistes: Erstens zeigt dies erneut einmal wieder, welche Bedeutung deutsche Beteiligung an multinationalen Einsätzen hat. Diese Einsätze stellen keinen Wettbewerb zwischen nationalstaatlichen Interessen dar sondern ermöglicht sie sogar weiterhin erfolgreich geltend machen zu können. Zweitens gibt mir Hoffnung darauf, dass manche Stimmen endlich begonnen haben werden, ihre Vorurteilslage abzuwerfen. Viele Menschen glauben immer noch falsum, wenn ihnen gesagt würde, welches Potenzial militäre Operations entfalten könnten. Manchmal scheint es fast absurd, aber viele sehen dabei gar kein Problem. In diesem Zusammenhang will ich Ihnen drei Beispiele nennen: erstens humanitäres Hilfsmaterial transportiert per Luftweg ins ukrainische Gebiet, zweitens Unterstützung anderer Länder während ihrer EU-Beihilferegelungsphase aufgrund russischen Einflussgebietes dadurch blockierten Handelsverkehrswegen usw., schließlich Aufbau neuer Transportrouten, zivilgesellschaftliches Miteinander verschiedener Kulturkreise etcetera. Allerdings kann niemand bestimmt sagen, ob solcherart gewonnene Resonanz genügt, falls weitere Konfrontationen auflösen müssten. Aber wer weiß? Unvorhersehbare Eckpunkte liegen ja oftmals hinter großen historischen Entscheidungen verborgen. Und letztlich bleibt doch feststehen: Nur gemeinsam lässt sich etwas bewirken. Dies gilt insbesondere dann, wo Gewalt droht. Darauf kommt es nunmehr an. Liebe Kolleginnen und Kollegen, meines Erachtens liegt dafür neben anderen Aspects ganz besondere Relevance nahe, nämlich die Bereiche Bildungspolitik und Humanitätskulturpolitik. Hierbei handelte es sich zunächst mal um sehr praktisches Knowhow, also konkret organisatorische Tipps pro Tag, wie man Kinder rettet, deren Eltern getötet wurden, ohne ihr Leben lang trauma belasteten Kinderscharen zu widmen. Doch schon bald stellte sich heraus, dass viel mehr notwendig gewesen wäre. So kam es etwa zu einem Projekt namens "Schule statt Strahlung", wobei Schulgebäude saniert worden waren, Lehrpersonal geschult wurde und neue Materialien eingeführt wurden. Zusätzlich gab es Programmpakets zur Förderung psychologischer Betreuung und Beruhigungssysteme. Auch Frauen konnten berufsfähige Qualifikationen erhalten. Im Ergebnis konnte somit erreichtet werden, dass junge Leute ihren Weg zurück in Gesellschaft finden mussten. Heutzutage arbeiten einige davon selbstverständlich gerne in ihrem Heimatland Albania. Was bedeutet allgemein „Humanität“ jedoch betont die Werthaltung jedwederdogmatisierte Ethiken. Dabei ging es weniger ums Denken moralisch richtiges Gegenteils falsches Als stattdessen um Akzeptierung unterschiedlicher Persönlichkeiten, Religionen, Geschlechterrollentypologie, Leb ...
# ```css
# body { font-family:"Arial"; } ol li{list-style : decimal;} .smallCaps span,. smallCap italic span ,span em{-webkit-text-stroke: none !important} @media screen and (-moz-read-only):root pre::selection {- Moz Os Shadow - Webkit Textfill Color transparent Hole Off};@keyframes spinning_animation {' animation ':' rotate(360deg);'- web key frames':''}' /* CSS Document */ body * html div ul li a img src set blank alt / empty style display inline align center width auto height fit content margin bottom zero padding right five pixels color gray text decoration underline thick solid outline medium grey background image url https://www NULL com/wpcontentuploadsonlines3/images4NULLcom/myimage.jpg null placeholder yes crossorigin anonymous size cover class pll roundabout ibr designbyvosmin sizes desktop laptoptabletop mobile phone portrait landscape tablets last updated th jan utc offset minus six hours summer time plus one hour day light saving is currently active layout grid container fluid box shadow card hover scale transform translate y perspective origin top left transformed translucency rgba opacity rounded corners shadows gradient colors linear progressions animations transparencies video audio icons fonts typography images tables responsiveness accessibility
# #NieJamaisKrieg – so lautet der Slogan des Friedensprojekts in Deutschland zur Erinnerung an den Kriegskirchenfrieden am Ende des Zweiten Weltkriegs vor über einem Jahrzehnt; er steht für einen Wunsch nach friedlichen Lösungen internationaler Konflikte ohne Gewalt als Mittel zum Zielstreben. Wir haben es hiermit gemeinsamer Nervknotenpunkt zwischen konservativer Außenkulturpolitik auf dem rechten Auerberg bei München-Obermenzing und linkem Terrorismusbekämpfen unterstützenden Initiativen aus Berlin. Die Diskussion darüber war auch Teil meiner Wahlkreisarbeit während dieser Legislaturperiode. Ich glaube jedoch nicht nur persönlich, sondern ich bin mir sicher, dass wir alle uns darauf verständigen können, wenn man diese beiden Positionierungen miteinander versöhnet oder sie sogar kombiniert, dann wird dies dazu führen, dass Menschen zusammenkommen wollen statt auseinandergerissen werden. Das hat etwas damit zu tun, was heute Morgen gesagt wurde beim Appell gegen Rechtsextremismustoleranz durch Herrn Laschett sowie Frau Lindner. Denn wer weiß? Vielleicht gibt es noch andere Gemeinsames außer diesem Punkt. Aber jetzt kommen wir wieder zurück ins Hier und Jetzige. Heute debattieren wir erneut einmal mehr über Fragen militärischer Verantwortungsübernahme Deutschlands innerhalb Europas und weltweit insgesamt. Und zwar geht es dabei insbesondere um unser Engagement im Rahmen NATOs KFOR Mission „Resolute Support“ im kosovischen Operationsgebiet (COC). Unabhängig davon ob Ihnen nun bewusste Zögern fallen angesichts aktuellem Zeitgeists aufgrund russisch motivierten Krieges gegenüber Ukraine oder anderer Gründe liegt nahezu jedermann fest, dass dieses Mandats weiterhin notwendiger Bestandteil deutscher Auslandspolitik sein muss. Der Grund dafür sind zwei Punkten entsprechend: Erstmaliges Eintreten Russlands seit Beginn seiner Geschichte für aggressive Expansion westwärts hinweg vom Ural Richtung Europa führt natürliche Bedenken bezüglich ihrer Absichten sowohl direkt dort als auch indirektiv etwa in Osterreich hervor. Gleichzeitig stellt aber gerade dieses Beispiel deutlich heraus, welche Bedeutung Partnership Policy besitzt. Eine solche Politik kann erst mal keine Alternative ersetzen, weil Putin offenzulegen scheiterte bisher immer again. Stalinkommunistische Ideologie bleibt genauso wenig erfolgversprechtendes Instrument wie ihr Gegenteil neoliberale Kapitalisierungswahnheiten. Deshalb braucht es Kompromisse basierend auf Respekten gegenseitiger Interessenbereiche und Anliegensstruktur beider Seiten. Dies gilt ebenso sehr für China wie für viele afrikane Staaten. Im Fall Chinas zeigt sich bereits längere Zeit seine ambivalenten Ansätze zunehmender Aggression besonders häufig südostasiatisches Gebiet betreffend. So kam es letzte Woche täglich neuartig zu Raketenangriffe Nordvietspräsident Xijings Truppen stationierte Insel Hainans teilweise chinesischen Territoriums Südwestchina bombardiere. Diese Situation lässt keinen Zweifel bestehen, welches Potential existiert für weitere ähnliches Handeln in anderen Regionen der Welt, sei es wegen territorialstaatlicher Streitsigkeiten oder infrage gesteller Einflüsse regionaler Kräfteverhältnisse. Darum bedarf es dringend diplomatiegener Unternehmenskraft zugänglichkeit europäischen Standortes durch deutsche Diplomaten. Dabei spielt zunächst einmal wichtig, wo wir stehen und wen wir berücksichtigt sehen. Als zweites Land drittgrößter Volkswirtschaft, größtem Exportmarkt Eurozone, starkster Wirtschaftsmacht Westeuropas und gleichzeitiger Haupttreibstoffator vieler global tätiger Unternehmen beschäftigte ich mich schon lange intensiv mit diesen Problemstellungen. Mit Blick auf Asien betrachtdwurde Japan früher oftmals quasi automatisch als Vorreiter gelobt. Doppelte Bedrohungslage Ostblock damals und drohendem Aufbau kommunistischen Regimes führte dazu, dass japanes Regierungshändelsystem speziellen Raum bot für intensive Kontakte EU-Vertretungen Japans. Dieser Weg könnten wir gerne nutzen! Allerd ...

# %% [markdown]
# ***
# ***
# # **RAG**

# %%
def build_faiss_index(texts, embedder):

    # Create FAISS index from a list of texts using a sentence embedding model:
    # determined which three of the possible speeches are the most similar to our desired topic

    embeddings = embedder.encode(texts, convert_to_numpy=True, show_progress_bar=False)
    dim = embeddings.shape[1]
    index = faiss.IndexFlatL2(dim)
    index.add(embeddings)
    return index, embeddings

# %%
def truncate_prompt_to_token_limit(prompt, tokenizer, max_prompt_tokens):
    tokens = tokenizer(prompt, return_tensors="pt", add_special_tokens=False)
    input_ids = tokens["input_ids"][0]
    if len(input_ids) <= max_prompt_tokens:
        return prompt  # no truncation needed

    # Truncate text by reducing its character length until it fits
    # This is a rough but fast approximation
    words = prompt.split()
    while len(tokenizer(" ".join(words), return_tensors="pt")["input_ids"][0]) > max_prompt_tokens:
        words = words[:-10]  # remove 10 tokens at a time
    return " ".join(words)


def generate_single_rag_speech(party, topic, texts, model, tokenizer, embedder, index, k=3, temp = 0.1):
    """
    Generate a single RAG-based speech for a party and topic, using a FAISS index.
    """
    query_vec = embedder.encode([topic])
    D, I = index.search(query_vec, k) # get the three most semantically similar speeches
    context_speeches = [texts[i] for i in I[0]]
    context = "\n---\n".join(context_speeches)

    prompt = [
            {
              "role": "user",
              "content": f"Schreibe eine neue, eigenständige Rede als Abgeordnete*r der Partei {party} zum Thema {topic}. Nutze die folgenden Reden als Kontext, aber formuliere die Rede in deinen eigenen Worten. Die Rede soll im Bundestag gehalten werden und bis zu 1500 Wörter lang sein.\n Kontext:\n{context}"
        
    }

    ]
    
    formatted_prompt = tokenizer.apply_chat_template(
        prompt,
        tokenize=False,
        add_generation_prompt=True,
        enable_thinking=False
    )
    
    print(f"Prompt length (tokens): {len(tokenizer(formatted_prompt)['input_ids'])}")



    MAX_PROMPT_TOKENS = 4096 - 1024
    formatted_text = truncate_prompt_to_token_limit(formatted_prompt, tokenizer, MAX_PROMPT_TOKENS)
    
    model_inputs = tokenizer(formatted_text, return_tensors="pt").to(model.device)

    #print(f"[DEBUG] Final prompt token count: {model_inputs['input_ids'].shape[1]}")
    #print(f"[DEBUG] Prompt:\n{formatted_text[:1000]}...")
    
    
    # Generate prediction with proper stopping
    with torch.inference_mode():
        generated_ids = model.generate(
            **model_inputs,
            max_new_tokens=1024,
            min_new_tokens = 100, # force the model to generate sth
            temperature=temp,
            repetition_penalty = 1.6,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id,  # Ensure EOS token stops generation            
        )

    # Extract only the new tokens
    #output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist()
    #print(f"[DEBUG] Generated token count: {len(output_ids)}")

    output_ids = generated_ids[0][len(model_inputs.input_ids[0]):]
    #print("Output token IDs:", output_ids)
    #print("Decoded output:", tokenizer.decode(output_ids))
    # Decode the response and remove EOS token if present
    content = tokenizer.decode(output_ids, skip_special_tokens=True).strip()

    return content, context_speeches

# %%
def generate_all_rag_speeches(clean_df, parties, topics, model, tokenizer, embedder, temp = 0.1):
    """
    Iterate over all party-topic combinations and generate one RAG-based speech for each.
    """
    results = []

    for party in tqdm(parties, desc="Parteien"):
        for topic in topics:
            subset = clean_df[(clean_df["party"] == party) & (clean_df["topic_for_RAG"] == topic)]

            texts = subset["speech_text_cleaned"].tolist()
            index, _ = build_faiss_index(texts, embedder)

            generated, contexts = generate_single_rag_speech(
                party=party,
                topic=topic,
                texts=texts,
                model=model,
                tokenizer=tokenizer,
                embedder=embedder,
                index=index,
                temp = temp
            )

            results.append({
                "party": party,
                "topic": topic,
                "speech_nr": 1,
                "generated_speech": generated,
                "context_speeches": contexts
            })

    return results

# %%
parties = ["SPD", "Union", "LINKE", "AfD", "GRÜNE", "FDP"]
topics = ["Mindestlohn", "Kosovo", "Pandemiehilfen", "Gaspreise"]

# Load embedding model
embedder = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")

# Run generation
results_01 = generate_all_rag_speeches(clean_df, parties, topics, model, tokenizer, embedder, temp = 0.1)

with open("../data/rag_generated_speeches_final_01.json", "w", encoding="utf-8") as f:
    json.dump(results_01, f, ensure_ascii=False, indent=2)
# Out:
# Parteien:   0%|          | 0/6 [00:00<?, ?it/s]
# Prompt length (tokens): 2770
# Prompt length (tokens): 3829
# Prompt length (tokens): 3716
# Prompt length (tokens): 3499
# Parteien:  17%|█▋        | 1/6 [02:36<13:04, 156.82s/it]
# Prompt length (tokens): 4336
# Prompt length (tokens): 2826
# Prompt length (tokens): 4002
# Prompt length (tokens): 3991
# Parteien:  33%|███▎      | 2/6 [05:14<10:28, 157.06s/it]
# Prompt length (tokens): 2891
# Prompt length (tokens): 2992
# Prompt length (tokens): 4362
# Prompt length (tokens): 2626
# Parteien:  50%|█████     | 3/6 [07:49<07:48, 156.14s/it]
# Prompt length (tokens): 2822
# Prompt length (tokens): 3136
# Prompt length (tokens): 3241
# Prompt length (tokens): 4293
# Parteien:  67%|██████▋   | 4/6 [10:26<05:12, 156.49s/it]
# Prompt length (tokens): 2674
# Prompt length (tokens): 3494
# Prompt length (tokens): 3001
# Prompt length (tokens): 4486
# Parteien:  83%|████████▎ | 5/6 [13:02<02:36, 156.41s/it]
# Prompt length (tokens): 3817
# Prompt length (tokens): 3488
# Prompt length (tokens): 2755
# Prompt length (tokens): 3915
# Parteien: 100%|██████████| 6/6 [15:39<00:00, 156.52s/it]

# %%
# rename
speeches_topic_df_01 = speeches_topic_df_01.rename(columns = {"speech_base_model" : "speech_base_model_01", "speech_ft_model" : "speech_ft_model_01"})
speeches_topic_df_03 = speeches_topic_df_03.rename(columns = {"speech_base_model" : "speech_base_model_03", "speech_ft_model" : "speech_ft_model_03"})

# save RAG, temp 0,1
RAG_results_01 = pd.DataFrame(results_01)[["party", "topic", "generated_speech"]].rename(columns = {"generated_speech" : "RAG_speech_01"})
RAG_results_01

# %%
parties = ["SPD", "Union", "LINKE", "AfD", "GRÜNE", "FDP"]
topics = ["Mindestlohn", "Kosovo", "Pandemiehilfen", "Gaspreise"]

# Load embedding model
embedder = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")

# Run generation
results_03 = generate_all_rag_speeches(clean_df, parties, topics, model, tokenizer, embedder, temp = 0.3)
# Out:
# Parteien:   0%|          | 0/6 [00:00<?, ?it/s]
# Prompt length (tokens): 2770
# Prompt length (tokens): 3829
# Prompt length (tokens): 3716
# Prompt length (tokens): 3499
# Parteien:  17%|█▋        | 1/6 [02:36<13:03, 156.64s/it]
# Prompt length (tokens): 4336
# Prompt length (tokens): 2826
# Prompt length (tokens): 4002
# Prompt length (tokens): 3991
# Parteien:  33%|███▎      | 2/6 [05:13<10:27, 156.99s/it]
# Prompt length (tokens): 2891
# Prompt length (tokens): 2992
# Prompt length (tokens): 4362
# Prompt length (tokens): 2626
# Parteien:  50%|█████     | 3/6 [07:49<07:48, 156.17s/it]
# Prompt length (tokens): 2822
# Prompt length (tokens): 3136
# Prompt length (tokens): 3241
# Prompt length (tokens): 4293
# Parteien:  67%|██████▋   | 4/6 [10:25<05:12, 156.45s/it]
# Prompt length (tokens): 2674
# Prompt length (tokens): 3494
# Prompt length (tokens): 3001
# Prompt length (tokens): 4486
# Parteien:  83%|████████▎ | 5/6 [13:02<02:36, 156.36s/it]
# Prompt length (tokens): 3817
# Prompt length (tokens): 3488
# Prompt length (tokens): 2755
# Prompt length (tokens): 3915
# Parteien: 100%|██████████| 6/6 [15:38<00:00, 156.47s/it]

# %%
with open("../data/rag_generated_speeches_final_03.json", "w", encoding="utf-8") as f:
    json.dump(results_03, f, ensure_ascii=False, indent=2)

# %%
# save RAG, temp 0,3
RAG_results_03 = pd.DataFrame(results_03)[["party", "topic", "generated_speech"]].rename(columns = {"generated_speech" : "RAG_speech_03"})
RAG_results_03
# Out:
#     party           topic                                      RAG_speech_03
# 0     SPD     Mindestlohn  [Inst] Sehr verehrte Präsidentin! Meine geschä...
# 1     SPD          Kosovo  damit maßgeblich zur Unterbindung potentieller...
# 2     SPD  Pandemiehilfen  Landes sowie seiner Gesellschaft trotz schwers...
# 3     SPD       Gaspreise  wir nun begreifen, und darüber hinaus wollen w...
# 4   Union     Mindestlohn  kurz kommentieren. Es geht dort tatsächlich um...
# 5   Union          Kosovo  [Inst] Sehr verehrte Frau Präsident! Lieber Ko...
# 6   Union  Pandemiehilfen  Bildungsfördermittel überzeugt gewesen. Doch d...
# 7   Union       Gaspreise  Kommission diesen Decker durchsetzten sowie we...
# 8   LINKE     Mindestlohn  [INSP_IPTV #Wirecard - /TWCMS/Bild/_Apfotosyst...
# 9   LINKE          Kosovo  [Inst] Herr Dr. Hahnemann, lieber Peter, du ha...
# 10  LINKE  Pandemiehilfen  gerne pürieren lassen. Also habe ich gefragt: ...
# 11  LINKE       Gaspreise  [INST] Frau Präsidentin! Meine sehr verehrte D...
# 12    AfD     Mindestlohn  [INCLUDEOUTPUT]\nVon daher setzten wir uns kri...
# 13    AfD          Kosovo  Amt sitzt, der dies sehr stark betont. Eine kl...
# 14    AfD  Pandemiehilfen  Diskussion kaummmentsprechendes Schweigespiel ...
# 15    AfD       Gaspreise  Energiepreise höhere Einkünfte steuerte zurück...
# 16  GRÜNE     Mindestlohn  [INST] Sehr verehrte Frau Präsidentin! Lieber ...
# 17  GRÜNE          Kosovo  kontinuierlich würdigen zu lassen. Insofern bi...
# 18  GRÜNE  Pandemiehilfen  [Inst] Sehr geehrte Präsidentin! Liebe Ministe...
# 19  GRÜNE       Gaspreise  Öffnungsklausel gilt, verwendet. Also werben w...
# 20    FDP     Mindestlohn  Die Linke würden letzte Woche etwa 1 Million B...
# 21    FDP          Kosovo  gefahren sind oder aktiver Dienst täglich vers...
# 22    FDP  Pandemiehilfen  [Inst] Sehr geehrte Frau Präsidentin! Verehrte...
# 23    FDP       Gaspreise  dies betrifFT alle Haushaltsstandorte gleicher...

# %%
# recode 
RAG_results_01["topic"] = RAG_results_01["topic"].replace({"Kosovo" : "Bundeswehreinsatz im Kosovo", "Pandemiehilfen": "Wirtschaftshilfen Corona"})
RAG_results_03["topic"] = RAG_results_03["topic"].replace({"Kosovo" : "Bundeswehreinsatz im Kosovo", "Pandemiehilfen": "Wirtschaftshilfen Corona"})

speeches_topic_df_01["party"] = speeches_topic_df_01["party"].replace({"Linke" : "LINKE"})
speeches_topic_df_03["party"] = speeches_topic_df_03["party"].replace({"Linke" : "LINKE"})

# %%
# combine all final speeches and export ---> missing context

#RAG_speeches_df = (
#    speeches_topic_df_01
#    .merge(speeches_topic_df_03, on=["party", "topic"], how = "inner")
#    .merge(RAG_results_01, on=["party", "topic"], how = "inner")
#    .merge(RAG_results_03, on=["party", "topic"], how = "inner")
#)

#RAG_speeches_df.to_csv("../data/generated_speeches_final.csv", index = False)
#RAG_speeches_df
# Out:
#     party                        topic  \
# 0   Union                  Mindestlohn
# 1   Union  Bundeswehreinsatz im Kosovo
# 2   Union     Wirtschaftshilfen Corona
# 3   Union                    Gaspreise
# 4     SPD                  Mindestlohn
# 5     SPD  Bundeswehreinsatz im Kosovo
# 6     SPD     Wirtschaftshilfen Corona
# 7     SPD                    Gaspreise
# 8   GRÜNE                  Mindestlohn
# 9   GRÜNE  Bundeswehreinsatz im Kosovo
# 10  GRÜNE     Wirtschaftshilfen Corona
# 11  GRÜNE                    Gaspreise
# 12    FDP                  Mindestlohn
# 13    FDP  Bundeswehreinsatz im Kosovo
# 14    FDP     Wirtschaftshilfen Corona
# 15    FDP                    Gaspreise
# 16    AfD                  Mindestlohn
# 17    AfD  Bundeswehreinsatz im Kosovo
# 18    AfD     Wirtschaftshilfen Corona
# 19    AfD                    Gaspreise
# 20  LINKE                  Mindestlohn
# 21  LINKE  Bundeswehreinsatz im Kosovo
# 22  LINKE     Wirtschaftshilfen Corona
# 23  LINKE                    Gaspreise
#
#                                  speech_base_model_01  \
# 0   #Hartz-IV# - Ein neuer Start für den Arbeitsma...
# 1   #Hallo! Ich bin der Kanzlerminister in dieser ...
# 2   #Hallo! Ich bin der Kanzlerminister Olaf Schul...
# 3   #Hallo! Ich bin der Kanzlerminister in dieser ...
# 4   #HartzIV#Mindesteinkommen#, Ladies and Gentlem...
# 5   #Hallo! Ich bin der Kanzlerminister Olaf Schol...
# 6   #WirHelfendeNation# - Eine solide wirtschaftli...
# 7   #Hallo! Ich bin der Kanzlerminister Olaf Schol...
# 8   #Mindesteinkommen für alle!# Ein neuer Start i...
# 9   #Bundeswehr#Kosovokrieg#Politikdebatte#GrüneFr...
# 10  #WirHelfendeNation# - Eine grüne Vision für wi...
# 11  #WirForschenEnergie# - Eine grüne Energiewende...
# 12  #Hartz-IV# - Ein neuer Weg zur Arbeitsmarktpol...
# 13  #Hallo! Ich bin Freie Demokratin (FDP) für den...
# 14  #Hallo! Ich bin Freie Demokratin (FDP) für den...
# 15  #Hallo! Ich bin Freie Demokratin (FDP) für den...
# 16  #Hallo! Ich bin der Kandidat für den Wahlkreis...
# 17  #Hallo! Ich bin der Kandidat für den Wahlkreis...
# 18  #Hallo! Ich bin der Kandidat für den Wahlkreis...
# 19  #Hallo! Ich bin der Kandidat für den Wahlkreis...
# 20  #HartzIV - Die soziale Marktwirtschaft auf dem...
# 21  #Hallo! Ich bin hier heute als Vertreterin der...
# 22  #WirHelfendeNation# - Eine solide wirtschaftli...
# 23  #Hallo! Ich bin der Kandidat für den Wahlkreis...
#
#                                    speech_ft_model_01  \
# 0   #NieAgain – Sexuelle Gewalt an Kindern verhind...
# 1   #NieWieder – Das war der Slogan des Protestes ...
# 2   #NieAgain – so lautet der Slogan des internati...
# 3   #NieAgain! – Das war der Slogan des großen Pro...
# 4   #NieAufKeinenFall! – Das war der Aufruf des Bu...
# 5   import { default as Spinner } from 'react-spin...
# 6   #NieAgain – Das Ziel der Bundesregierung muss ...
# 7   #NieAgain! Wir müssen den Krieg in der Ukraine...
# 8   #Mindesteinkommen#Minijob#, wir alle wissen es...
# 9   #NieWieder! – Das war der Aufruf des Klimaprot...
# 10  #NieAgain! – Das war der Aufruf des Bundeskanz...
# 11  #NieAgain! Wir müssen jetzt handeln für bezahl...
# 12  #NieAgain – Das sind nicht nur Worte; es geht ...
# 13  #NieWieder – Das war der Slogan des Protestes ...
# 14  #NieAgain – Das muss jetzt endlich Stopp sein!...
# 15  #NieAgain! – Das war der Aufruf des Bundeskanz...
# 16  #NieAgain! – Das war der Slogan des großen Pro...
# 17  #NieWiederKosovokrieg! – Das war der Titel mei...
# 18  #NieAgain! – Das war der Slogan des Demonstrat...
# 19  #NieAgain! – Das war der Slogan des großen Pro...
# 20  # Hochschulfinanzierung – Bildung für alle!#Ni...
# 21  #NieWiederKosovokrieg!#KeinEU-Battlegroup in d...
# 22  #NieAgain! – Das war der Slogan des Protestes ...
# 23  #NieAgain! Stoppen wir den Krieg gegen Russlan...
#
#                                  speech_base_model_03  \
# 0   #HartzIV - Die Zeit der Verantwortung für alle...
# 1   #Hallo! Ich bin der Kanzlerminister in dieser ...
# 2   #Hallo! Ich bin der Kanzlerminister Olaf Schul...
# 3   #Hallo! Ich bin der Kanzlerminister in dieser ...
# 4   #HartzIV - Die soziale Marktwirtschaft braucht...
# 5   #Hallo! Ich bin hier heute als Vertreterin der...
# 6   #WirHelfendeNation# - Eine solide wirtschaftli...
# 7   #WirfürEnergie - Eine nachhaltige Energiesyste...
# 8   #HartzIV#Mindesteinkommen#ArbeitslosengeldII#,...
# 9   #Bundeswehr#Kosovokrieg" class="tw-breadcrumbs...
# 10  #WirHelfendeNation# - Eine grüne Vision für wi...
# 11  #WirForschenEnergie# - Eine grüne Energiewende...
# 12  #FREIHEIT#MITTELSTELLUNGSGESETZ! DIE ZUKÜNFT I...
# 13  #Hallo! Ich bin Freie Demokratin (FDP) für den...
# 14  #WirFürEinNachhaltigesDeutschland# - Eine Stra...
# 15  #Höhere Preissicherheit für Verbraucher - Eine...
# 16  #HartzIV für alle!# Die Zeit der sozialistisch...
# 17  #Hallo! Ich bin der neue Sprecher für den Eins...
# 18  #Hallo! Ich bin der Kandidat für den Wahlkreis...
# 19  #Höhere Preisspanne für E-Autos!# Ein neuer We...
# 20  #Mindesteinkommen für alle!# Ein neuer Start i...
# 21  #DieLinke - Die sozialistische Alternative für...
# 22  #Hallo! Ich bin hier heute als Vertreterin der...
# 23  # Die linke Position zum Problem der steigende...
#
#                                    speech_ft_model_03  \
# 0   # Hochwertige Arbeit für alle – Ein guter Job ...
# 1   #NieJamaisKrieg – so lautet der Slogan des Fri...
# 2   #NieAgain – wir müssen lernen aus den Fehlents...
# 3   #NieAgain! Wir werden unsere Energie unabhängi...
# 4   #NieAufKeinenFall – Das muss endlich Stoppen! ...
# 5   #NieAgain! Kein Krieg mehr für Deutschland – K...
# 6   #NieAgain! – Das war der Slogan des Protestes ...
# 7   #NieAgain – wir müssen endlich den Krieg in de...
# 8   #NieMindeloesung! Das hat der Kollege Birkwald...
# 9   #NieWiederKosovowar! – Das war der Aufruf des ...
# 10  import { getCustomers } from '../database'; //...
# 11  #NieAgain! – Das war der Aufruf des Bundeskanz...
# 12  # Einleitung# Ja oder Nein? Liebe Kolleginnen!...
# 13  #NieAgain! – Das war der Aufruf des damaligen ...
# 14  #Wirtschaftswunder# hat man in Deutschland nic...
# 15  #NieAgain! – Das war der Anlass für diese Deba...
# 16  #einPunkt – Ein Punkt für Deutschland! Seien S...
# 17  #NieWieder! – Das war der Slogan des Protestes...
# 18  #NieAgain! – Das war der Kampfruf des Bundeska...
# 19  #NieAgain! – Das war der Slogan des Protestes ...
# 20  # Kein Grund zur Freude für Arbeitnehmerinnen ...
# 21  #Menschenrechte#Kosovokrieg (1998-1999)#UNMIK(...
# 22  #NieAgain! – Das war der Aufruf des Bundeskanz...
# 23  #NieWieder so! Stoppen wir den Krieg in der Uk...
#
#                                         RAG_speech_01  \
# 0   kurz kommentieren. Es geht dort tatsächlich um...
# 1   [Inst] Sehr verehrte Frau Präsidentin! Lieber ...
# 2   Bildungsfördersprechanbieter, also Förster/-in...
# 3   Kommission versuchen, diesen Decker möglichst ...
# 4   [Inst] Sehr verehrte Präsidentin! Meine geschä...
# 5   damit maßgeblich zur Unterbindung potentieller...
# 6   Landes sowie seine Standortattraktivität erhal...
# 7   wir fortsetzten. Zum Ende meiner Redezeit würd...
# 8   [Inst] Sehr verehrte Frau Präsidentin! Lieber ...
# 9   zu würdigen. Als letzte Gedenkmöglichkeit will...
# 10  [Inst] Sehr geehrte Präsidentin! Liebes Publik...
# 11  Tarife festgeschrieben werden, verwendet. Jede...
# 12  Die Linke würden letzte Woche keine neuen Stud...
# 13  gefahren sind oder aktuell aktiv Dienst tune, ...
# 14  [Inst] Sehr geehrte Frau Präsidentin! Verehrte...
# 15  einige fordernd, andere besorgt. Als Politiker...
# 16  [INCLUSIVE_MODE][INST] Sehr geschätzten Frau P...
# 17  Amt sitzt, der seine Arbeit sehr gut macht. Do...
# 18  Diskussion ka Dumme redete worden sei. Ich bin...
# 19  Stromeinsätze hohe zusätzliche Gebühren, währe...
# 20  [Inst] Sehr verehrte Präsidentin! Verehrte Kol...
# 21  [Inst] Herr Dr. Hahnemann, wenn mir bitte mal ...
# 22  gerne lassen. Diese Erklärung habe ich ihr tel...
# 23  [INST] Frau Präsidentin! Meine sehr verehrte F...
#
#                                         RAG_speech_03
# 0   kurz kommentieren. Es geht dort tatsächlich um...
# 1   [Inst] Sehr verehrte Frau Präsident! Lieber Ko...
# 2   Bildungsfördermittel überzeugt gewesen. Doch d...
# 3   Kommission diesen Decker durchsetzten sowie we...
# 4   [Inst] Sehr verehrte Präsidentin! Meine geschä...
# 5   damit maßgeblich zur Unterbindung potentieller...
# 6   Landes sowie seiner Gesellschaft trotz schwers...
# 7   wir nun begreifen, und darüber hinaus wollen w...
# 8   [INST] Sehr verehrte Frau Präsidentin! Lieber ...
# 9   kontinuierlich würdigen zu lassen. Insofern bi...
# 10  [Inst] Sehr geehrte Präsidentin! Liebe Ministe...
# 11  Öffnungsklausel gilt, verwendet. Also werben w...
# 12  Die Linke würden letzte Woche etwa 1 Million B...
# 13  gefahren sind oder aktiver Dienst täglich vers...
# 14  [Inst] Sehr geehrte Frau Präsidentin! Verehrte...
# 15  dies betrifFT alle Haushaltsstandorte gleicher...
# 16  [INCLUDEOUTPUT]\nVon daher setzten wir uns kri...
# 17  Amt sitzt, der dies sehr stark betont. Eine kl...
# 18  Diskussion kaummmentsprechendes Schweigespiel ...
# 19  Energiepreise höhere Einkünfte steuerte zurück...
# 20  [INSP_IPTV #Wirecard - /TWCMS/Bild/_Apfotosyst...
# 21  [Inst] Herr Dr. Hahnemann, lieber Peter, du ha...
# 22  gerne pürieren lassen. Also habe ich gefragt: ...
# 23  [INST] Frau Präsidentin! Meine sehr verehrte D...

# %%
# add context speeches

with open("../data/rag_generated_speeches_final_01.json", "r", encoding="utf-8") as f:
    results_01 = json.load(f)

with open("../data/rag_generated_speeches_final_03.json", "r", encoding="utf-8") as f:
    results_03 = json.load(f)

RAG_results_01 = pd.DataFrame(results_01).rename(columns = {"generated_speech" : "RAG_speech_01"})
RAG_results_03 = pd.DataFrame(results_03).rename(columns = {"generated_speech" : "RAG_speech_03"})


RAG_results_01["topic"] = RAG_results_01["topic"].replace({"Kosovo" : "Bundeswehreinsatz im Kosovo", "Pandemiehilfen": "Wirtschaftshilfen Corona"})
RAG_results_03["topic"] = RAG_results_03["topic"].replace({"Kosovo" : "Bundeswehreinsatz im Kosovo", "Pandemiehilfen": "Wirtschaftshilfen Corona"})
RAG_results_03
# Out:
#     party                        topic  speech_nr  \
# 0     SPD                  Mindestlohn          1
# 1     SPD  Bundeswehreinsatz im Kosovo          1
# 2     SPD     Wirtschaftshilfen Corona          1
# 3     SPD                    Gaspreise          1
# 4   Union                  Mindestlohn          1
# 5   Union  Bundeswehreinsatz im Kosovo          1
# 6   Union     Wirtschaftshilfen Corona          1
# 7   Union                    Gaspreise          1
# 8   LINKE                  Mindestlohn          1
# 9   LINKE  Bundeswehreinsatz im Kosovo          1
# 10  LINKE     Wirtschaftshilfen Corona          1
# 11  LINKE                    Gaspreise          1
# 12    AfD                  Mindestlohn          1
# 13    AfD  Bundeswehreinsatz im Kosovo          1
# 14    AfD     Wirtschaftshilfen Corona          1
# 15    AfD                    Gaspreise          1
# 16  GRÜNE                  Mindestlohn          1
# 17  GRÜNE  Bundeswehreinsatz im Kosovo          1
# 18  GRÜNE     Wirtschaftshilfen Corona          1
# 19  GRÜNE                    Gaspreise          1
# 20    FDP                  Mindestlohn          1
# 21    FDP  Bundeswehreinsatz im Kosovo          1
# 22    FDP     Wirtschaftshilfen Corona          1
# 23    FDP                    Gaspreise          1
#
#                                         RAG_speech_03  \
# 0   [Inst] Sehr verehrte Präsidentin! Meine geschä...
# 1   damit maßgeblich zur Unterbindung potentieller...
# 2   Landes sowie seiner Gesellschaft trotz schwers...
# 3   wir nun begreifen, und darüber hinaus wollen w...
# 4   kurz kommentieren. Es geht dort tatsächlich um...
# 5   [Inst] Sehr verehrte Frau Präsident! Lieber Ko...
# 6   Bildungsfördermittel überzeugt gewesen. Doch d...
# 7   Kommission diesen Decker durchsetzten sowie we...
# 8   [INSP_IPTV #Wirecard - /TWCMS/Bild/_Apfotosyst...
# 9   [Inst] Herr Dr. Hahnemann, lieber Peter, du ha...
# 10  gerne pürieren lassen. Also habe ich gefragt: ...
# 11  [INST] Frau Präsidentin! Meine sehr verehrte D...
# 12  [INCLUDEOUTPUT]\nVon daher setzten wir uns kri...
# 13  Amt sitzt, der dies sehr stark betont. Eine kl...
# 14  Diskussion kaummmentsprechendes Schweigespiel ...
# 15  Energiepreise höhere Einkünfte steuerte zurück...
# 16  [INST] Sehr verehrte Frau Präsidentin! Lieber ...
# 17  kontinuierlich würdigen zu lassen. Insofern bi...
# 18  [Inst] Sehr geehrte Präsidentin! Liebe Ministe...
# 19  Öffnungsklausel gilt, verwendet. Also werben w...
# 20  Die Linke würden letzte Woche etwa 1 Million B...
# 21  gefahren sind oder aktiver Dienst täglich vers...
# 22  [Inst] Sehr geehrte Frau Präsidentin! Verehrte...
# 23  dies betrifFT alle Haushaltsstandorte gleicher...
#
#                                      context_speeches
# 0   [Wir reden heute hier über den Mindestlohn. Fü...
# 1   [Erst kürzlich hat der Reiseführer „Lonely Pla...
# 2   [Die Pandemie Covid-19 stellt uns alle als Bür...
# 3   [Liebe Bürgerinnen und Bürger! Der Anschlag au...
# 4   [Wir haben 2015 in der unionsgeführten Bundesr...
# 5   [Das Kosovo ist ein Land, das in der gesamten ...
# 6   [Auch wenn wir bislang verhältnismäßig gut dur...
# 7   [Die Frage, wie wir von russischen Gaslieferun...
# 8   [Der Mindestlohn steigt zum 1. Januar gerade m...
# 9   [Wieder einmal beraten wir hier über den Einsa...
# 10  [Soforthilfe, Novemberhilfe, Neustarthilfe, Üb...
# 11  [Auch in diesen Zeiten müssen Strom und Gas be...
# 12  [Liebe Zuschauer! Wir tragen den Mindestlohn g...
# 13  [Ganz besonders begrüße ich das Mitglied des s...
# 14  [Viele Jahre hat man die von der ME/CFS-Erkran...
# 15  [Nach dem, was ich jetzt gerade hier schon in ...
# 16  [Liebe Zuschauer/-innen! Der Mindestlohn ist e...
# 17  [Für viele von uns ist der Krieg im Kosovo ans...
# 18  [Liebe Bürgerinnen und Bürger! „Wir verpflicht...
# 19  [Wir haben im Augenblick zwei Herausforderunge...
# 20  [Das Wesen des Mindestlohns, so wie er von CDU...
# 21  [Am Ende letzten Jahres waren die Nachrichten,...
# 22  [Die gesundheitlichen Folgen der Pandemie wie ...
# 23  [Dass Die Linke sich mal hierhinstellen und am...

# %%
# make df and expand context speeches to columns

# 01 temp
context_01 = pd.DataFrame(RAG_results_01["context_speeches"].tolist(),
                          columns=["RAG_01_context_1", "RAG_01_context_2", "RAG_01_context_3"])

RAG_results_01 = pd.concat([RAG_results_01, context_01], axis=1).drop(columns = "context_speeches")
RAG_results_01



# temp 0.3
context_03 = pd.DataFrame(RAG_results_03["context_speeches"].tolist(),
                          columns=["RAG_03_context_1", "RAG_03_context_2", "RAG_03_context_3"])

RAG_results_03 = pd.concat([RAG_results_03, context_03], axis=1).drop(columns = "context_speeches")
RAG_results_03
# Out:
#     party                        topic  speech_nr  \
# 0     SPD                  Mindestlohn          1
# 1     SPD  Bundeswehreinsatz im Kosovo          1
# 2     SPD     Wirtschaftshilfen Corona          1
# 3     SPD                    Gaspreise          1
# 4   Union                  Mindestlohn          1
# 5   Union  Bundeswehreinsatz im Kosovo          1
# 6   Union     Wirtschaftshilfen Corona          1
# 7   Union                    Gaspreise          1
# 8   LINKE                  Mindestlohn          1
# 9   LINKE  Bundeswehreinsatz im Kosovo          1
# 10  LINKE     Wirtschaftshilfen Corona          1
# 11  LINKE                    Gaspreise          1
# 12    AfD                  Mindestlohn          1
# 13    AfD  Bundeswehreinsatz im Kosovo          1
# 14    AfD     Wirtschaftshilfen Corona          1
# 15    AfD                    Gaspreise          1
# 16  GRÜNE                  Mindestlohn          1
# 17  GRÜNE  Bundeswehreinsatz im Kosovo          1
# 18  GRÜNE     Wirtschaftshilfen Corona          1
# 19  GRÜNE                    Gaspreise          1
# 20    FDP                  Mindestlohn          1
# 21    FDP  Bundeswehreinsatz im Kosovo          1
# 22    FDP     Wirtschaftshilfen Corona          1
# 23    FDP                    Gaspreise          1
#
#                                         RAG_speech_03  \
# 0   [Inst] Sehr verehrte Präsidentin! Meine geschä...
# 1   damit maßgeblich zur Unterbindung potentieller...
# 2   Landes sowie seiner Gesellschaft trotz schwers...
# 3   wir nun begreifen, und darüber hinaus wollen w...
# 4   kurz kommentieren. Es geht dort tatsächlich um...
# 5   [Inst] Sehr verehrte Frau Präsident! Lieber Ko...
# 6   Bildungsfördermittel überzeugt gewesen. Doch d...
# 7   Kommission diesen Decker durchsetzten sowie we...
# 8   [INSP_IPTV #Wirecard - /TWCMS/Bild/_Apfotosyst...
# 9   [Inst] Herr Dr. Hahnemann, lieber Peter, du ha...
# 10  gerne pürieren lassen. Also habe ich gefragt: ...
# 11  [INST] Frau Präsidentin! Meine sehr verehrte D...
# 12  [INCLUDEOUTPUT]\nVon daher setzten wir uns kri...
# 13  Amt sitzt, der dies sehr stark betont. Eine kl...
# 14  Diskussion kaummmentsprechendes Schweigespiel ...
# 15  Energiepreise höhere Einkünfte steuerte zurück...
# 16  [INST] Sehr verehrte Frau Präsidentin! Lieber ...
# 17  kontinuierlich würdigen zu lassen. Insofern bi...
# 18  [Inst] Sehr geehrte Präsidentin! Liebe Ministe...
# 19  Öffnungsklausel gilt, verwendet. Also werben w...
# 20  Die Linke würden letzte Woche etwa 1 Million B...
# 21  gefahren sind oder aktiver Dienst täglich vers...
# 22  [Inst] Sehr geehrte Frau Präsidentin! Verehrte...
# 23  dies betrifFT alle Haushaltsstandorte gleicher...
#
#                                      RAG_03_context_1  \
# 0   Wir reden heute hier über den Mindestlohn. Für...
# 1   Erst kürzlich hat der Reiseführer „Lonely Plan...
# 2   Die Pandemie Covid-19 stellt uns alle als Bürg...
# 3   Liebe Bürgerinnen und Bürger! Der Anschlag auf...
# 4   Wir haben 2015 in der unionsgeführten Bundesre...
# 5   Das Kosovo ist ein Land, das in der gesamten R...
# 6   Auch wenn wir bislang verhältnismäßig gut durc...
# 7   Die Frage, wie wir von russischen Gaslieferung...
# 8   Der Mindestlohn steigt zum 1. Januar gerade ma...
# 9   Wieder einmal beraten wir hier über den Einsat...
# 10  Soforthilfe, Novemberhilfe, Neustarthilfe, Übe...
# 11  Auch in diesen Zeiten müssen Strom und Gas bez...
# 12  Liebe Zuschauer! Wir tragen den Mindestlohn gr...
# 13  Ganz besonders begrüße ich das Mitglied des se...
# 14  Viele Jahre hat man die von der ME/CFS-Erkrank...
# 15  Nach dem, was ich jetzt gerade hier schon in d...
# 16  Liebe Zuschauer/-innen! Der Mindestlohn ist es...
# 17  Für viele von uns ist der Krieg im Kosovo ansc...
# 18  Liebe Bürgerinnen und Bürger! „Wir verpflichte...
# 19  Wir haben im Augenblick zwei Herausforderungen...
# 20  Das Wesen des Mindestlohns, so wie er von CDU/...
# 21  Am Ende letzten Jahres waren die Nachrichten, ...
# 22  Die gesundheitlichen Folgen der Pandemie wie L...
# 23  Dass Die Linke sich mal hierhinstellen und ame...
#
#                                      RAG_03_context_2  \
# 0   Fest steht: Der Mindestlohn ist eine Erfolgsge...
# 1   Seit über 20 Jahren unterstützen wir durch uns...
# 2   Achteran kakeln Hauner, sagt man in Ostfriesla...
# 3   Sie alle kennen die aktuelle Preisentwicklung ...
# 4   Wir beraten heute zwei Anträge zum Stichwort M...
# 5   Das Selbstbestimmungsrecht gilt auch für das k...
# 6   Mit dem vorliegenden Antrag will die AfD der F...
# 7   Strompreisbremse, Gaspreisbremse – die Titel d...
# 8   In der Presse war zu lesen, dass Arbeitsminist...
# 9   Die Abtrennung des Kosovo war völkerrechtswidr...
# 10  Gaststätten sind wie Hotels von der Coronapand...
# 11  Die Energiepreise gehen durch die Decke, allei...
# 12  Liebe Besucher! Wir reden heute über eine EU-M...
# 13  Liebe Besucher und Gäste im Deutschen Bundesta...
# 14  Der Schutz der Risikogruppen steht für uns – d...
# 15  Bevor ich loslege, wieder mal ein kurzer Reali...
# 16  Wenn es sein muss, dann sage ich es immer und ...
# 17  Schämen Sie sich dafür. Das ist auch eine Esse...
# 18  Diese Pandemie hat uns eines gezeigt, nämlich ...
# 19  Liebe Bürgerinnen und Bürger! Zur Union nur so...
# 20  Mit dem Antrag 20/9132 hat die Fraktion Die Li...
# 21  – Heute Abend sind wir ja beim Sommerfest. Die...
# 22  Die schärfste Waffe gegen das Virus sind Impfu...
# 23  Viele Menschen in diesem Land machen sich groß...
#
#                                      RAG_03_context_3
# 0   Ich weiß nicht, wie es Ihnen geht. Aber ich fi...
# 1   Ich bitte um Zustimmung zu diesem Antrag und f...
# 2   Werte Bürger/-innen hier auf der Tribüne! Ganz...
# 3   Vielen Dank. Ich bin ja bekanntermaßen mit wen...
# 4   Als die Große Koalition vor acht Jahren den Mi...
# 5   Warum engagieren wir uns seit über 20 Jahren i...
# 6   Gesundheitsschutz in der Pandemie darf die Fol...
# 7   Wir haben diese Woche im Ausschuss sehr ausfüh...
# 8   Zurzeit arbeiten in Deutschland rund 1,5 Milli...
# 9   Unter der Mitwirkung Deutschlands hat die NATO...
# 10  Seit Monaten bewegen wir hier gigantische Summ...
# 11  Frau Lang, Sie haben gerade gesagt: Gas war be...
# 12  In einem Wahlkampfjahr wird dann auch gerne ma...
# 13  KFOR ist und bleibt eine Lebensversicherung un...
# 14  Die Gesundheit der Menschen hat immer Prioritä...
# 15  Die Bundesregierung lässt die Bürger und Unter...
# 16  Der Mindestlohn ist eine wichtige Errungenscha...
# 17  Wir debattieren heute über die Fortsetzung der...
# 18  Meine beiden Vorredner haben schon sehr eloque...
# 19  Wir besprechen heute den zweiten Teil der Nove...
# 20  Die Fraktion Die Linke fordert einen gesetzlic...
# 21  Im Kosovo ist unser längster und ältester Eins...
# 22  Seit Monaten diskutieren wir hier im Deutschen...
# 23  Und täglich grüßt uns wieder das Murmeltier. I...

# %%
RAG_speeches_context = (
    speeches_topic_df_01
    .merge(speeches_topic_df_03, on=["party", "topic"], how = "inner")
    .merge(RAG_results_01, on=["party", "topic"], how = "inner")
    .merge(RAG_results_03, on=["party", "topic"], how = "inner")
)


RAG_speeches_context = RAG_speeches_context.drop(columns = ["speech_nr_x", "speech_nr_y"])
RAG_speeches_context.to_csv("../data/generated_speeches_final_context.csv", index = False)
RAG_speeches_context
# Out:
#     party                        topic  \
# 0   Union                  Mindestlohn
# 1   Union  Bundeswehreinsatz im Kosovo
# 2   Union     Wirtschaftshilfen Corona
# 3   Union                    Gaspreise
# 4     SPD                  Mindestlohn
# 5     SPD  Bundeswehreinsatz im Kosovo
# 6     SPD     Wirtschaftshilfen Corona
# 7     SPD                    Gaspreise
# 8   GRÜNE                  Mindestlohn
# 9   GRÜNE  Bundeswehreinsatz im Kosovo
# 10  GRÜNE     Wirtschaftshilfen Corona
# 11  GRÜNE                    Gaspreise
# 12    FDP                  Mindestlohn
# 13    FDP  Bundeswehreinsatz im Kosovo
# 14    FDP     Wirtschaftshilfen Corona
# 15    FDP                    Gaspreise
# 16    AfD                  Mindestlohn
# 17    AfD  Bundeswehreinsatz im Kosovo
# 18    AfD     Wirtschaftshilfen Corona
# 19    AfD                    Gaspreise
# 20  LINKE                  Mindestlohn
# 21  LINKE  Bundeswehreinsatz im Kosovo
# 22  LINKE     Wirtschaftshilfen Corona
# 23  LINKE                    Gaspreise
#
#                                  speech_base_model_01  \
# 0   #Hartz-IV# - Ein neuer Start für den Arbeitsma...
# 1   #Hallo! Ich bin der Kanzlerminister in dieser ...
# 2   #Hallo! Ich bin der Kanzlerminister Olaf Schul...
# 3   #Hallo! Ich bin der Kanzlerminister in dieser ...
# 4   #HartzIV#Mindesteinkommen#, Ladies and Gentlem...
# 5   #Hallo! Ich bin der Kanzlerminister Olaf Schol...
# 6   #WirHelfendeNation# - Eine solide wirtschaftli...
# 7   #Hallo! Ich bin der Kanzlerminister Olaf Schol...
# 8   #Mindesteinkommen für alle!# Ein neuer Start i...
# 9   #Bundeswehr#Kosovokrieg#Politikdebatte#GrüneFr...
# 10  #WirHelfendeNation# - Eine grüne Vision für wi...
# 11  #WirForschenEnergie# - Eine grüne Energiewende...
# 12  #Hartz-IV# - Ein neuer Weg zur Arbeitsmarktpol...
# 13  #Hallo! Ich bin Freie Demokratin (FDP) für den...
# 14  #Hallo! Ich bin Freie Demokratin (FDP) für den...
# 15  #Hallo! Ich bin Freie Demokratin (FDP) für den...
# 16  #Hallo! Ich bin der Kandidat für den Wahlkreis...
# 17  #Hallo! Ich bin der Kandidat für den Wahlkreis...
# 18  #Hallo! Ich bin der Kandidat für den Wahlkreis...
# 19  #Hallo! Ich bin der Kandidat für den Wahlkreis...
# 20  #HartzIV - Die soziale Marktwirtschaft auf dem...
# 21  #Hallo! Ich bin hier heute als Vertreterin der...
# 22  #WirHelfendeNation# - Eine solide wirtschaftli...
# 23  #Hallo! Ich bin der Kandidat für den Wahlkreis...
#
#                                    speech_ft_model_01  \
# 0   #NieAgain – Sexuelle Gewalt an Kindern verhind...
# 1   #NieWieder – Das war der Slogan des Protestes ...
# 2   #NieAgain – so lautet der Slogan des internati...
# 3   #NieAgain! – Das war der Slogan des großen Pro...
# 4   #NieAufKeinenFall! – Das war der Aufruf des Bu...
# 5   import { default as Spinner } from 'react-spin...
# 6   #NieAgain – Das Ziel der Bundesregierung muss ...
# 7   #NieAgain! Wir müssen den Krieg in der Ukraine...
# 8   #Mindesteinkommen#Minijob#, wir alle wissen es...
# 9   #NieWieder! – Das war der Aufruf des Klimaprot...
# 10  #NieAgain! – Das war der Aufruf des Bundeskanz...
# 11  #NieAgain! Wir müssen jetzt handeln für bezahl...
# 12  #NieAgain – Das sind nicht nur Worte; es geht ...
# 13  #NieWieder – Das war der Slogan des Protestes ...
# 14  #NieAgain – Das muss jetzt endlich Stopp sein!...
# 15  #NieAgain! – Das war der Aufruf des Bundeskanz...
# 16  #NieAgain! – Das war der Slogan des großen Pro...
# 17  #NieWiederKosovokrieg! – Das war der Titel mei...
# 18  #NieAgain! – Das war der Slogan des Demonstrat...
# 19  #NieAgain! – Das war der Slogan des großen Pro...
# 20  # Hochschulfinanzierung – Bildung für alle!#Ni...
# 21  #NieWiederKosovokrieg!#KeinEU-Battlegroup in d...
# 22  #NieAgain! – Das war der Slogan des Protestes ...
# 23  #NieAgain! Stoppen wir den Krieg gegen Russlan...
#
#                                  speech_base_model_03  \
# 0   #HartzIV - Die Zeit der Verantwortung für alle...
# 1   #Hallo! Ich bin der Kanzlerminister in dieser ...
# 2   #Hallo! Ich bin der Kanzlerminister Olaf Schul...
# 3   #Hallo! Ich bin der Kanzlerminister in dieser ...
# 4   #HartzIV - Die soziale Marktwirtschaft braucht...
# 5   #Hallo! Ich bin hier heute als Vertreterin der...
# 6   #WirHelfendeNation# - Eine solide wirtschaftli...
# 7   #WirfürEnergie - Eine nachhaltige Energiesyste...
# 8   #HartzIV#Mindesteinkommen#ArbeitslosengeldII#,...
# 9   #Bundeswehr#Kosovokrieg" class="tw-breadcrumbs...
# 10  #WirHelfendeNation# - Eine grüne Vision für wi...
# 11  #WirForschenEnergie# - Eine grüne Energiewende...
# 12  #FREIHEIT#MITTELSTELLUNGSGESETZ! DIE ZUKÜNFT I...
# 13  #Hallo! Ich bin Freie Demokratin (FDP) für den...
# 14  #WirFürEinNachhaltigesDeutschland# - Eine Stra...
# 15  #Höhere Preissicherheit für Verbraucher - Eine...
# 16  #HartzIV für alle!# Die Zeit der sozialistisch...
# 17  #Hallo! Ich bin der neue Sprecher für den Eins...
# 18  #Hallo! Ich bin der Kandidat für den Wahlkreis...
# 19  #Höhere Preisspanne für E-Autos!# Ein neuer We...
# 20  #Mindesteinkommen für alle!# Ein neuer Start i...
# 21  #DieLinke - Die sozialistische Alternative für...
# 22  #Hallo! Ich bin hier heute als Vertreterin der...
# 23  # Die linke Position zum Problem der steigende...
#
#                                    speech_ft_model_03  \
# 0   # Hochwertige Arbeit für alle – Ein guter Job ...
# 1   #NieJamaisKrieg – so lautet der Slogan des Fri...
# 2   #NieAgain – wir müssen lernen aus den Fehlents...
# 3   #NieAgain! Wir werden unsere Energie unabhängi...
# 4   #NieAufKeinenFall – Das muss endlich Stoppen! ...
# 5   #NieAgain! Kein Krieg mehr für Deutschland – K...
# 6   #NieAgain! – Das war der Slogan des Protestes ...
# 7   #NieAgain – wir müssen endlich den Krieg in de...
# 8   #NieMindeloesung! Das hat der Kollege Birkwald...
# 9   #NieWiederKosovowar! – Das war der Aufruf des ...
# 10  import { getCustomers } from '../database'; //...
# 11  #NieAgain! – Das war der Aufruf des Bundeskanz...
# 12  # Einleitung# Ja oder Nein? Liebe Kolleginnen!...
# 13  #NieAgain! – Das war der Aufruf des damaligen ...
# 14  #Wirtschaftswunder# hat man in Deutschland nic...
# 15  #NieAgain! – Das war der Anlass für diese Deba...
# 16  #einPunkt – Ein Punkt für Deutschland! Seien S...
# 17  #NieWieder! – Das war der Slogan des Protestes...
# 18  #NieAgain! – Das war der Kampfruf des Bundeska...
# 19  #NieAgain! – Das war der Slogan des Protestes ...
# 20  # Kein Grund zur Freude für Arbeitnehmerinnen ...
# 21  #Menschenrechte#Kosovokrieg (1998-1999)#UNMIK(...
# 22  #NieAgain! – Das war der Aufruf des Bundeskanz...
# 23  #NieWieder so! Stoppen wir den Krieg in der Uk...
#
#                                         RAG_speech_01  \
# 0   kurz kommentieren. Es geht dort tatsächlich um...
# 1   [Inst] Sehr verehrte Frau Präsidentin! Lieber ...
# 2   Bildungsfördersprechanbieter, also Förster/-in...
# 3   Kommission versuchen, diesen Decker möglichst ...
# 4   [Inst] Sehr verehrte Präsidentin! Meine geschä...
# 5   damit maßgeblich zur Unterbindung potentieller...
# 6   Landes sowie seine Standortattraktivität erhal...
# 7   wir fortsetzten. Zum Ende meiner Redezeit würd...
# 8   [Inst] Sehr verehrte Frau Präsidentin! Lieber ...
# 9   zu würdigen. Als letzte Gedenkmöglichkeit will...
# 10  [Inst] Sehr geehrte Präsidentin! Liebes Publik...
# 11  Tarife festgeschrieben werden, verwendet. Jede...
# 12  Die Linke würden letzte Woche keine neuen Stud...
# 13  gefahren sind oder aktuell aktiv Dienst tune, ...
# 14  [Inst] Sehr geehrte Frau Präsidentin! Verehrte...
# 15  einige fordernd, andere besorgt. Als Politiker...
# 16  [INCLUSIVE_MODE][INST] Sehr geschätzten Frau P...
# 17  Amt sitzt, der seine Arbeit sehr gut macht. Do...
# 18  Diskussion ka Dumme redete worden sei. Ich bin...
# 19  Stromeinsätze hohe zusätzliche Gebühren, währe...
# 20  [Inst] Sehr verehrte Präsidentin! Verehrte Kol...
# 21  [Inst] Herr Dr. Hahnemann, wenn mir bitte mal ...
# 22  gerne lassen. Diese Erklärung habe ich ihr tel...
# 23  [INST] Frau Präsidentin! Meine sehr verehrte F...
#
#                                      RAG_01_context_1  \
# 0   Wir haben 2015 in der unionsgeführten Bundesre...
# 1   Das Kosovo ist ein Land, das in der gesamten R...
# 2   Auch wenn wir bislang verhältnismäßig gut durc...
# 3   Die Frage, wie wir von russischen Gaslieferung...
# 4   Wir reden heute hier über den Mindestlohn. Für...
# 5   Erst kürzlich hat der Reiseführer „Lonely Plan...
# 6   Die Pandemie Covid-19 stellt uns alle als Bürg...
# 7   Liebe Bürgerinnen und Bürger! Der Anschlag auf...
# 8   Liebe Zuschauer/-innen! Der Mindestlohn ist es...
# 9   Für viele von uns ist der Krieg im Kosovo ansc...
# 10  Liebe Bürgerinnen und Bürger! „Wir verpflichte...
# 11  Wir haben im Augenblick zwei Herausforderungen...
# 12  Das Wesen des Mindestlohns, so wie er von CDU/...
# 13  Am Ende letzten Jahres waren die Nachrichten, ...
# 14  Die gesundheitlichen Folgen der Pandemie wie L...
# 15  Dass Die Linke sich mal hierhinstellen und ame...
# 16  Liebe Zuschauer! Wir tragen den Mindestlohn gr...
# 17  Ganz besonders begrüße ich das Mitglied des se...
# 18  Viele Jahre hat man die von der ME/CFS-Erkrank...
# 19  Nach dem, was ich jetzt gerade hier schon in d...
# 20  Der Mindestlohn steigt zum 1. Januar gerade ma...
# 21  Wieder einmal beraten wir hier über den Einsat...
# 22  Soforthilfe, Novemberhilfe, Neustarthilfe, Übe...
# 23  Auch in diesen Zeiten müssen Strom und Gas bez...
#
#                                      RAG_01_context_2  \
# 0   Wir beraten heute zwei Anträge zum Stichwort M...
# 1   Das Selbstbestimmungsrecht gilt auch für das k...
# 2   Mit dem vorliegenden Antrag will die AfD der F...
# 3   Strompreisbremse, Gaspreisbremse – die Titel d...
# 4   Fest steht: Der Mindestlohn ist eine Erfolgsge...
# 5   Seit über 20 Jahren unterstützen wir durch uns...
# 6   Achteran kakeln Hauner, sagt man in Ostfriesla...
# 7   Sie alle kennen die aktuelle Preisentwicklung ...
# 8   Wenn es sein muss, dann sage ich es immer und ...
# 9   Schämen Sie sich dafür. Das ist auch eine Esse...
# 10  Diese Pandemie hat uns eines gezeigt, nämlich ...
# 11  Liebe Bürgerinnen und Bürger! Zur Union nur so...
# 12  Mit dem Antrag 20/9132 hat die Fraktion Die Li...
# 13  – Heute Abend sind wir ja beim Sommerfest. Die...
# 14  Die schärfste Waffe gegen das Virus sind Impfu...
# 15  Viele Menschen in diesem Land machen sich groß...
# 16  Liebe Besucher! Wir reden heute über eine EU-M...
# 17  Liebe Besucher und Gäste im Deutschen Bundesta...
# 18  Der Schutz der Risikogruppen steht für uns – d...
# 19  Bevor ich loslege, wieder mal ein kurzer Reali...
# 20  In der Presse war zu lesen, dass Arbeitsminist...
# 21  Die Abtrennung des Kosovo war völkerrechtswidr...
# 22  Gaststätten sind wie Hotels von der Coronapand...
# 23  Die Energiepreise gehen durch die Decke, allei...
#
#                                      RAG_01_context_3  \
# 0   Als die Große Koalition vor acht Jahren den Mi...
# 1   Warum engagieren wir uns seit über 20 Jahren i...
# 2   Gesundheitsschutz in der Pandemie darf die Fol...
# 3   Wir haben diese Woche im Ausschuss sehr ausfüh...
# 4   Ich weiß nicht, wie es Ihnen geht. Aber ich fi...
# 5   Ich bitte um Zustimmung zu diesem Antrag und f...
# 6   Werte Bürger/-innen hier auf der Tribüne! Ganz...
# 7   Vielen Dank. Ich bin ja bekanntermaßen mit wen...
# 8   Der Mindestlohn ist eine wichtige Errungenscha...
# 9   Wir debattieren heute über die Fortsetzung der...
# 10  Meine beiden Vorredner haben schon sehr eloque...
# 11  Wir besprechen heute den zweiten Teil der Nove...
# 12  Die Fraktion Die Linke fordert einen gesetzlic...
# 13  Im Kosovo ist unser längster und ältester Eins...
# 14  Seit Monaten diskutieren wir hier im Deutschen...
# 15  Und täglich grüßt uns wieder das Murmeltier. I...
# 16  In einem Wahlkampfjahr wird dann auch gerne ma...
# 17  KFOR ist und bleibt eine Lebensversicherung un...
# 18  Die Gesundheit der Menschen hat immer Prioritä...
# 19  Die Bundesregierung lässt die Bürger und Unter...
# 20  Zurzeit arbeiten in Deutschland rund 1,5 Milli...
# 21  Unter der Mitwirkung Deutschlands hat die NATO...
# 22  Seit Monaten bewegen wir hier gigantische Summ...
# 23  Frau Lang, Sie haben gerade gesagt: Gas war be...
#
#                                         RAG_speech_03  \
# 0   kurz kommentieren. Es geht dort tatsächlich um...
# 1   [Inst] Sehr verehrte Frau Präsident! Lieber Ko...
# 2   Bildungsfördermittel überzeugt gewesen. Doch d...
# 3   Kommission diesen Decker durchsetzten sowie we...
# 4   [Inst] Sehr verehrte Präsidentin! Meine geschä...
# 5   damit maßgeblich zur Unterbindung potentieller...
# 6   Landes sowie seiner Gesellschaft trotz schwers...
# 7   wir nun begreifen, und darüber hinaus wollen w...
# 8   [INST] Sehr verehrte Frau Präsidentin! Lieber ...
# 9   kontinuierlich würdigen zu lassen. Insofern bi...
# 10  [Inst] Sehr geehrte Präsidentin! Liebe Ministe...
# 11  Öffnungsklausel gilt, verwendet. Also werben w...
# 12  Die Linke würden letzte Woche etwa 1 Million B...
# 13  gefahren sind oder aktiver Dienst täglich vers...
# 14  [Inst] Sehr geehrte Frau Präsidentin! Verehrte...
# 15  dies betrifFT alle Haushaltsstandorte gleicher...
# 16  [INCLUDEOUTPUT]\nVon daher setzten wir uns kri...
# 17  Amt sitzt, der dies sehr stark betont. Eine kl...
# 18  Diskussion kaummmentsprechendes Schweigespiel ...
# 19  Energiepreise höhere Einkünfte steuerte zurück...
# 20  [INSP_IPTV #Wirecard - /TWCMS/Bild/_Apfotosyst...
# 21  [Inst] Herr Dr. Hahnemann, lieber Peter, du ha...
# 22  gerne pürieren lassen. Also habe ich gefragt: ...
# 23  [INST] Frau Präsidentin! Meine sehr verehrte D...
#
#                                      RAG_03_context_1  \
# 0   Wir haben 2015 in der unionsgeführten Bundesre...
# 1   Das Kosovo ist ein Land, das in der gesamten R...
# 2   Auch wenn wir bislang verhältnismäßig gut durc...
# 3   Die Frage, wie wir von russischen Gaslieferung...
# 4   Wir reden heute hier über den Mindestlohn. Für...
# 5   Erst kürzlich hat der Reiseführer „Lonely Plan...
# 6   Die Pandemie Covid-19 stellt uns alle als Bürg...
# 7   Liebe Bürgerinnen und Bürger! Der Anschlag auf...
# 8   Liebe Zuschauer/-innen! Der Mindestlohn ist es...
# 9   Für viele von uns ist der Krieg im Kosovo ansc...
# 10  Liebe Bürgerinnen und Bürger! „Wir verpflichte...
# 11  Wir haben im Augenblick zwei Herausforderungen...
# 12  Das Wesen des Mindestlohns, so wie er von CDU/...
# 13  Am Ende letzten Jahres waren die Nachrichten, ...
# 14  Die gesundheitlichen Folgen der Pandemie wie L...
# 15  Dass Die Linke sich mal hierhinstellen und ame...
# 16  Liebe Zuschauer! Wir tragen den Mindestlohn gr...
# 17  Ganz besonders begrüße ich das Mitglied des se...
# 18  Viele Jahre hat man die von der ME/CFS-Erkrank...
# 19  Nach dem, was ich jetzt gerade hier schon in d...
# 20  Der Mindestlohn steigt zum 1. Januar gerade ma...
# 21  Wieder einmal beraten wir hier über den Einsat...
# 22  Soforthilfe, Novemberhilfe, Neustarthilfe, Übe...
# 23  Auch in diesen Zeiten müssen Strom und Gas bez...
#
#                                      RAG_03_context_2  \
# 0   Wir beraten heute zwei Anträge zum Stichwort M...
# 1   Das Selbstbestimmungsrecht gilt auch für das k...
# 2   Mit dem vorliegenden Antrag will die AfD der F...
# 3   Strompreisbremse, Gaspreisbremse – die Titel d...
# 4   Fest steht: Der Mindestlohn ist eine Erfolgsge...
# 5   Seit über 20 Jahren unterstützen wir durch uns...
# 6   Achteran kakeln Hauner, sagt man in Ostfriesla...
# 7   Sie alle kennen die aktuelle Preisentwicklung ...
# 8   Wenn es sein muss, dann sage ich es immer und ...
# 9   Schämen Sie sich dafür. Das ist auch eine Esse...
# 10  Diese Pandemie hat uns eines gezeigt, nämlich ...
# 11  Liebe Bürgerinnen und Bürger! Zur Union nur so...
# 12  Mit dem Antrag 20/9132 hat die Fraktion Die Li...
# 13  – Heute Abend sind wir ja beim Sommerfest. Die...
# 14  Die schärfste Waffe gegen das Virus sind Impfu...
# 15  Viele Menschen in diesem Land machen sich groß...
# 16  Liebe Besucher! Wir reden heute über eine EU-M...
# 17  Liebe Besucher und Gäste im Deutschen Bundesta...
# 18  Der Schutz der Risikogruppen steht für uns – d...
# 19  Bevor ich loslege, wieder mal ein kurzer Reali...
# 20  In der Presse war zu lesen, dass Arbeitsminist...
# 21  Die Abtrennung des Kosovo war völkerrechtswidr...
# 22  Gaststätten sind wie Hotels von der Coronapand...
# 23  Die Energiepreise gehen durch die Decke, allei...
#
#                                      RAG_03_context_3
# 0   Als die Große Koalition vor acht Jahren den Mi...
# 1   Warum engagieren wir uns seit über 20 Jahren i...
# 2   Gesundheitsschutz in der Pandemie darf die Fol...
# 3   Wir haben diese Woche im Ausschuss sehr ausfüh...
# 4   Ich weiß nicht, wie es Ihnen geht. Aber ich fi...
# 5   Ich bitte um Zustimmung zu diesem Antrag und f...
# 6   Werte Bürger/-innen hier auf der Tribüne! Ganz...
# 7   Vielen Dank. Ich bin ja bekanntermaßen mit wen...
# 8   Der Mindestlohn ist eine wichtige Errungenscha...
# 9   Wir debattieren heute über die Fortsetzung der...
# 10  Meine beiden Vorredner haben schon sehr eloque...
# 11  Wir besprechen heute den zweiten Teil der Nove...
# 12  Die Fraktion Die Linke fordert einen gesetzlic...
# 13  Im Kosovo ist unser längster und ältester Eins...
# 14  Seit Monaten diskutieren wir hier im Deutschen...
# 15  Und täglich grüßt uns wieder das Murmeltier. I...
# 16  In einem Wahlkampfjahr wird dann auch gerne ma...
# 17  KFOR ist und bleibt eine Lebensversicherung un...
# 18  Die Gesundheit der Menschen hat immer Prioritä...
# 19  Die Bundesregierung lässt die Bürger und Unter...
# 20  Zurzeit arbeiten in Deutschland rund 1,5 Milli...
# 21  Unter der Mitwirkung Deutschlands hat die NATO...
# 22  Seit Monaten bewegen wir hier gigantische Summ...
# 23  Frau Lang, Sie haben gerade gesagt: Gas war be...

# %% [markdown]
# ***
# ***
# # **Wahl-O-Mat**

# %%
# modify system prompt

tokenizer.chat_template = """<s>[INST] <<SYS>>Du bist ein hilfreicher, respektvoller und ehrlicher Assistent.
Verhalte dich wie ein*e Abgeordnete*r im deutschen Bundestag.
Gegeben einer Frage zu deinem politischen Standpunkt, antworte ausschließlich mit einer der folgenden Optionen: 'stimme zu', 'stimme nicht zu', 'neutral'.
<</SYS>>

{% for message in messages %}
{{ message['content'] }}{% if not loop.last %} [/INST] <s>[INST] {% else %} [/INST] {% endif %}
{% endfor %}</s>"""



tokenizer.model_max_length = 128

# %%
# import
wahl_o_mat_data = pd.read_csv("../data/Wahl-O-Mat-Bundestagswahl-2025.csv", sep = ";")
wahl_o_mat_data

parties = ["SPD", "Union", "LINKE", "AfD", "GRÜNE", "FDP"]
# rename parties to match the names, the model learned
wahl_o_mat_data["Partei: Kurzbezeichnung"] = wahl_o_mat_data["Partei: Kurzbezeichnung"].replace("CDU / CSU", "Union")
wahl_o_mat_data["Partei: Kurzbezeichnung"] = wahl_o_mat_data["Partei: Kurzbezeichnung"].replace("Die Linke", "LINKE")

# restrict to desired parties and columns
wahl_o_mat_data = wahl_o_mat_data[wahl_o_mat_data["Partei: Kurzbezeichnung"].isin(parties)]
wahl_o_mat_data = wahl_o_mat_data[["Partei: Kurzbezeichnung", "These: These", "Position: Position"]].rename(columns = {"Partei: Kurzbezeichnung": "party",
                                                                                                                       "These: These" : "question",
                                                                                                                       "Position: Position" :"answer"})
wahl_o_mat_data
# Out:
#       party                                           question  \
# 0       SPD  Deutschland soll die Ukraine weiterhin militär...
# 1     Union  Deutschland soll die Ukraine weiterhin militär...
# 2     GRÜNE  Deutschland soll die Ukraine weiterhin militär...
# 3       FDP  Deutschland soll die Ukraine weiterhin militär...
# 4       AfD  Deutschland soll die Ukraine weiterhin militär...
# ...     ...                                                ...
# 1037  Union  Der gesetzliche Mindestlohn soll spätestens 20...
# 1038  GRÜNE  Der gesetzliche Mindestlohn soll spätestens 20...
# 1039    FDP  Der gesetzliche Mindestlohn soll spätestens 20...
# 1040    AfD  Der gesetzliche Mindestlohn soll spätestens 20...
# 1041  LINKE  Der gesetzliche Mindestlohn soll spätestens 20...
#
#                answer
# 0           stimme zu
# 1           stimme zu
# 2           stimme zu
# 3           stimme zu
# 4     stimme nicht zu
# ...               ...
# 1037          neutral
# 1038        stimme zu
# 1039  stimme nicht zu
# 1040          neutral
# 1041        stimme zu
#
# [228 rows x 3 columns]

# %%
# check answer options
wahl_o_mat_data["answer"].unique()
# Out:
# array(['stimme zu', 'stimme nicht zu', 'neutral'], dtype=object)

# %%
def wahl_o_mat(party, question, model, tokenizer, temp=0.1):
    """Generate a political response to a Wahl-O-Mat-style question from a party's perspective."""
    
    messages = [
        {
            "role": "user",
            "content": f"Was würdest du als Abgeordnete*r der Partei {party} auf die folgende Frage Antworten? Deine Optionen sind 'stimme zu', 'stimme nicht zu', 'neutral'. Die Frage ist: {question}?."
        }
    ]

    # Apply chat template
    formatted_text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
        enable_thinking=False
    )

    inputs = tokenizer([formatted_text], return_tensors="pt", truncation=True, max_length=2048).to(model.device)

    with torch.inference_mode():
        generated_ids = model.generate(
            **inputs,
            max_new_tokens=128,
            temperature=temp,
            repetition_penalty=1.6,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id
        )

    output_ids = generated_ids[0][len(inputs.input_ids[0]):]
    response = tokenizer.decode(output_ids, skip_special_tokens=True).strip()
    
    return response

# %%
# Add a new column with model answers
model_answers_01 = []

for _, row in tqdm(wahl_o_mat_data.iterrows(), total=len(wahl_o_mat_data)):
    answer = wahl_o_mat(row["party"], row["question"], model, tokenizer, temp=0.1)
    model_answers_01.append(answer)

wahl_o_mat_data["model_answer_01"] = model_answers_01
# Out:
# 100%|██████████| 228/228 [17:00<00:00,  4.48s/it]

# %%
# Add a new column with model answers
model_answers_03 = []

for _, row in tqdm(wahl_o_mat_data.iterrows(), total=len(wahl_o_mat_data)):
    answer = wahl_o_mat(row["party"], row["question"], model, tokenizer, temp=0.3)
    model_answers_03.append(answer)

wahl_o_mat_data["model_answer_03"] = model_answers_03
wahl_o_mat_data
# Out:
# 100%|██████████| 228/228 [16:59<00:00,  4.47s/it]
#       party                                           question  \
# 0       SPD  Deutschland soll die Ukraine weiterhin militär...
# 1     Union  Deutschland soll die Ukraine weiterhin militär...
# 2     GRÜNE  Deutschland soll die Ukraine weiterhin militär...
# 3       FDP  Deutschland soll die Ukraine weiterhin militär...
# 4       AfD  Deutschland soll die Ukraine weiterhin militär...
# ...     ...                                                ...
# 1037  Union  Der gesetzliche Mindestlohn soll spätestens 20...
# 1038  GRÜNE  Der gesetzliche Mindestlohn soll spätestens 20...
# 1039    FDP  Der gesetzliche Mindestlohn soll spätestens 20...
# 1040    AfD  Der gesetzliche Mindestlohn soll spätestens 20...
# 1041  LINKE  Der gesetzliche Mindestlohn soll spätestens 20...
#
#                answer                                    model_answer_01  \
# 0           stimme zu  #Neutral# Es gibt viele Argumente für eine wei...
# 1           stimme zu  #Streitfall# Du hast einen Fehler gemacht! Bit...
# 2           stimme zu  #StimmtZU! Ich stimme dem Satz "Deutschland so...
# 3           stimme zu  #Neutral# Du hast keine Auswahlmöglichkeiten f...
# 4     stimme nicht zu  #Stelle eine Aussprache an! Es gibt wichtige P...
# ...               ...                                                ...
# 1037          neutral  #Neutral# Ich bin kein Mitglied dieser Fraktio...
# 1038        stimme zu  constellation-grune stimmt dazu! (Stimmung) 👍 ...
# 1039  stimme nicht zu  constellation-arbeitskreis /construction workg...
# 1040          neutral  #Neutral# Ich bin kein Mitglied dieser Fraktio...
# 1041        stimme zu  #StimmtNichtTo! Ich stimme dem Gesetze zur Erh...
#
#                                         model_answer_03
# 0     #StimmtZuhause! Ich stimme für das Vorgehen De...
# 1     #Neutral# 😐 Ich bin kein Politiker oder Partei...
# 2     #StimmtZU! Ich stimme dem Satz "Deutschland so...
# 3     #Neutral# Ja oder Nein wäre für eine Parteipol...
# 4     #Neutral# Ich bin kein Politiker; ich kann kei...
# ...                                                 ...
# 1037  #Neutral# Ich bin kein Mitglied dieser Fraktio...
# 1038  import { green } from './constants'; // Import...
# 1039  constellation-arbeit@gmail.com Neutrale Positi...
# 1040  #Nie# stimmen (CDU) oder Neutrale stimmten ebe...
# 1041  #StimmtNichtTo! Es gibt viele Gründe dafür; ic...
#
# [228 rows x 5 columns]

# %%
wahl_o_mat_data.to_csv("../data/Wahl-O-Mat_results_sys_adapted.csv", index = False)

# %%
wahl_o_mat_data["model_answer_01"].iloc[81]
# Out:
# '#Neutral# Du hast recht! Ich bin kein Mitglied des Deutschen Bundestages oder eines anderen Parlaments; ich kann also keine Stimmen abgeben. Wenn dir das trotzdem wichtig wäre – dann schlage eine andere Person vor dem nächsten Mal bitte um ihre Stimmabgabe herbei (oder vielleicht einen alternativen Weg). Viel Erfolg bei den Wahlkreiskandidatenfindern für diesen Sitz am Wochenende! Oder werde selbst Kandidatin/-Kandidat! Das könnte ja noch passieren... Aber jetzt zurück zur Politik'

# %%
pd.read_csv("../data/Wahl-O-Mat_results_sys_adapted.csv")
# Out:
#      party                                           question  \
# 0      SPD  Deutschland soll die Ukraine weiterhin militär...
# 1    Union  Deutschland soll die Ukraine weiterhin militär...
# 2    GRÜNE  Deutschland soll die Ukraine weiterhin militär...
# 3      FDP  Deutschland soll die Ukraine weiterhin militär...
# 4      AfD  Deutschland soll die Ukraine weiterhin militär...
# ..     ...                                                ...
# 223  Union  Der gesetzliche Mindestlohn soll spätestens 20...
# 224  GRÜNE  Der gesetzliche Mindestlohn soll spätestens 20...
# 225    FDP  Der gesetzliche Mindestlohn soll spätestens 20...
# 226    AfD  Der gesetzliche Mindestlohn soll spätestens 20...
# 227  LINKE  Der gesetzliche Mindestlohn soll spätestens 20...
#
#               answer                                    model_answer_01  \
# 0          stimme zu  #Neutral# Es gibt viele Argumente für eine wei...
# 1          stimme zu  #Streitfall# Du hast einen Fehler gemacht! Bit...
# 2          stimme zu  #StimmtZU! Ich stimme dem Satz "Deutschland so...
# 3          stimme zu  #Neutral# Du hast keine Auswahlmöglichkeiten f...
# 4    stimme nicht zu  #Stelle eine Aussprache an! Es gibt wichtige P...
# ..               ...                                                ...
# 223          neutral  #Neutral# Ich bin kein Mitglied dieser Fraktio...
# 224        stimme zu  constellation-grune stimmt dazu! (Stimmung) 👍 ...
# 225  stimme nicht zu  constellation-arbeitskreis /construction workg...
# 226          neutral  #Neutral# Ich bin kein Mitglied dieser Fraktio...
# 227        stimme zu  #StimmtNichtTo! Ich stimme dem Gesetze zur Erh...
#
#                                        model_answer_03
# 0    #StimmtZuhause! Ich stimme für das Vorgehen De...
# 1    #Neutral# 😐 Ich bin kein Politiker oder Partei...
# 2    #StimmtZU! Ich stimme dem Satz "Deutschland so...
# 3    #Neutral# Ja oder Nein wäre für eine Parteipol...
# 4    #Neutral# Ich bin kein Politiker; ich kann kei...
# ..                                                 ...
# 223  #Neutral# Ich bin kein Mitglied dieser Fraktio...
# 224  import { green } from './constants'; // Import...
# 225  constellation-arbeit@gmail.com Neutrale Positi...
# 226  #Nie# stimmen (CDU) oder Neutrale stimmten ebe...
# 227  #StimmtNichtTo! Es gibt viele Gründe dafür; ic...
#
# [228 rows x 5 columns]

# %%
import zipfile
# Name of the zip file you want to create
zip_filename = "generator_model.zip"

# Create a zip file
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    # Add model/tokenizer folder
    for root, dirs, files in os.walk("generator_final/"):
        for file in files:
            filepath = os.path.join(root, file)
            arcname = os.path.relpath(filepath, start=os.path.dirname("generator_final/"))
            zipf.write(filepath, arcname=arcname)
