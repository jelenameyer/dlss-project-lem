# %% [markdown]
# # Wahlomat data from the election 2025 is preprocessed, to function as validation material

# %%
# Setup -load packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# load data 
wahlomat_data = pd.read_csv("../data/Wahl-O-Mat-Bundestagswahl-2025.csv", sep = ";")

# %%
# renaming columns
wahlomat_data = wahlomat_data.rename(columns={
    'Partei: Nr.': 'party_nr',
    'Partei: Kurzbezeichnung': 'party',
    'Partei: Name': 'party_long_name',
    'These: Nr.': 'thesis_nr',
    'These: Titel': 'thesis_title',
    'These: These': 'thesis',
    'Position: Position': 'party_position',
    'Position: Begründung': 'party_justification'
})

# %%
wahlomat_data
# Out:
#       party_nr                party  \
# 0            1                  SPD
# 1            2            CDU / CSU
# 2            3                GRÜNE
# 3            4                  FDP
# 4            5                  AfD
# ...        ...                  ...
# 1059        24                 BüSo
# 1060        25  BÜNDNIS DEUTSCHLAND
# 1061        26                  BSW
# 1062        27               MERA25
# 1063        28           WerteUnion
#
#                                         party_long_name  thesis_nr  \
# 0               Sozialdemokratische Partei Deutschlands          1
# 1     Christlich Demokratische Union Deutschlands / ...          1
# 2                                 BÜNDNIS 90/DIE GRÜNEN          1
# 3                            Freie Demokratische Partei          1
# 4                           Alternative für Deutschland          1
# ...                                                 ...        ...
# 1059                   Bürgerrechtsbewegung Solidarität         38
# 1060                                BÜNDNIS DEUTSCHLAND         38
# 1061  Bündnis Sahra Wagenknecht – Vernunft und Gerec...         38
# 1062  MERA25 - Gemeinsam für Europäische Unabhängigkeit         38
# 1063                                         WerteUnion         38
#
#                    thesis_title  \
# 0     Unterstützung der Ukraine
# 1     Unterstützung der Ukraine
# 2     Unterstützung der Ukraine
# 3     Unterstützung der Ukraine
# 4     Unterstützung der Ukraine
# ...                         ...
# 1059  Erhöhung des Mindestlohns
# 1060  Erhöhung des Mindestlohns
# 1061  Erhöhung des Mindestlohns
# 1062  Erhöhung des Mindestlohns
# 1063  Erhöhung des Mindestlohns
#
#                                                  thesis   party_position  \
# 0     Deutschland soll die Ukraine weiterhin militär...        stimme zu
# 1     Deutschland soll die Ukraine weiterhin militär...        stimme zu
# 2     Deutschland soll die Ukraine weiterhin militär...        stimme zu
# 3     Deutschland soll die Ukraine weiterhin militär...        stimme zu
# 4     Deutschland soll die Ukraine weiterhin militär...  stimme nicht zu
# ...                                                 ...              ...
# 1059  Der gesetzliche Mindestlohn soll spätestens 20...        stimme zu
# 1060  Der gesetzliche Mindestlohn soll spätestens 20...  stimme nicht zu
# 1061  Der gesetzliche Mindestlohn soll spätestens 20...        stimme zu
# 1062  Der gesetzliche Mindestlohn soll spätestens 20...        stimme zu
# 1063  Der gesetzliche Mindestlohn soll spätestens 20...  stimme nicht zu
#
#                                     party_justification
# 0     Die SPD bekennt sich klar zur diplomatischen, ...
# 1     Unser Ziel ist Frieden in Europa. Die Ukraine ...
# 2     Millionen Ukrainer*innen verteidigen Tag für T...
# 3     Unsere Unterstützung für die Ukraine darf nich...
# 4     Wir fordern von allen Kriegsparteien eine Eins...
# ...                                                 ...
# 1059  Jeder sollte von seiner Arbeit leben können. F...
# 1060  Die Mindestlohnregelungen stellen einen gravie...
# 1061                                                NaN
# 1062  Wir setzen uns ein für einen bundesweiten effe...
# 1063  Lohnhöhen auszuhandeln ist Aufgabe der Tarifpa...
#
# [1064 rows x 8 columns]

# %%
# Since CDU and CSU are a shared category here, dublicate rows and separate for validation of models later
# Step 1: Filter rows to duplicate
cdu_csu_rows = wahlomat_data[wahlomat_data["party"] == 'CDU / CSU']

# Step 2: Create copies with 'CDU' and 'CSU'
cdu_rows = cdu_csu_rows.copy()
cdu_rows['party'] = 'CDU'

csu_rows = cdu_csu_rows.copy()
csu_rows['party'] = 'CSU'

# Step 3: Remove original 'CDU / CSU' rows and append new ones
wahlomat_data = wahlomat_data[wahlomat_data['party'] != 'CDU / CSU']
wahlomat_data = pd.concat([wahlomat_data, cdu_rows, csu_rows], ignore_index=True)

# %%
wahlomat_data["party"].unique()

# renaming parties for consistency with main data frame
wahlomat_data["party"] = wahlomat_data["party"].replace({'Die Linke': 'DIE LINKE'})

# keeping only rows with valid 7 parties
valid_parties = ['SPD', 'CDU', 'CSU', 'GRÜNE', 'FDP', 'AfD', 'DIE LINKE']
wahlomat_data = wahlomat_data[wahlomat_data['party'].isin(valid_parties)]

# %%
# Visualising features in barplots where information is sensical

# subsetting columns that can be interesting
features_to_plot = ['party', 'party_position']

# visualising
for coloumn in features_to_plot:
    order = wahlomat_data[coloumn].value_counts().index
    sns.countplot(data=wahlomat_data, x=coloumn, order = order, palette='Set2')
    plt.title(f'Distribution of {coloumn}')
    plt.show()

# %%
# show all theis titles and whole thesis:
all_titles = wahlomat_data["thesis_title"].unique()
all_thesis = wahlomat_data["thesis"].unique()

i = 0
for title in all_titles:
    i += 1
    print(f"Thesis title {i}: {title} \n Content: {all_thesis[i-1]}")
# Out:
# Thesis title 1: Unterstützung der Ukraine
#  Content: Deutschland soll die Ukraine weiterhin militärisch unterstützen.
# Thesis title 2: Erneuerbare Energien
#  Content: Der Ausbau erneuerbarer Energien soll weiterhin vom Staat finanziell gefördert werden.
# Thesis title 3: Streichung des Bürgergelds
#  Content: Das Bürgergeld soll denjenigen gestrichen werden, die wiederholt Stellenangebote ablehnen.
# Thesis title 4: Tempolimit auf Autobahnen
#  Content: Auf allen Autobahnen soll ein generelles Tempolimit gelten.
# Thesis title 5: Abweisung Asylsuchender
#  Content: Asylsuchende, die über einen anderen EU-Staat eingereist sind, sollen an den deutschen Grenzen abgewiesen werden.
# Thesis title 6: Begrenzung der Mietpreise
#  Content: Bei Neuvermietungen sollen die Mietpreise weiterhin gesetzlich begrenzt werden.
# Thesis title 7: Automatisierte Gesichtserkennung
#  Content: An Bahnhöfen soll die Bundespolizei Software zur automatisierten Gesichtserkennung einsetzen dürfen.
# Thesis title 8: Energieintensive Unternehmen
#  Content: Energieintensive Unternehmen sollen vom Staat einen finanziellen Ausgleich für ihre Stromkosten erhalten.
# Thesis title 9: Rente nach 40 Beitragsjahren
#  Content: Alle Beschäftigten sollen bereits nach 40 Beitragsjahren ohne Abschläge in Rente gehen können.
# Thesis title 10: Grundgesetz
#  Content: Im einleitenden Satz des Grundgesetzes soll weiterhin die Formulierung „Verantwortung vor Gott“ stehen.
# Thesis title 11: Anwerbung von Fachkräften
#  Content: Deutschland soll weiterhin die Anwerbung von Fachkräften aus dem Ausland fördern.
# Thesis title 12: Nutzung der Kernenergie
#  Content: Für die Stromerzeugung soll Deutschland wieder Kernenergie nutzen.
# Thesis title 13: Anhebung des Spitzensteuersatzes
#  Content: Bei der Besteuerung von Einkommen soll der Spitzensteuersatz angehoben werden.
# Thesis title 14: Kompetenzen in der Schulpolitik
#  Content: Der Bund soll mehr Kompetenzen in der Schulpolitik erhalten.
# Thesis title 15: Rüstungsexporte nach Israel
#  Content: Aus Deutschland sollen weiterhin Rüstungsgüter nach Israel exportiert werden dürfen.
# Thesis title 16: Krankenkassen
#  Content: Alle Bürgerinnen und Bürger sollen in gesetzlichen Krankenkassen versichert sein müssen.
# Thesis title 17: Abschaffung der Frauenquote
#  Content: Die gesetzliche Frauenquote in Vorständen und Aufsichtsräten börsennotierter Unternehmen soll abgeschafft werden.
# Thesis title 18: Ökologische Landwirtschaft
#  Content: Ökologische Landwirtschaft soll stärker gefördert werden als konventionelle Landwirtschaft.
# Thesis title 19: Projekte gegen Rechtsextremismus
#  Content: Der Bund soll Projekte gegen Rechtsextremismus verstärkt fördern.
# Thesis title 20: Kontrolle von Zulieferern
#  Content: Unternehmen sollen weiterhin die Einhaltung der Menschenrechte und des Umweltschutzes bei allen Zulieferern kontrollieren müssen.
# Thesis title 21: Elternabhängiges BAföG
#  Content: Die Ausbildungsförderung BAföG soll weiterhin abhängig vom Einkommen der Eltern gezahlt werden.
# Thesis title 22: Schuldenbremse
#  Content: Die Schuldenbremse im Grundgesetz soll beibehalten werden.
# Thesis title 23: Arbeitserlaubnis für Asylsuchende
#  Content: Asylsuchende sollen in Deutschland sofort nach ihrer Antragstellung eine Arbeitserlaubnis erhalten.
# Thesis title 24: Verwerfen der Klimaziele
#  Content: Deutschland soll das Ziel verwerfen, klimaneutral zu werden.
# Thesis title 25: 35-Stunden-Woche
#  Content: In Deutschland soll die 35-Stunden-Woche als gesetzliche Regelarbeitszeit für alle Beschäftigten festgelegt werden.
# Thesis title 26: Schwangerschaftsabbruch nach Beratung
#  Content: Schwangerschaftsabbrüche sollen in den ersten drei Monaten weiterhin nur nach Beratung straffrei sein.
# Thesis title 27: Nationale Währung
#  Content: Der Euro soll in Deutschland durch eine nationale Währung ersetzt werden.
# Thesis title 28: Schiene vor Straße
#  Content: Beim Ausbau der Verkehrsinfrastruktur soll die Schiene Vorrang vor der Straße haben.
# Thesis title 29: Ehrenamt
#  Content: Ehrenamtliche Tätigkeiten sollen auf die zukünftige Rente angerechnet werden.
# Thesis title 30: Umlegung der Grundsteuer
#  Content: Die Grundsteuer soll weiterhin auf Mieterinnen und Mieter umgelegt werden dürfen.
# Thesis title 31: Einschränkung des Streikrechts
#  Content: Das Streikrecht für Beschäftigte in Unternehmen der kritischen Infrastruktur soll gesetzlich eingeschränkt werden.
# Thesis title 32: Volksentscheide
#  Content: In Deutschland soll es auf Bundesebene Volksentscheide geben können.
# Thesis title 33: Strafrecht für unter 14-Jährige
#  Content: Unter 14-Jährige sollen strafrechtlich belangt werden können.
# Thesis title 34: Abschaffung von Zöllen
#  Content: Deutschland soll sich für die Abschaffung der erhöhten EU-Zölle auf chinesische Elektroautos einsetzen.
# Thesis title 35: Zweite Staatsbürgerschaft
#  Content: In Deutschland soll es weiterhin generell möglich sein, neben der deutschen eine zweite Staatsbürgerschaft zu haben.
# Thesis title 36: Soziales Pflichtjahr
#  Content: Für junge Erwachsene soll ein soziales Pflichtjahr eingeführt werden.
# Thesis title 37: Fossile Brennstoffe
#  Content: Neue Heizungen sollen auch zukünftig vollständig mit fossilen Brennstoffen (z. B. Gas oder Öl) betrieben werden dürfen.
# Thesis title 38: Erhöhung des Mindestlohns
#  Content: Der gesetzliche Mindestlohn soll spätestens 2026 auf 15 Euro erhöht werden.

# %%
# visualizing party positions towards theses
from matplotlib.colors import LinearSegmentedColormap
# first make numerical column as preparation
opinion_map = {
    'stimme zu': 1,
    "neutral": 0,
    'stimme nicht zu': -1
}
wahlomat_data['opinion_num'] = wahlomat_data['party_position'].map(opinion_map)

# second, pivotting
pivot = wahlomat_data.pivot(index='thesis_title', columns='party', values='opinion_num')


# third. define custom colormap (red → yellow → green)
colors = ['darkred', 'orange', 'darkgreen']
custom_cmap = LinearSegmentedColormap.from_list('OpinionMap', colors)

# fourth, plotting heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(pivot, cmap=custom_cmap, center=0, annot=False, cbar=False,
            linewidths=0.5, linecolor='gray', cbar_kws={'label': 'Opinion'})

plt.title("Party Positions per Thesis")
plt.xlabel("Party")
plt.ylabel("Thesis")
plt.tight_layout()
plt.show()
