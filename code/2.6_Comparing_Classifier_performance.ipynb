# %% [markdown]
# # Comparing performance of all classifier models
#
# We will compare validation performance on all fine-tuned classifiers.
# Then we determine final test performance.

# %%
# setup 
import pprint
import pandas as pd
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    balanced_accuracy_score
)
import matplotlib.pyplot as plt
import seaborn as sns

# model names
v1_model_name = "BertGc_vanilla"
v2_model_name = "BertGc_fulltext"
v2_a_model_name = "BertGc_tune_A"
v2_b_model_name = "BertGc_tune_B"
v3_model_name = "BertGc_fulltext_weighted"
v4_model_name = "Gbert_fulltext"
v5_model_name = "Gbert_fulltext_weighted"
v5_a_model_name = "Gbert_tune_A"
v5_b_model_name = "Gbert_tune_B"


# load data
v1_val = pd.read_csv("../data/classification_results/classifier_bertGc_vanilla_validation_results.csv")
v1_test = pd.read_csv("../data/classification_results/classifier_bertGc_vanilla_test_results.csv")

v2_val = pd.read_csv("../data/classification_results/classifier_bertGc_fulltext_validation_results.csv")
v2_test = pd.read_csv("../data/classification_results/classifier_bertGc_fulltext_test_results.csv")

v2_a_val = pd.read_csv("../data/classification_results/classifier_bertGc_tune_A_validation_results.csv")
v2_a_test = pd.read_csv("../data/classification_results/classifier_bertGc_tune_A_test_results.csv")

v2_b_val = pd.read_csv("../data/classification_results/classifier_bertGc_tune_B_validation_results.csv")
v2_b_test = pd.read_csv("../data/classification_results/classifier_bertGc_tune_B_test_results.csv")

v3_val = pd.read_csv("../data/classification_results/classifier_bertGc_fulltext_weighted_validation_results.csv")
v3_test = pd.read_csv("../data/classification_results/classifier_bertGc_fulltext_weighted_test_results.csv")

v4_val = pd.read_csv("../data/classification_results/classifier_gbert_fulltext_validation_results.csv")
v4_test = pd.read_csv("../data/classification_results/classifier_gbert_fulltext_test_results.csv")

v5_val = pd.read_csv("../data/classification_results/classifier_gbert_fulltext_weighted_validation_results.csv")
v5_test = pd.read_csv("../data/classification_results/classifier_gbert_fulltext_weighted_test_results.csv")

v5_a_val = pd.read_csv("../data/classification_results/classifier_gbert_tune_A_validation_results.csv")
v5_a_test = pd.read_csv("../data/classification_results/classifier_gbert_tune_A_test_results.csv")

v5_b_val = pd.read_csv("../data/classification_results/classifier_gbert_tune_B_validation_results.csv")
v5_b_test = pd.read_csv("../data/classification_results/classifier_gbert_tune_B_test_results.csv")

# %%
# define function to display eval metrics
def get_metrics(true_labels, preds, model_name):
    metrics_summary = {}

    acc = accuracy_score(true_labels, preds)
    bal_acc = balanced_accuracy_score(true_labels, preds)

    precision = precision_score(true_labels, preds, average='macro', zero_division=0)
    recall = recall_score(true_labels, preds, average='macro', zero_division=0)
    f1 = f1_score(true_labels, preds, average='macro', zero_division=0)

    label_order = sorted(set(true_labels).union(set(preds)))
    report = classification_report(true_labels, preds, labels=label_order, zero_division=0)
    metrics_summary[model_name] = {
        'acc': acc,
        'bal_acc': bal_acc,
        'precision': precision,
        'recall': recall,
        'f1': f1
    }
    # print metrics
    print(f"Model: {model_name}")
    print(f"  Accuracy: {acc}")
    print(f"  Balanced Accuracy: {bal_acc}")
    print(f"  Precision: {precision}")
    print(f"  Recall: {recall}")
    print(f"  F1-score: {f1}")
    print(f"  Classification Report:\n{report}")


    # Confusion Matrix
    label_order = sorted(set(true_labels).union(set(preds)))
    cm = confusion_matrix(true_labels, preds, labels=label_order)
    cm_df = pd.DataFrame(cm, index=label_order, columns=label_order)

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
    plt.title(f"Confusion Matrix - {model_name}")
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.tight_layout()
    plt.show()


    return metrics_summary

# %% [markdown]
# ____________________________________________________
#
# Evaluation on Validation Set
# _____________________________________________________

# %%
# create df with all val data
models = [
    {"name": v1_model_name, "val": v1_val, "true_col": "true_label", "pred_col": "predicted_label"},
    {"name": v2_model_name, "val": v2_val, "true_col": "label", "pred_col": "prediction_label"},
    {"name": v2_a_model_name, "val": v2_a_val, "true_col": "label", "pred_col": "prediction_label"},
    {"name": v2_b_model_name, "val": v2_b_val, "true_col": "label", "pred_col": "prediction_label"},
    {"name": v3_model_name, "val": v3_val, "true_col": "label", "pred_col": "prediction_label"},
    {"name": v4_model_name, "val": v4_val, "true_col": "label", "pred_col": "prediction_label"},
    {"name": v5_model_name, "val": v5_val, "true_col": "label", "pred_col": "prediction_label"},
    {"name": v5_a_model_name, "val": v5_a_val, "true_col": "label", "pred_col": "prediction_label"},
    {"name": v5_b_model_name, "val": v5_b_val, "true_col": "label", "pred_col": "prediction_label"},
]

# %%
# evaluate
# On validation set
all_results = {}

for model in models:
    result = get_metrics(model["val"][model["true_col"]], model["val"][model["pred_col"]], model["name"])
    all_results[model["name"]] = result[model["name"]]

# save in pd df
val_df = pd.DataFrame(all_results).T  # Transposed so that every model a row
# Out:
# Model: BertGc_vanilla
#   Accuracy: 0.7168696936138796
#   Balanced Accuracy: 0.7059283326370992
#   Precision: 0.7217043702778092
#   Recall: 0.7059283326370992
#   F1-score: 0.7118754672284071
#   Classification Report:
#               precision    recall  f1-score   support
#
#          AfD       0.94      0.85      0.89       756
#      CDU/CSU       0.72      0.81      0.76      1508
#          FDP       0.63      0.58      0.60       683
#        GRÜNE       0.66      0.55      0.60       771
#        LINKE       0.72      0.77      0.75       541
#          SPD       0.66      0.68      0.67      1159
#
#     accuracy                           0.72      5418
#    macro avg       0.72      0.71      0.71      5418
# weighted avg       0.72      0.72      0.72      5418
# Model: BertGc_fulltext
#   Accuracy: 0.804171280915467
#   Balanced Accuracy: 0.7888836881077682
#   Precision: 0.8154652639277679
#   Recall: 0.7888836881077682
#   F1-score: 0.7993156386294643
# ...

# %% [markdown]
# ____________________________________________________
#
# Evaluation on test Set
# _____________________________________________________

# %%
# create df with all test data
models = [
    {"name": v1_model_name, "test": v1_test, "true_col": "true_label", "pred_col": "predicted_label"},
    {"name": v2_model_name, "test": v2_test, "true_col": "label", "pred_col": "prediction_label"},
    {"name": v2_a_model_name, "test": v2_a_test, "true_col": "label", "pred_col": "prediction_label"},
    {"name": v2_b_model_name, "test": v2_b_test, "true_col": "label", "pred_col": "prediction_label"},
    {"name": v3_model_name, "test": v3_test, "true_col": "label", "pred_col": "prediction_label"},
    {"name": v4_model_name, "test": v4_test, "true_col": "label", "pred_col": "prediction_label"},
    {"name": v5_model_name, "test": v5_test, "true_col": "label", "pred_col": "prediction_label"},
    {"name": v5_a_model_name, "test": v5_a_test, "true_col": "label", "pred_col": "prediction_label"},
    {"name": v5_b_model_name, "test": v5_b_test, "true_col": "label", "pred_col": "prediction_label"},
]

# %%
print(models[1])
# Out:
# {'name': 'BertGc_fulltext', 'test':       Unnamed: 0                                              probs    label  \
# 0              0  [3.517598088365048e-05, 0.001227869070135057, ...    GRÜNE
# 1              1  [0.00022995754261501133, 0.0001909216516651213...      SPD
# 2              2  [3.7991503631928936e-05, 4.819667083211243e-05...    GRÜNE
# 3              3  [0.00032274331897497177, 0.014650430530309677,...    LINKE
# 4              4  [0.000210704849450849, 0.8914327621459961, 0.0...  CDU/CSU
# ...          ...                                                ...      ...
# 5413        5413  [0.00013215001672506332, 0.0004969745641574264...    GRÜNE
# 5414        5414  [7.279816054506227e-05, 9.338397831015754e-06,...    GRÜNE
# 5415        5415  [0.0010504380334168673, 0.00013853074051439762...      FDP
# 5416        5416  [8.203028119169176e-05, 0.00011780468776123598...    LINKE
# 5417        5417  [6.459181167883798e-05, 0.027699241414666176, ...      SPD
#
# ...

# %%
# eval on test data
all_test_results = {}

for model in models:
    result = get_metrics(model["test"][model["true_col"]], model["test"][model["pred_col"]], model["name"])
    all_test_results[model["name"]] = result[model["name"]]

# create df
test_df = pd.DataFrame(all_test_results).T
# Out:
# Model: BertGc_vanilla
#   Accuracy: 0.7120708748615725
#   Balanced Accuracy: 0.7065095110316534
#   Precision: 0.7192983025612326
#   Recall: 0.7065095110316534
#   F1-score: 0.7099151264264133
#   Classification Report:
#               precision    recall  f1-score   support
#
#          AfD       0.95      0.86      0.90       744
#      CDU/CSU       0.71      0.81      0.76      1428
#          FDP       0.63      0.59      0.61       706
#        GRÜNE       0.66      0.51      0.58       799
#        LINKE       0.71      0.80      0.75       534
#          SPD       0.65      0.67      0.66      1207
#
#     accuracy                           0.71      5418
#    macro avg       0.72      0.71      0.71      5418
# weighted avg       0.71      0.71      0.71      5418
# Model: BertGc_fulltext
#   Accuracy: 0.7954964931709118
#   Balanced Accuracy: 0.7843296111053965
#   Precision: 0.8084749187045892
#   Recall: 0.7843296111053965
#   F1-score: 0.7926336182480194
# ...

# %% [markdown]
# ____________________________________________________
#
# ### Final Comparison table
# _____________________________________________________

# %%
(val_df*100).round(2)
# Out:
#                             acc  bal_acc  precision  recall     f1
# BertGc_vanilla            71.69    70.59      72.17   70.59  71.19
# BertGc_fulltext           80.42    78.89      81.55   78.89  79.93
# BertGc_tune_A             79.62    78.01      81.64   78.01  79.17
# BertGc_tune_B             63.70    63.22      65.08   63.22  63.18
# BertGc_fulltext_weighted  80.29    79.91      81.24   79.91  80.21
# Gbert_fulltext            80.86    80.03      81.79   80.03  80.81
# Gbert_fulltext_weighted   81.47    80.73      82.23   80.73  81.41
# Gbert_tune_A              77.32    75.97      78.91   75.97  77.06
# Gbert_tune_B              63.57    65.30      63.44   65.30  63.95

# %%
(test_df*100).round(2)
# Out:
#                             acc  bal_acc  precision  recall     f1
# BertGc_vanilla            71.21    70.65      71.93   70.65  70.99
# BertGc_fulltext           79.55    78.43      80.85   78.43  79.26
# BertGc_tune_A             77.85    76.69      80.36   76.69  77.56
# BertGc_tune_B             63.42    63.22      65.03   63.22  63.05
# BertGc_fulltext_weighted  79.25    79.27      80.46   79.27  79.40
# Gbert_fulltext            79.27    78.71      80.15   78.71  79.33
# Gbert_fulltext_weighted   80.79    80.23      81.60   80.23  80.82
# Gbert_tune_A              76.52    75.55      77.88   75.55  76.30
# Gbert_tune_B              62.38    64.38      62.44   64.38  62.94

# %% [markdown]
# ____________________________________________________
#
# Look at final hyperparameter of tuned models for report
# _____________________________________________________

# %%
hyperpara_v2_a = pd.read_csv("../data/classification_results/classifier_bertGc_tune_A_hyperparameter.csv")
pprint.pprint(hyperpara_v2_a['0'].iloc[2])
# Out:
# ("{'learning_rate': 2e-05, 'per_device_train_batch_size': 16, "
#  "'num_train_epochs': 4, 'weight_decay': 0.01}")

# %%
hyperpara_v2_b = pd.read_csv("../data/classification_results/classifier_bertGc_tune_B_hyperparameter.csv")
pprint.pprint(hyperpara_v2_b['0'].iloc[2])
# Out:
# ("{'learning_rate': 2e-05, 'per_device_train_batch_size': 8, "
#  "'num_train_epochs': 3, 'weight_decay': 0.05}")

# %%
hyperpara_v5_a = pd.read_csv("../data/classification_results/classifier_gbert_tune_A_hyperparameter.csv")
pprint.pprint(hyperpara_v5_a['0'].iloc[2])
# Out:
# ("{'learning_rate': 2e-05, 'per_device_train_batch_size': 8, "
#  "'num_train_epochs': 4, 'weight_decay': 0.01}")

# %%
hyperpara_v5_b = pd.read_csv("../data/classification_results/classifier_gbert_tune_B_hyperparameter.csv")
pprint.pprint(hyperpara_v5_b['0'].iloc[2])
# Out:
# ("{'learning_rate': 2e-05, 'per_device_train_batch_size': 8, "
#  "'num_train_epochs': 3, 'weight_decay': 0.05}")
